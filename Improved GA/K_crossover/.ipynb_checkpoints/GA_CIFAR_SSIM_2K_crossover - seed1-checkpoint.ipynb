# %% [markdown]
# # IMPORT

# %% [markdown]
# In this notebook I did not normalized images before evolving, just when predicting

# %%
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
import pickle
import time
from skimage.measure import compare_ssim
import tensorflow as tf
from keras.models import Model,load_model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input, Activation
from keras.utils import to_categorical
import keras
import random
# Out:
# Using TensorFlow backend.

# %%
#Set seeds
random.seed(1)
np.random.seed(1)

# %% [markdown]
# # GLOBAL VARS

# %%
INDIVIDUALS = 50
P_CROSS = 0.6
P_MUTATION = 0.01
CIFAR_IMG= 32

# %% [markdown]
# # THE DATA

# %%
from keras.datasets import cifar10

# The data, split between train and test sets:
(x_train_C, y_train_C), (x_test_C, y_test_C) = cifar10.load_data()
print('x_train shape:', x_train_C.shape)
print(x_train_C.shape[0], 'train samples')
print(x_test_C.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
num_classes=10
epochs=10
img_shape=32 
y_train_C = to_categorical(y_train_C, num_classes)
y_test_C = to_categorical(y_test_C, num_classes)


input_shape=(32,32,1)

x_train_C = x_train_C.astype('float32')
x_test_C = x_test_C.astype('float32')
x_train_C /= 255
x_test_C /= 255


print('x_train shape:', x_train_C.shape)
print('Number of images in x_train', x_train_C.shape[0])
print('Number of images in x_test', x_test_C.shape[0])
print('y_train shape:', y_train_C.shape)
print("input shape: ",input_shape)


# CONVERT TO GRAY SCALE

import matplotlib.pyplot as plt
import numpy as np

def grayscale(data, dtype='float32'):
    # luma coding weighted average in video systems
    r, g, b = np.asarray(.3, dtype=dtype), np.asarray(.59, dtype=dtype), np.asarray(.11, dtype=dtype)
    rst = r * data[:, :, :, 0] + g * data[:, :, :, 1] + b * data[:, :, :, 2]
    # add channel dimension
    rst = np.expand_dims(rst, axis=3)
    return rst

x_train_C = grayscale(x_train_C)
x_test_C = grayscale(x_test_C)

# now we have only one channel in the images
img_channels = 1
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# Number of images in x_train 50000
# Number of images in x_test 10000
# y_train shape: (50000, 10)
# input shape:  (32, 32, 1)

# %% [markdown]
# # READ PICKLE FILES

# %%
with open('../../Subsets/subset_cifar', 'rb') as f:
    original = pickle.load(f)
    adversarial= pickle.load(f)
    original_y = pickle.load(f)
    adversarial_y = pickle.load(f)

# %%
print(f"Original shape {original.shape}")
print(f"Adversarial shape {adversarial.shape}")
print(f"Original labels shape {original_y.shape}")
print(f"Adversarial labels shape {adversarial_y.shape}")
# Out:
# Original shape (914, 32, 32, 1)
# Adversarial shape (133, 32, 32, 1)
# Original labels shape (914, 1)
# Adversarial labels shape (133, 1)

# %% [markdown]
# # LOAD THE MODEL

# %% [markdown]
# 3. CNN v2
#
# This network is made for CIFAR 10. The network is taken from [this blog]( https://appliedmachinelearning.blog/2018/03/24/achieving-90-accuracy-in-object-recognition-task-on-cifar-10-dataset-with-keras-convolutional-neural-networks/) . In this version below I didn't use some things used in the blog e.g. z-score and data augmentation.
#
#
# This network has training accuracy: 0.8940 , validation accuracy: 0.8245.
#
# **NOTE:** Training really slow, try to avoid it.

# %%
# Network 3 
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np

input_shape = (CIFAR_IMG,CIFAR_IMG,1)
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=input_shape))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
 
model.summary()


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


'''
history = model.fit(x=x_train_C,y=y_train_C, epochs=150, batch_size=64, validation_data=[x_test_C,y_test_C])

score= model.evaluate(x_test_C, y_test_C,verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save_weights("CNN_CIFAR10_net3.h5")
files.download('CNN_CIFAR10_net3.h5')
'''

model = load_model("../../Models/CNN_CIFAR10_net3.h5")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        320
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 308,714
# Trainable params: 307,818
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# # GENETIC ALGORITHM FUNCTIONS

# %%
def computing_SSIM(individual,target):
    return compare_ssim(individual.reshape(CIFAR_IMG,CIFAR_IMG), target.reshape(CIFAR_IMG,CIFAR_IMG))

def calculate_fitness(model,ind,target_image,label,l1=0.2, l2=0.8, N=50, num_classes=10):
  # predict the population
  predictions=model.predict(ind.reshape(1,CIFAR_IMG,CIFAR_IMG,1) / 255.0)  
  # po is the ground truth prediction, so for label = 0, it will be prediciton[0]
  predictions=predictions[0]
  po=predictions[label]
  # set that value to 0
  predictions[label]=0
  # take next highest one
  pd = np.max(predictions)
  diff=pd-po
  return l1*computing_SSIM(ind.reshape(CIFAR_IMG,CIFAR_IMG),target_image.reshape(CIFAR_IMG,CIFAR_IMG)) +l2*(diff)
  


def pop_fitness(model,pop,target,label):
    return [calculate_fitness(model, p, target, label) for p in pop]

def flatten(imgs):
    # flatten all images in np array or list
    return np.array([im.flatten() for im in imgs])

def gaussian_noise():
    # draw one sample of noise from zero mean 1 variance Gaussian
    return np.random.normal(0, 10)

def p_noise(x):
  if 0.01 > np.random.uniform():
    return x + gaussian_noise()
  else:
    return x
    
def add_noise(image):
    noise_v=np.vectorize(p_noise)
    return noise_v(image) #np.array([x + gaussian_noise() if P_MUTATION > np.random.uniform(0.0, 1.0) else x+0 for x in image])

def k_crossover(im1, im2, k=2):
    c1, c2 = [], []
    # get k crossover points
    points = sorted([np.random.randint(0, CIFAR_IMG*CIFAR_IMG-1, 1) for p in range(k)])
    points = sorted([np.random.randint(0,CIFAR_IMG*CIFAR_IMG-1,1) for p in range(k)])
    im_1_split = np.split(im1, [int(p) for p in points])
    im_2_split = np.split(im2, [int(p) for p in points])
    
    # alternate between lists to realise crossover (theres got to be a more clever way to do this)
    for i in range(k+1):
        if i % 2 == 0:
            c1.append(im_1_split[i])
            c2.append(im_2_split[i])
        else:
            c1.append(im_2_split[i])
            c2.append(im_1_split[i])
    return np.concatenate(c1, axis=0), np.concatenate(c2, axis=0)

def tournament(pop, model, ground_truth, target, k=3):

    indices = np.random.choice(range(len(pop)), k, replace=False) #we get 3 indxes [2 34 46]    
    individuals = pop.take(indices,axis=0)
    scores = pop_fitness(model,np.expand_dims(individuals.reshape(individuals.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3), ground_truth.reshape(CIFAR_IMG,CIFAR_IMG), target)
    index_max = np.argmax(scores)
    winner = individuals[index_max]
    return winner


def check_adv_termination(ind, label,ground_truth, model):
  # individual - the best one from the generation
  # label - class we want
  # ground_truth - the image (32,32)
  # model we are using 
  dist = 1-compare_ssim(ind.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG))
  predictions= model.predict(ind.reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0)
  predicted_label= np.argmax(predictions[0])
  if label != predicted_label and dist < 0.001:
    print("FOUND ADVERSARIAL")
    print(f"Fitness of the adversarial {calculate_fitness(model,ind,ground_truth,label)}")
    return ind
  return []

def init_pop_from_sample(n,img,label):
    x = np.array([add_noise(img) for i in range(n)])
    return x.reshape(n, CIFAR_IMG*CIFAR_IMG)

# %%
''' my part of the code ''' 
''' I know it is ugly, I will fix it . this is the intial version'''
# from Goorge Clooney paper
def quadrant_crossover(parent_1,parent_2):

  # reshape parents
  parent_1,parent_2= parent_1.reshape((CIFAR_IMG,CIFAR_IMG)), parent_2.reshape((CIFAR_IMG,CIFAR_IMG))
  # quadrants for both parents
  p1,p2,p3,p4,q1,q2,q3,q4 = [],[],[],[],[],[],[],[]
  child1, child2 = [],[]
  # getting random (x,y) point in 2D matrix
  x,y = np.random.randint(0,CIFAR_IMG-1), np.random.randint(0,CIFAR_IMG-1)  

  # choose which quadrant we want to crossover
  N = np.random.randint(0,3)
  #make quadrants
  for i in range(CIFAR_IMG):
    if (i<=x):
      p1.append(parent_1[i][:y+1])
      p2.append(parent_1[i][y+1:])
      q1.append(parent_2[i][:y+1])
      q2.append(parent_2[i][y+1:])
    else:
      p3.append(parent_1[i][:y+1])
      p4.append(parent_1[i][y+1:])
      q3.append(parent_2[i][:y+1])
      q4.append(parent_2[i][y+1:])

  if (N==0):
    ch1 = connect_quadrants(p1,q2,q3,q4)
    ch2 = connect_quadrants(q1,p2,p3,p4)
  elif (N==1):
    ch1 = connect_quadrants(q1,p2,q3,q4)
    ch2 = connect_quadrants(p1,q2,p3,p4)
  elif (N==2):
    ch1 = connect_quadrants(q1,q2,p3,q4)
    ch2 = connect_quadrants(p1,p2,q3,p4)
  else:
    ch1 = connect_quadrants(q1,q2,q3,p4)
    ch2 = connect_quadrants(p1,p2,p3,q4)

  return ch1,ch2

def connect_quadrants(q1,q2,q3,q4):
  left = np.concatenate((q1,q3))
  right = np.concatenate((q2,q4))
  image = np.concatenate((left,right),axis=1)
  return image.flatten()


def multi_crossover(parent1,parent2,target):
  pop= []
  # 2-k crossover
  pop.append(k_crossover(parent1, parent2))
  # Gorge Clooney crossover
  pop.append(quadrant_crossover(parent1,parent2))
  # uniform crossover
  pop.append(k_crossover(parent1, parent2,1))
  # SSIM similarity 
  flattened_list = [y for x in pop for y in x] # need to flatten the list because pop is list of lists, cause every crossover function returns 2 obj
  ssim = [computing_SSIM(ind,target) for ind in flattened_list ]
  # taking the index of largest two score
  id1=np.argmax(ssim)
  ssim[id1]=0
  id2 = np.argmax(ssim)
  #returning parents
  return flattened_list[id1],flattened_list[id2]

# %%
def return_best_individual(pop,fitness):
  index = np.argmax(fitness)
  best = pop[index]
  return best, np.max(fitness)

# %%
def choose_better_child(ch1, ch2,ground_truth,label,model):
  # I named it better child, but we choose by this parents as well
  ch1_f = calculate_fitness(model,ch1.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG),label)
  ch2_f = calculate_fitness(model,ch2.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG),label)
  # change this into ternary operator
  if ch1_f>ch2_f:
    return ch1
  else:
    return ch2

# %% [markdown]
# # THE MAIN LOOP

# %%
# for each image and label in adversarial
n=50
import time
# these are the examples that are found as adversarialwe will save these at the end in a file
evolved_examples= []
# fitness of the adversarials
fitness_of_evolved=[]
# time necessary to evolve the adversarial
times=[]
# the distance between the original image and the adversarial
ssim_values=[]
# number of round necessary to produce adversarial 
number_of_rounds=[]
# this will serve to see if the fitness changes or not 
best_fitness = 0


numb_of_found_after30=0
numb_of_adv_found=0

#dictionary to keep the best individual to check if the fitness is improving or not 


predicted_class= []
for img,label in zip(adversarial,adversarial_y):
  winner_of_gen = {"image":[],"label": None, "fitness": None}
  #temporary variable to check generations:
  fitness_no_change = 0
  start = time.time()
  label=label[0]
  #intialize population from the image and with the given label
  population = init_pop_from_sample(n,img,label)
  # calculate fitness of these individuals
  fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label)
  print(f"Initial fitness: \n {fitness}")
  #retun the best one from the population
  best,fit_max = return_best_individual(population,fitness)
  #check if adversarial
  check_adv = check_adv_termination(best,label,img, model)
  #define max generation
  max_gen=0
  winner_of_gen.update(image= best)
  winner_of_gen.update(label= label)
  winner_of_gen.update(fitness= fit_max)

  while (len(check_adv)==0 or max_gen<10000):
      new_pop=[]
      for i in range(50):
        parent1= tournament(population, model, img, label) 
        parent2 = tournament(population, model, img, label)
        if 0.8 > np.random.uniform(0.0, 1.0):
          child1, child2 = k_crossover(parent1, parent2) # crossover
          new_pop.append(add_noise(choose_better_child(child1, child2,img,label,model)))
        else:
          new_pop.append(add_noise(choose_better_child(parent1, parent2,img,label,model)))

      # to reshape into an array 
      population= np.array(new_pop)
      #check fitness of the generation
      fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label) 
      #find the highest fitness
      best,fit_max1 = return_best_individual(population,fitness)
      # check adversarial - check if pred != target, distance < 0.001 or fitness didn't improve 0.001 after 30 generations(this is in else condition)
      check_adv = check_adv_termination(best,label,img,model)

      #check if the first termination true 
      if(len(check_adv) != 0):
        print("Adversarial example image: \n")
        evolved_examples.append(check_adv) #add evolved example
        ssim_values.append(1-compare_ssim(check_adv.reshape(CIFAR_IMG,CIFAR_IMG),img.reshape(CIFAR_IMG,CIFAR_IMG))) #add the distance
        end=time.time()
        times.append(end-start) #add the time 
        fitness_of_evolved.append(calculate_fitness(model,check_adv,img,label)) #add the fitness value of adversarial
        number_of_rounds.append(max_gen)
        pred_l=np.argmax(model.predict(check_adv.reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0))
        predicted_class.append(pred_l)
        print("Left: adversarial \t Right: ground truth")
        fd, idx = plt.subplots(1,2)
        idx[0].imshow(check_adv.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        idx[1].imshow(img.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        plt.show()
        print(f"True label: {label}")
        print(f"predicted label: {pred_l}") 
        print("Time: ",end-start ," seconds")
        numb_of_adv_found+=1
        break
      #check the second termination 
      else:
          #check if fitness increases, if not , add +1 to temporary var
        if fit_max1>fit_max:
          fit_max=fit_max1
          winner_of_gen.update(image= best)
          winner_of_gen.update(label= label)
          winner_of_gen.update(fitness= fit_max1)
          fitness_no_change=0
        else:
          fitness_no_change+=1
      
      #print after every 10 generations to see the progress
      if (max_gen % 10 == 0):
        print(f"Generation {max_gen}")
        print(f"Max fitness value {fit_max}")
      max_gen+=1

      # if fitness did not improve for 30 generations, save the image that was best , saved it in a dicitonary
      if fitness_no_change==30:
        print("FITNESS DID NOT IMPROVE FOR 30 GENERATIONS")
        print("Best adversarial image we could find: \n")
        evolved_examples.append(winner_of_gen["image"])
        ssim_values.append(1-compare_ssim(np.array(winner_of_gen["image"]).reshape(CIFAR_IMG,CIFAR_IMG),img.reshape(CIFAR_IMG,CIFAR_IMG)))
        number_of_rounds.append(max_gen)
        end=time.time()
        times.append(end-start)
        fitness_of_evolved.append(winner_of_gen["fitness"])
        pred_l=np.argmax(model.predict(np.array(winner_of_gen["image"]).reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0))
        predicted_class.append(pred_l)
        print("Left: adversarial \t Right: ground truth")
        fd, idx = plt.subplots(1,2)
        idx[0].imshow(np.array(winner_of_gen["image"]).reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        idx[1].imshow(img.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        plt.show()
        print(f"True label: {label}")
        print(f"predicted label: {pred_l}")
        print("Time: ",end-start ," seconds")
        numb_of_found_after30 +=1
        break
# Out:
# Initial fitness:
#  [-0.6003421846829813, -0.6014233009400011, -0.6021710252132082, -0.6010787395273278, -0.6017296644445892, -0.6006246064342724, -0.6016371008769117, -0.6015986491587476, -0.6013498892158472, -0.5999955458140832, -0.601020590562576, -0.6017574466266108, -0.602747413741685, -0.6017573611414601, -0.6005499628970601, -0.6009253942964956, -0.6012076525904644, -0.6017729240012388, -0.601591565086971, -0.6002356500571928, -0.6020833207438715, -0.6014473382482549, -0.6047364836056387, -0.6036656071764964, -0.6028087296464472, -0.6002553189157103, -0.6011277407964598, -0.600873706128894, -0.6002998612753933, -0.5999804860611871, -0.6004737955634604, -0.6011875444301396, -0.6008069189157474, -0.6019352034546327, -0.6000528284646404, -0.6013990531717441, -0.600529128618289, -0.6021990828935389, -0.5999799240095858, -0.6013059022818715, -0.6010262546795597, -0.6028610166065058, -0.6013173335334538, -0.6016748774691136, -0.6015680422549939, -0.6016282783645052, -0.6015389422224486, -0.6002344390427716, -0.60037182666477, -0.602540684945236]
# Generation 0
# Max fitness value -0.5999799240095858
# C:\Users\Lora\Anaconda3\lib\site-packages\skimage\measure\_structural_similarity.py:155: UserWarning: Inputs have mismatched dtype.  Setting data_range based on X.dtype.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "
# Generation 10
# Max fitness value 0.06539527025178066
# Generation 20
# Max fitness value 0.9680552477580453
# Generation 30
# Max fitness value 0.972190105475206
# Generation 40
# Max fitness value 0.9723114069728372
# Generation 50
# Max fitness value 0.973625669800204
# Generation 60
# Max fitness value 0.9740874860865036
# Generation 70
# Max fitness value 0.9742080341435985
# Generation 80
# Max fitness value 0.9742080341435985
# Generation 90
# Max fitness value 0.9742080341435985
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  557.7421436309814  seconds
# Initial fitness:
#  [-0.5492550199901253, -0.525137214881125, -0.4939627148253687, -0.5122027012056438, -0.5248360109919905, -0.5320668042191856, -0.4914426400486826, -0.4965166341358509, -0.5100328653669777, -0.4783873121586707, -0.4665820810573139, -0.5050987494296624, -0.5303208111545639, -0.54363792861182, -0.4671744500325986, -0.4952763275289383, -0.47914532225030826, -0.5328297144987463, -0.4382587291829987, -0.40302152817130754, -0.4986202178017052, -0.4849091289837745, -0.4690369776922702, -0.5559218406958052, -0.4983374282391589, -0.4834449254911839, -0.4870034085901782, -0.42804850195071414, -0.5286661649409307, -0.5394121756230177, -0.5194508930630609, -0.5352432696122887, -0.5183931765291258, -0.4856825725742872, -0.46065085809341244, -0.5088442156182283, -0.4957666144668399, -0.5250893047797285, -0.49789195874542946, -0.5029422898301787, -0.33604921791656794, -0.5282249565449192, -0.4855488481885929, -0.4965525349908575, -0.40093027055251845, -0.39699245826409113, -0.5136637315365272, -0.46072543099769503, -0.49012209130110435, -0.5236784469878911]
# Generation 0
# Max fitness value -0.21949562053425464
# Generation 10
# Max fitness value 0.9203570538602699
# Generation 20
# Max fitness value 0.9919220114125502
# Generation 30
# Max fitness value 0.9951895650133306
# Generation 40
# Max fitness value 0.9953208966210083
# Generation 50
# Max fitness value 0.9953208966210083
# Generation 60
# Max fitness value 0.9953208966210083
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  349.88784742355347  seconds
# Initial fitness:
#  [-0.36783242695440055, -0.17900089849167336, -0.30243506492957095, -0.40904066213382323, -0.2667494979892874, -0.34445500321236533, -0.40154754008684923, -0.3420685565060134, -0.34957483728734284, -0.29624094310801596, -0.315204924656156, -0.315792655162208, -0.30345478021333117, -0.33800563909305986, -0.34773171744354847, -0.36361641681970003, -0.28859192085638097, -0.342290862567618, -0.22514924336974773, -0.41886018373273415, -0.18440633541799686, -0.2631350643446654, -0.04475989393608937, -0.3116753713046056, -0.2213133342984758, -0.38675957194518773, -0.4267444972911688, -0.38722351538685995, -0.25558951155824355, -0.4189027666323102, -0.37832955692114834, -0.21634094550548855, -0.22764492135653508, -0.3747796552455841, -0.289418909007478, -0.32603744614386104, -0.26971110684224453, -0.32252731612002195, -0.2878712885421213, -0.33339895926918656, -0.3376619562226496, -0.3016807076559641, -0.23681976741498725, -0.2840248389166906, -0.3469943722840114, -0.3479787249600709, -0.4080567914196459, -0.3955929933294617, -0.3653817278687006, -0.32126989777818205]
# Generation 0
# Max fitness value 0.1575208609622206
# Generation 10
# Max fitness value 0.9898125006458569
# Generation 20
# Max fitness value 0.9922373560901685
# Generation 30
# Max fitness value 0.9922825643291516
# Generation 40
# Max fitness value 0.9922825643291516
# Generation 50
# Max fitness value 0.9922825643291516
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  353.6177930831909  seconds
# Initial fitness:
#  [-0.5962604599924706, -0.5948613237579857, -0.5934500105112783, -0.5944686983469418, -0.5984084077350597, -0.5953185776014805, -0.5967442865473084, -0.595769555121556, -0.5985112158290012, -0.5914906228602437, -0.5964193939041416, -0.5956733456764082, -0.5941467189713567, -0.5916359351084906, -0.5948695945829668, -0.5944319040981474, -0.5962068281998978, -0.5936237134765162, -0.5958612362284204, -0.5935681315887059, -0.5908693101091156, -0.5929523164612476, -0.5918357953834255, -0.5940760068939879, -0.594018355804299, -0.5966819460831413, -0.5910835040540394, -0.5928285615682896, -0.5971154618276446, -0.5915730950722373, -0.5927438165769229, -0.5954284733663814, -0.594182285241464, -0.5909698351145829, -0.5936604743334076, -0.5948860393779027, -0.5963125788604038, -0.5916906358874944, -0.5933868142963179, -0.592459699100101, -0.5936631554618561, -0.5948799996727977, -0.5939364000506967, -0.5960517222539747, -0.5980045294903334, -0.5931038740569993, -0.5919830197178448, -0.5944013103487518, -0.5935243438427923, -0.5937873682286552]
# Generation 0
# Max fitness value -0.5792696508819553
# Generation 10
# Max fitness value 0.652239518513989
# Generation 20
# Max fitness value 0.9931846631150315
# Generation 30
# Max fitness value 0.9943069950281742
# Generation 40
# Max fitness value 0.9946941142405092
# Generation 50
# Max fitness value 0.9946941142405092
# Generation 60
# Max fitness value 0.9946941142405092
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  394.29502749443054  seconds
# Initial fitness:
#  [-0.5381201665439099, -0.5542570727984569, -0.47944067960322057, -0.4892490395059441, -0.5352425861490396, -0.5466270692090915, -0.526886463051983, -0.5164693135679717, -0.4685433986717477, -0.5336963574513076, -0.5379441653060931, -0.5380043003043824, -0.4981965759517111, -0.552850422235866, -0.5793419991688022, -0.5558240134542631, -0.5149933775887064, -0.5474019846328717, -0.5089428051750313, -0.5634761711513969, -0.5188399063226836, -0.5312831940061005, -0.5359912674144166, -0.5646831528413941, -0.5505574753924575, -0.5437393691519705, -0.5600282415986322, -0.5489701809347015, -0.5536966190293579, -0.5350928212842192, -0.5652597718668542, -0.5570117582262326, -0.5771902300730155, -0.5364414602984551, -0.5450809451417806, -0.5666769710955094, -0.5041437592795387, -0.5259083923198589, -0.5601730424248665, -0.530579391322104, -0.5022900047175791, -0.5525008889778217, -0.5815596482956229, -0.5163882197502095, -0.5771478339368785, -0.5345967931431299, -0.523881905594966, -0.5698493970590089, -0.544913776438096, -0.5702807596915769]
# Generation 0
# Max fitness value -0.40180348434014235
# Generation 10
# Max fitness value 0.9551860565363803
# Generation 20
# Max fitness value 0.9614194927464375
# Generation 30
# Max fitness value 0.963065353886676
# Generation 40
# Max fitness value 0.963065353886676
# Generation 50
# Max fitness value 0.963065353886676
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  302.80207204818726  seconds
# Initial fitness:
#  [-0.6044806727289467, -0.6034721377254895, -0.612627920730744, -0.5963580326288117, -0.603538051298175, -0.595093532571553, -0.6030723193183309, -0.6006668018380615, -0.6022690512403104, -0.6066141575764039, -0.5981284313261949, -0.5953651472416317, -0.5857998907625872, -0.6072853636217046, -0.5956380478402594, -0.609905943136319, -0.6132897902692681, -0.6051901549323818, -0.600224088849515, -0.5997608197457938, -0.6023268905272466, -0.6152614067859223, -0.5909581269366936, -0.592920643964555, -0.5943441460884378, -0.6033797183031702, -0.5943141337912003, -0.6122916290004722, -0.5996392970329993, -0.6059286377608833, -0.5960782936531881, -0.6001037618017764, -0.603495780547882, -0.5968719815343362, -0.5942448191139039, -0.5981889455743745, -0.5905602706073723, -0.6025047235806584, -0.5961330444527828, -0.6004062864163809, -0.6092679522952975, -0.609744564675663, -0.6031852400788604, -0.6142908615728558, -0.6126769544377068, -0.6047190635156542, -0.6066969607078375, -0.6044395590653092, -0.5924987904338714, -0.5919994358633218]
# Generation 0
# Max fitness value -0.5298669261204771
# Generation 10
# Max fitness value 0.8834065099502801
# Generation 20
# Max fitness value 0.9308031986704355
# Generation 30
# Max fitness value 0.9308031986704355
# Generation 40
# Max fitness value 0.9308031986704355
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  261.6954801082611  seconds
# Initial fitness:
#  [-0.599691841440146, -0.6036312587605495, -0.6051758897816691, -0.6037094872251825, -0.601071824167166, -0.6006175515760581, -0.6062971334258002, -0.602000320338056, -0.6001539648810366, -0.6016406072202802, -0.599716238263469, -0.6027761322879799, -0.6060044859476548, -0.5997328516298749, -0.6007156641697491, -0.6077938082368818, -0.6004510960813555, -0.604709892042187, -0.6027524299988744, -0.6018500547348024, -0.6037900577755431, -0.6039725374290663, -0.6035930471439135, -0.5999516700456654, -0.6018846133752657, -0.6082842866661546, -0.6068133849167432, -0.6000529078615091, -0.6004075129567975, -0.6024030590597633, -0.6010085255860746, -0.6037021840300081, -0.599686427197176, -0.603140184283218, -0.6111732494972426, -0.6025337577225744, -0.600589479514759, -0.6034116408603771, -0.5997729614732779, -0.6131501784615714, -0.6021461216201573, -0.6066247676467434, -0.6038411772120746, -0.6022643434542927, -0.6005339236044883, -0.6039735110046694, -0.6044632896716983, -0.6031567509587605, -0.6061248275927609, -0.604956929250024]
# Generation 0
# Max fitness value -0.599686427197176
# Generation 10
# Max fitness value -0.5785391417760444
# Generation 20
# Max fitness value 0.5383105462800454
# Generation 30
# Max fitness value 0.9580160216396251
# Generation 40
# Max fitness value 0.9687247710442856
# Generation 50
# Max fitness value 0.9702891232033068
# Generation 60
# Max fitness value 0.9703860711927723
# Generation 70
# Max fitness value 0.9708009991383303
# Generation 80
# Max fitness value 0.9709162132557773
# Generation 90
# Max fitness value 0.9722770880764358
# Generation 100
# Max fitness value 0.9722770880764358
# Generation 110
# Max fitness value 0.9728186360221034
# Generation 120
# Max fitness value 0.9728186360221034
# Generation 130
# Max fitness value 0.9731627524585178
# Generation 140
# Max fitness value 0.9735463175806728
# Generation 150
# Max fitness value 0.9736562411012581
# Generation 160
# Max fitness value 0.9737049728339122
# Generation 170
# Max fitness value 0.9737049728339122
# Generation 180
# Max fitness value 0.9737049728339122
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  735.8550510406494  seconds
# Initial fitness:
#  [-0.594243675416597, -0.5948946672256663, -0.5967362037443501, -0.5919779708095866, -0.5953726005720719, -0.5943189897237432, -0.5957314456478544, -0.5952409209971475, -0.596857746923543, -0.596218748665921, -0.5969861802357694, -0.5949183340116304, -0.5963667370219682, -0.5969954386340024, -0.5967857244500352, -0.594118980345989, -0.5943495304362622, -0.5965320688548211, -0.5958885333202543, -0.5955194422065556, -0.5942902532496399, -0.5979139424708713, -0.5981077997718784, -0.5964251807406686, -0.5962615907566668, -0.5941365941096018, -0.5949415462860547, -0.5942674738946936, -0.5949858109624984, -0.5961378528846191, -0.596123420882057, -0.5953091676641229, -0.5872549527274367, -0.5967128070505492, -0.5960040419783874, -0.5964249011421021, -0.5969351700215094, -0.5962525820010683, -0.5964327684277716, -0.5976691817844415, -0.5968366006898506, -0.5958398354005058, -0.5960414506117239, -0.5961698310928301, -0.5966095732869068, -0.5972247121565374, -0.5965838456204197, -0.596281848184773, -0.5969573265261333, -0.5963131829550277]
# Generation 0
# Max fitness value -0.5829656015775664
# Generation 10
# Max fitness value 0.10289337353349717
# Generation 20
# Max fitness value 0.9504015528377813
# Generation 30
# Max fitness value 0.9924869470052338
# Generation 40
# Max fitness value 0.9938694760181984
# Generation 50
# Max fitness value 0.9941381359025656
# Generation 60
# Max fitness value 0.9942725732671299
# Generation 70
# Max fitness value 0.9944002731759323
# Generation 80
# Max fitness value 0.9944970452897192
# Generation 90
# Max fitness value 0.9944970452897192
# Generation 100
# Max fitness value 0.9944970452897192
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 4
# Time:  421.8812735080719  seconds
# Initial fitness:
#  [-0.5690065796239336, -0.5815695012358382, -0.5873797795670042, -0.5882079266161511, -0.5771583079574188, -0.5761529037355086, -0.5739985653026914, -0.5832075458476561, -0.5342851991351886, -0.5791777857530656, -0.5887655296979164, -0.5926821891180084, -0.5780569369856616, -0.5781162868349811, -0.5788689385416071, -0.5854071510216388, -0.5841036053907998, -0.5716862492400924, -0.5608234474148962, -0.5759003498255966, -0.59271392954831, -0.5861898807518656, -0.5833926312076805, -0.5752439112182595, -0.5742155634569718, -0.5781536201519033, -0.5756621081117097, -0.5890920601138655, -0.5814279774008968, -0.5793642666718255, -0.5750941556245475, -0.585021282072748, -0.5848398939123154, -0.5803703885402723, -0.5801974639939427, -0.5935905267685279, -0.583629746378614, -0.5741501526947281, -0.5743250192740696, -0.5966977355883969, -0.5625740483585244, -0.5803372341402429, -0.5818638431755122, -0.5725824226642556, -0.5674976746395013, -0.5746179902562831, -0.5712600596059746, -0.5788819206380338, -0.5840888307257424, -0.5873259155464308]
# Generation 0
# Max fitness value -0.5205510628183153
# Generation 10
# Max fitness value 0.8171837675950335
# Generation 20
# Max fitness value 0.9837549806889339
# Generation 30
# Max fitness value 0.9883091370498917
# Generation 40
# Max fitness value 0.9889514888173432
# Generation 50
# Max fitness value 0.9892606874526233
# Generation 60
# Max fitness value 0.9892606874526233
# Generation 70
# Max fitness value 0.9895209191890676
# Generation 80
# Max fitness value 0.9895209191890676
# Generation 90
# Max fitness value 0.9895209191890676
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  372.3719675540924  seconds
# Initial fitness:
#  [-0.0558895295835809, -0.1728790520761952, -0.3888832250075303, 0.1526216894596574, -0.12539715870440704, -0.11551966670016545, -0.08535534468922518, -0.12707329037966114, -0.08555053848073096, 0.022493338340965396, -0.3739673218751305, -0.14063427014082622, -0.15556521610229063, -0.11325483956550281, -0.13619334329629876, 0.04277577672529745, -0.1724950297461171, 0.12793305075431624, -0.18148053329591, -0.058676703475941255, 0.21334868953030062, -0.061915422943940646, 0.09519930942445604, -0.3156924916279824, -0.06597028340833042, -0.09949734408947589, -0.23109580153401638, -0.39168321760440206, -0.24706733494340338, -0.012918494910411554, -0.40253637417321975, -0.1456183595070692, -0.18060004526599727, -0.07348539685335284, -0.25541475999738367, -0.20583030416288423, -0.22382507640757543, -0.04614724351833177, -0.15960275619281716, -0.044458647064858664, -0.12829729715544116, -0.3680627272893524, -0.1668489433831115, -0.5033026051971745, -0.2463486425584602, -0.06395006674432599, -0.06451826965443946, -0.06834162847531405, -0.23622363025157234, 0.2670018866749343]
# Generation 0
# Max fitness value 0.5476083232523714
# Generation 10
# Max fitness value 0.9805063009026576
# Generation 20
# Max fitness value 0.9817000052090221
# Generation 30
# Max fitness value 0.9817000052090221
# Generation 40
# Max fitness value 0.9817000052090221
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  173.82689809799194  seconds
# Initial fitness:
#  [-0.5413119991511599, -0.48941961968711833, -0.5315437818044081, -0.5145364829097184, -0.4985507773654049, -0.48421168983667384, -0.5325977514976996, -0.588061260366199, -0.4730446734333915, -0.4902304444613824, -0.5230868510742999, -0.540800838054447, -0.4504869088709391, -0.5411415956787414, -0.5273709328416631, -0.5697709844680697, -0.5618078019618702, -0.5322009948921356, -0.5390022991652115, -0.5053907237579373, -0.5425687246764774, -0.48857984949189626, -0.5157412521287503, -0.5408220130541249, -0.5671577005754805, -0.5260379546873978, -0.5819594745243277, -0.48427811330033094, -0.4672608212477636, -0.5146906511066704, -0.4320237870154906, -0.5082792107509165, -0.4889563409949249, -0.5225367810013819, -0.5483921247111855, -0.5621785219574228, -0.5101109080579487, -0.5084619335867688, -0.5417454060181247, -0.48624269243760154, -0.4276533355599127, -0.4853974105495429, -0.5577697256172197, -0.4908046410628064, -0.5133789956374618, -0.19101366422357963, -0.5017899866366435, -0.5167791023847215, -0.5005365435840078, -0.5469356577206468]
# Generation 0
# Max fitness value -0.18670984066828616
# Generation 10
# Max fitness value 0.9558260046556025
# Generation 20
# Max fitness value 0.9941027087034271
# Generation 30
# Max fitness value 0.9946656673506725
# Generation 40
# Max fitness value 0.9948869923659973
# Generation 50
# Max fitness value 0.9948869923659973
# Generation 60
# Max fitness value 0.9949737412279746
# Generation 70
# Max fitness value 0.9950200524121076
# Generation 80
# Max fitness value 0.9950200524121076
# Generation 90
# Max fitness value 0.9950200524121076
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 9
# Time:  384.3823711872101  seconds
# Initial fitness:
#  [0.4074409731601714, 0.5078460141502709, 0.4276537694913313, 0.45182992542564715, 0.4570504615728893, 0.397569273845404, 0.4293524459722078, 0.4814252763762638, 0.4653746490026763, 0.38071490273639047, 0.3819793789215423, 0.5604739990252412, 0.41932980311056645, 0.4332604897306132, 0.4031167041027433, 0.4818543213332747, 0.5649823660944622, 0.2948623224098226, 0.4797250313254864, 0.5204853668334837, 0.3705744248047012, 0.3720102249993751, 0.4096876786819306, 0.47299245380001687, 0.32377026207541804, 0.4303455325261134, 0.38191568641370305, 0.48436617551965366, 0.379451510325804, 0.5274861101905118, 0.6263162683346665, 0.3509308983587106, 0.35912618956027187, 0.5264193357536258, 0.4041716242466997, 0.45884377395054443, 0.4604438813339029, 0.44530010928404784, 0.4662537230420476, 0.5577750702372586, 0.482775749577855, 0.4696300459033328, 0.45799519085288337, 0.43551256667854216, 0.395465331630488, 0.4874621203976225, 0.3835651040042818, 0.38685285891340826, 0.3722147391394044, 0.42960198258818116]
# Generation 0
# Max fitness value 0.7526520295066084
# Generation 10
# Max fitness value 0.9920276358193553
# Generation 20
# Max fitness value 0.9935252633128325
# Generation 30
# Max fitness value 0.9935252633128325
# Generation 40
# Max fitness value 0.9935252633128325
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  190.86417961120605  seconds
# Initial fitness:
#  [-0.40945813626263905, -0.18676918875677956, 0.019147504337293064, -0.2720479962335519, -0.41406175653082544, 0.10520240817902095, -0.21803489213766325, -0.11889579954806359, -0.05066517073035576, 0.1953679642657604, -0.18399122143029994, -0.08475930611801791, -0.46589755130266, -0.08739053204059852, -0.0003301486154853872, -0.3059438785427092, -0.38907869749573143, -0.10940355656428827, -0.26668024031598403, 0.06913145131720438, -0.2732172559347871, -0.015982404894941682, -0.28936321701389245, -0.22506492276171755, -0.2911840674001336, -0.1650619187532389, -0.18914912378185614, -0.0965027530397885, -0.26491284216596145, -0.28295105205693705, -0.256123325752577, 0.4266796836314076, -0.1030183295862439, -0.31282402953062377, -0.25906339274910506, -0.31886321692754316, -0.36747340378791915, -0.1419452031864755, -0.0410541329542731, -0.2856525840065255, -0.16819365130716174, -0.19583260622893162, -0.2506470833025792, -0.22127907988986667, -0.18718620406264952, -0.31730981311696727, -0.23606623842643568, -0.3007445070994068, -0.14458799713358977, 0.26088217958841853]
# Generation 0
# Max fitness value 0.6088509949352912
# Generation 10
# Max fitness value 0.9953286758067426
# Generation 20
# Max fitness value 0.996136225159975
# Generation 30
# Max fitness value 0.9963024046282988
# Generation 40
# Max fitness value 0.9963024046282988
# Generation 50
# Max fitness value 0.9963731834621861
# Generation 60
# Max fitness value 0.9963731834621861
# Generation 70
# Max fitness value 0.9963731834621861
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  301.5486378669739  seconds
# Initial fitness:
#  [-0.6016649765173033, -0.6012848271312312, -0.6017946630655368, -0.6032587416774675, -0.6001175349899218, -0.6000665044661138, -0.6001774167681782, -0.6021306816406147, -0.6026205508325927, -0.6000997206063862, -0.6024498021731997, -0.602031024595662, -0.602400615946804, -0.6005956482556813, -0.601065186065867, -0.6024315240012713, -0.6012286598278155, -0.6008578503890034, -0.6010917386967444, -0.6041064412492312, -0.600640402110341, -0.6016799403781801, -0.6014141548774032, -0.601867030165807, -0.6033922200888862, -0.6000186428919266, -0.6026611298603572, -0.6022932026610559, -0.6052517852942244, -0.6010791220183873, -0.6011446096527747, -0.6007542315710422, -0.6046924734289131, -0.6028785327820859, -0.6030377647013005, -0.6011943144608743, -0.600775586761445, -0.6008396976068713, -0.6027108749396223, -0.6011953630282647, -0.6007764687817727, -0.6020917332006626, -0.6038141914037609, -0.6001764754926748, -0.6013495921752907, -0.6008341775477546, -0.6022095667863607, -0.6007993108612408, -0.6023352954591022, -0.6020476416641782]
# Generation 0
# Max fitness value -0.6000186428919266
# Generation 10
# Max fitness value -0.6000186428919266
# Generation 20
# Max fitness value -0.03616441991396285
# Generation 30
# Max fitness value 0.9862346176208525
# Generation 40
# Max fitness value 0.9897386639525321
# Generation 50
# Max fitness value 0.9897386639525321
# Generation 60
# Max fitness value 0.9897386639525321
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 8
# Time:  277.4495360851288  seconds
# Initial fitness:
#  [-0.5496139060511219, -0.49041119063559824, -0.5385398711901975, -0.3914205806345924, -0.5529822549524762, -0.5623290718492708, -0.5257843440209286, -0.3630560736899491, -0.5345075394437597, -0.5356316340551228, -0.4872104410787057, -0.5277733930433073, -0.5517954868728443, -0.5525975157469037, -0.5523047520318397, -0.5448173617224812, -0.5756527136284721, -0.4532492188877479, -0.5057984934609874, -0.557126952390236, -0.5695566651225523, -0.585428270040449, -0.5587186090919595, -0.5645727392159468, -0.5411289908019922, -0.5521702661319887, -0.5318239847725924, -0.5541274323122093, -0.5457278113850365, -0.5040184026417842, -0.5740325815553664, -0.464034778422503, -0.5445350832324825, -0.3353668356822336, -0.5478672935059676, -0.5503066281826183, -0.5501927382771727, -0.513734932927411, -0.5598514093343997, -0.5701558005397304, -0.5666269367323747, -0.5261028885980489, -0.5286958955298126, -0.5607034505027413, -0.5177118822856234, -0.5317205799415525, -0.559548799286463, -0.5813364360866887, -0.5729902287465283, -0.5508290258010786]
# Generation 0
# Max fitness value -0.1524890012656086
# Generation 10
# Max fitness value 0.9943079207998096
# Generation 20
# Max fitness value 0.9974171666099039
# Generation 30
# Max fitness value 0.9976376369863034
# Generation 40
# Max fitness value 0.9976376369863034
# Generation 50
# Max fitness value 0.9976376369863034
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  231.42150807380676  seconds
# Initial fitness:
#  [-0.600869894821906, -0.6004936129634152, -0.6066299382349364, -0.6006930609737797, -0.6001998130494683, -0.6034586685850244, -0.6007107346860722, -0.600610047670093, -0.6006124671570817, -0.605039632632497, -0.6026291128013066, -0.6043200620022728, -0.6012427232054318, -0.6023504244012662, -0.6000339534116581, -0.603195870333729, -0.6004347019637194, -0.6031393301112875, -0.6003383462871891, -0.6070381550944297, -0.601163211381728, -0.6051337123886067, -0.6008660928659519, -0.605074916127091, -0.6004884638707616, -0.6060453103161918, -0.6013288287699416, -0.6001316749506445, -0.6002365734005712, -0.6023675905999987, -0.6015484355309184, -0.604142952871348, -0.6007635769631375, -0.6036415753627611, -0.6023912561924012, -0.6005194508590245, -0.6005887978125216, -0.601836918540828, -0.6001753582694338, -0.6031560129821139, -0.6018961166041308, -0.6025191471653332, -0.603590071477673, -0.6025097737779576, -0.6014165899018333, -0.6016387211168146, -0.6019952498191357, -0.6024692800626403, -0.6022115910883552, -0.6022341745850842]
# Generation 0
# Max fitness value -0.6000339534116581
# Generation 10
# Max fitness value -0.6000339534116581
# Generation 20
# Max fitness value -0.6000339534116581
# Generation 30
# Max fitness value -0.5720502570477346
# Generation 40
# Max fitness value 0.8658901089885693
# Generation 50
# Max fitness value 0.9660513944861476
# Generation 60
# Max fitness value 0.9739481355205984
# Generation 70
# Max fitness value 0.9751338568737761
# Generation 80
# Max fitness value 0.9766764898419904
# Generation 90
# Max fitness value 0.9766764898419904
# Generation 100
# Max fitness value 0.9783571502265
# Generation 110
# Max fitness value 0.9783571502265
# Generation 120
# Max fitness value 0.9786212330584728
# Generation 130
# Max fitness value 0.9786226708517419
# Generation 140
# Max fitness value 0.9786226708517419
# Generation 150
# Max fitness value 0.9786226708517419
# Generation 160
# Max fitness value 0.9786509880738816
# Generation 170
# Max fitness value 0.9786509880738816
# Generation 180
# Max fitness value 0.9786509880738816
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  721.2989172935486  seconds
# Initial fitness:
#  [0.5165694211286859, 0.3302876516305915, 0.5133988027472768, 0.38974152583505584, 0.4631021811382683, 0.5600283612137258, 0.15861044595347074, 0.3028966115645712, 0.33756240046400177, 0.6296198420813912, 0.10329419614015595, 0.33864520732266334, 0.11230610209588739, 0.2844527699025915, 0.3427972772285589, 0.5387308532977123, 0.3961762537314629, 0.3943441476347801, 0.5047946600308892, 0.5549611139254073, 0.515117149936211, 0.41659658341481576, 0.4049427757517076, 0.3632305954359104, 0.3460539195696821, 0.30673910621373524, 0.356367855265297, 0.5084313696464455, 0.1836759612373605, 0.40843179706295496, 0.24819287273308033, 0.5196498950797942, 0.25736434128396113, 0.3243119208619537, 0.32575341163218574, -0.07583329622355889, 0.1697173200895945, 0.4073638455958781, 0.3880867902009114, 0.20563836040530314, 0.2670749665789408, 0.5384243523431603, 0.333551520681334, 0.4089830747869261, 0.4407149158589049, 0.3899950573100559, 0.31769992336409997, 0.09107590042282629, 0.29325503233686007, 0.38205953084880756]
# Generation 0
# Max fitness value 0.8417532396465499
# Generation 10
# Max fitness value 0.9965169944702726
# Generation 20
# Max fitness value 0.9970751162187917
# Generation 30
# Max fitness value 0.9971619366261322
# Generation 40
# Max fitness value 0.9971619366261322
# Generation 50
# Max fitness value 0.9971619366261322
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 7
# Time:  215.20662999153137  seconds
# Initial fitness:
#  [0.6465716617314549, 0.5846812438652178, 0.5730347555723473, 0.6304389162333011, 0.5775430893175588, 0.5402859777058417, 0.5508412985168393, 0.5496974835896422, 0.5424287011983452, 0.31532015238657835, 0.5626808548575737, 0.6562257433658337, 0.5075349776633543, 0.41211411982022655, 0.37791278815989016, 0.5953885284997855, 0.5710611904971492, 0.3986850035111946, 0.4466323954048951, 0.5616956458012216, 0.4833244880168739, 0.5058534667793059, 0.5341085710859024, 0.5278603541033273, 0.5672674732350789, 0.7177966631523651, 0.5576189395846156, 0.4214512503407305, 0.7032011831900337, 0.5090124696312687, 0.4928455980529781, 0.4278673253366125, 0.5592609699533333, 0.5782550594257374, 0.5169348016926104, 0.4803229262312154, 0.5129354549805515, 0.6494222991604504, 0.5545734062328929, 0.5432657566135688, 0.5605043887095877, 0.6385279076022379, 0.5450409305007776, 0.5151308251756961, 0.4709766451095708, 0.6928133381851133, 0.6579092793875067, 0.5832207982161095, 0.48156052761397944, 0.5522116088904601]
# Generation 0
# Max fitness value 0.8024060563259277
# Generation 10
# Max fitness value 0.9933311471218205
# Generation 20
# Max fitness value 0.9933311471218205
# Generation 30
# Max fitness value 0.9933311471218205
# Generation 40
# Max fitness value 0.9933311471218205
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 6
# Time:  161.83442783355713  seconds
# Initial fitness:
#  [-0.5933905945895636, -0.5952078665874815, -0.5914235016736363, -0.5874641802198879, -0.5830002794426357, -0.5903199412567086, -0.5960252311460046, -0.58905673284221, -0.5932604182208063, -0.5936264074926394, -0.5951333889865688, -0.5917994486992346, -0.5945874962744597, -0.582488958573044, -0.5935317709198241, -0.5919264089062697, -0.5917336040105946, -0.5900708535643874, -0.5942446549760493, -0.5888675083098132, -0.5900953721395776, -0.587921732291897, -0.5959158912114053, -0.5913097337388739, -0.5746704608198588, -0.5959997771982909, -0.5907173905068256, -0.5930317760817196, -0.5915420959419465, -0.5911285372669552, -0.594805149359175, -0.5947410528985141, -0.5899335398382921, -0.5807908770928781, -0.5920242979895639, -0.5934030963506145, -0.5836423716699595, -0.5961624740890715, -0.5899294168704814, -0.5967001076805268, -0.591185138534282, -0.5963447486716198, -0.5923826142228588, -0.591535893900956, -0.5796259453678227, -0.594602455979161, -0.5908552571149086, -0.5903054491546196, -0.5935198939770651, -0.5919934415279853]
# Generation 0
# Max fitness value -0.4443020784146499
# Generation 10
# Max fitness value 0.9771570251464249
# Generation 20
# Max fitness value 0.9952020112845023
# Generation 30
# Max fitness value 0.9953452692818253
# Generation 40
# Max fitness value 0.9954819666016056
# Generation 50
# Max fitness value 0.9955690929527722
# Generation 60
# Max fitness value 0.9955690929527722
# Generation 70
# Max fitness value 0.9955690929527722
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 0
# Time:  302.95367217063904  seconds
# Initial fitness:
#  [-0.6000229045417064, -0.6000660160806749, -0.6000144029234367, -0.6000122303921831, -0.6000119115934612, -0.6000444691215128, -0.600146413578228, -0.6001090503569693, -0.6000611968442363, -0.600052009846238, -0.600009896236102, -0.6000698271535796, -0.600022878219318, -0.6000312812907063, -0.6000427703950422, -0.6000201130261562, -0.6000600866497221, -0.6000726302818127, -0.600055496344658, -0.6000905295204801, -0.6000634290609084, -0.60008784281123, -0.600013049609671, -0.6000525611323911, -0.6000577729490141, -0.6000539533026958, -0.600051946463118, -0.600117655008004, -0.6000757382804786, -0.6000211367076517, -0.6000136736831848, -0.600079503420222, -0.6000825659285167, -0.6000692846255964, -0.6000180843286863, -0.6000395178785551, -0.6000190212180716, -0.6000980788017745, -0.6000788108691282, -0.600044002843701, -0.6001048905028806, -0.6000566906337501, -0.6000129148613116, -0.6000947294398915, -0.6000809602959587, -0.6000645295870052, -0.6000407678793804, -0.6000170591884183, -0.6000279200397394, -0.6000392251572141]
# Generation 0
# Max fitness value -0.6000077764815274
# Generation 10
# Max fitness value -0.6000077764815274
# Generation 20
# Max fitness value -0.6000077764815274
# Generation 30
# Max fitness value -0.5909153264191839
# Generation 40
# Max fitness value 0.7248837255967232
# Generation 50
# Max fitness value 0.9723190856013353
# Generation 60
# Max fitness value 0.9946971448849375
# Generation 70
# Max fitness value 0.9965035629324278
# Generation 80
# Max fitness value 0.9968450498108449
# Generation 90
# Max fitness value 0.9968896035729906
# Generation 100
# Max fitness value 0.9971181082117384
# Generation 110
# Max fitness value 0.9972316343122288
# Generation 120
# Max fitness value 0.9973444858291152
# Generation 130
# Max fitness value 0.9974630380550056
# Generation 140
# Max fitness value 0.9974630380550056
# Generation 150
# Max fitness value 0.9974630380550056
# Generation 160
# Max fitness value 0.9974693984311105
# Generation 170
# Max fitness value 0.9975161163617392
# Generation 180
# Max fitness value 0.9975361360060955
# Generation 190
# Max fitness value 0.9975896663024428
# Generation 200
# Max fitness value 0.9975896663024428
# Generation 210
# Max fitness value 0.9976236813518758
# Generation 220
# Max fitness value 0.9976236813518758
# Generation 230
# Max fitness value 0.9976236813518758
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  1154.9317727088928  seconds
# Initial fitness:
#  [-0.6012949884692849, -0.6007857110847508, -0.6008497944190354, -0.6007959904502357, -0.6000764994423566, -0.6001874634213036, -0.6024661581521783, -0.6006519448436601, -0.600014508408637, -0.6003646532681304, -0.6001233598951122, -0.6000969613868736, -0.6002045102126148, -0.6001414965530298, -0.6005442423291423, -0.6003488787588354, -0.6004343010220059, -0.6003132927682467, -0.6002435538406107, -0.6010735555946036, -0.6002635941658477, -0.6005107675933234, -0.6004257894949104, -0.6000214743376451, -0.6030634465249874, -0.6022904518316405, -0.6007098874824917, -0.6001253146673825, -0.6000150302634008, -0.6004078212385624, -0.6001153660802282, -0.6003375055046475, -0.6013607709191477, -0.6007991547204675, -0.6000261910068686, -0.6002084728113088, -0.6012904963144189, -0.6001702011153746, -0.6003701342579938, -0.6003686575224467, -0.6001958376930185, -0.6000948075777164, -0.6012133190886871, -0.6015864106821545, -0.6001940622484357, -0.6000380920594018, -0.6001446111427888, -0.6021909852597906, -0.6001756227123332, -0.6024943248187821]
# Generation 0
# Max fitness value -0.600014508408637
# Generation 10
# Max fitness value 0.45301382045210475
# Generation 20
# Max fitness value 0.9926218985935256
# Generation 30
# Max fitness value 0.9941701617156319
# Generation 40
# Max fitness value 0.9947312557126531
# Generation 50
# Max fitness value 0.9947765499345883
# Generation 60
# Max fitness value 0.9947765499345883
# Generation 70
# Max fitness value 0.9948853859626867
# Generation 80
# Max fitness value 0.9950349701159308
# Generation 90
# Max fitness value 0.9950349701159308
# Generation 100
# Max fitness value 0.9950349701159308
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 0
# Time:  534.7154169082642  seconds
# Initial fitness:
#  [-0.6000017299778257, -0.600009614807856, -0.6000559079977198, -0.6000102260509256, -0.6000631727112966, -0.6000573012588437, -0.6000720606819867, -0.6000712706302445, -0.600067173244182, -0.60001024027109, -0.6000309522617082, -0.6000495358997923, -0.6000399027432375, -0.6000686328968046, -0.6000448930936028, -0.6001367476824362, -0.6000603009837611, -0.6000415937970871, -0.6000490949165624, -0.6000525389164129, -0.6001513913183711, -0.6000950168026875, -0.6000707069458077, -0.6000545251474652, -0.6000730102436029, -0.6000496003408637, -0.6000648160922655, -0.6000439970072614, -0.6000232019208536, -0.6000738299211618, -0.6000137594403009, -0.6000611385236281, -0.6000515143675369, -0.60002523818075, -0.6000264714769583, -0.6000797071603936, -0.6000769138686552, -0.6000938698261571, -0.6000664895240756, -0.6000252165286343, -0.6001394396321029, -0.6000357127120517, -0.6000509411429928, -0.6000562916558172, -0.6001072005175346, -0.6000469786243883, -0.6000351910244955, -0.6000549856416899, -0.600043476206684, -0.60010178517189]
# Generation 0
# Max fitness value -0.6000017299778257
# Generation 10
# Max fitness value -0.6000017299778257
# Generation 20
# Max fitness value -0.6000017299778257
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  157.5524561405182  seconds
# Initial fitness:
#  [-0.5992643934330454, -0.5983169408641994, -0.599982867004575, -0.6001872018358112, -0.599363131031633, -0.6000810629843338, -0.600222297783397, -0.5995452590934873, -0.599352322217564, -0.5994012270356224, -0.5977761297390062, -0.5995578673451063, -0.599431186027105, -0.5994058758286758, -0.5999831498805179, -0.5995330654600035, -0.5997689963795014, -0.6004959627820623, -0.6000192474241849, -0.5994853590842438, -0.5995083065278164, -0.5996721588829599, -0.5994277722865061, -0.5996870075621419, -0.5996536589976563, -0.5992543374992524, -0.599565114557206, -0.599460469600308, -0.5996894886461193, -0.600282027477914, -0.599701619533579, -0.5995269180700115, -0.5996968396155548, -0.5994890384763023, -0.5990598091378807, -0.599823592093783, -0.5995999135929593, -0.5998116183136522, -0.599764171563201, -0.5994763108633435, -0.5995809280234338, -0.5995280052143903, -0.59955029662078, -0.5995570013524996, -0.5991967569678479, -0.5997526257615153, -0.5998788563228453, -0.5997605103641602, -0.5996525278549256, -0.6000489315442545]
# Generation 0
# Max fitness value -0.5941490351813259
# Generation 10
# Max fitness value 0.7704645801710417
# Generation 20
# Max fitness value 0.9937976249467535
# Generation 30
# Max fitness value 0.9953447478160492
# Generation 40
# Max fitness value 0.9953447478160492
# Generation 50
# Max fitness value 0.9954202184574965
# Generation 60
# Max fitness value 0.9954202184574965
# Generation 70
# Max fitness value 0.9954202184574965
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  386.38267159461975  seconds
# Initial fitness:
#  [-0.6000921694101926, -0.6004750463867566, -0.6001625904357881, -0.6000695326345662, -0.6000668336802639, -0.6000829515899126, -0.600035706737515, -0.6003006169906211, -0.6000344593483428, -0.6005666708656368, -0.6002564071130079, -0.600510949322689, -0.6002456771634913, -0.6000648298161806, -0.6003615229318329, -0.6001289617028915, -0.6001295672852689, -0.6001158802285697, -0.6001987117134926, -0.6002349684485042, -0.6001843729287076, -0.6002199714884173, -0.6000412965295321, -0.6001182366574672, -0.6000045157374579, -0.6002001359041668, -0.6000862850449169, -0.6000606825951242, -0.6002054921802863, -0.6001751627492323, -0.6002710711985846, -0.6000902923133207, -0.600031638036289, -0.6001181129490726, -0.6000591499017873, -0.6001047984746827, -0.6003623730606996, -0.6003875846370967, -0.6001131617215864, -0.6002533300703173, -0.6003096767047429, -0.6001229538516841, -0.6001097147484337, -0.6001894841366755, -0.6000853100056557, -0.6000444868031776, -0.6000524371563735, -0.6000982176402654, -0.6001858663036457, -0.6000942686404794]
# Generation 0
# Max fitness value -0.6000045157374579
# Generation 10
# Max fitness value -0.6000045157374579
# Generation 20
# Max fitness value -0.6000045157374579
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  157.73104453086853  seconds
# Initial fitness:
#  [-0.6002896840177208, -0.6000355751369335, -0.6003339539047441, -0.600409402531813, -0.6004023168234066, -0.6001056172455567, -0.6001163026232604, -0.6002636812056021, -0.6002746623884516, -0.6000775138311182, -0.6004052307657541, -0.6001371194005958, -0.6001354359494877, -0.6000111619902012, -0.600195167570178, -0.6001210539448906, -0.6002530257601519, -0.600017274566158, -0.6002478986323192, -0.6002935928669744, -0.6001155338302554, -0.6000920703731187, -0.6001401042323938, -0.6003168885796347, -0.6000885174990869, -0.6004810972315673, -0.6006478968189233, -0.6002375027985054, -0.6002610845534571, -0.6002994995795106, -0.6000763813536939, -0.6003887698491263, -0.6002441203711957, -0.6001205849650842, -0.6002784543444166, -0.6001041588838102, -0.6000823089907172, -0.6002977641407166, -0.6001763785305945, -0.6000407972438753, -0.6000455748766587, -0.6003001033729669, -0.6000070328688988, -0.6000443756173972, -0.6001410203705293, -0.6001819963425457, -0.6002027815801853, -0.6002448570279294, -0.6001354265013993, -0.6003007838240034]
# Generation 0
# Max fitness value -0.6000070328688988
# Generation 10
# Max fitness value -0.6000070328688988
# Generation 20
# Max fitness value -0.6000070328688988
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  158.0890383720398  seconds
# Initial fitness:
#  [-0.593545818212919, -0.5921498063534301, -0.5875870651984143, -0.5915494679546565, -0.5925315211775316, -0.5917414052979584, -0.5935299735483908, -0.592928936277468, -0.5897679697901507, -0.591415262361897, -0.578457317583678, -0.5929909194435183, -0.5962770830788452, -0.5932437751739337, -0.5935917763037482, -0.5908914121158814, -0.5919500384803796, -0.5932691866267492, -0.5868045822277583, -0.5911956691158542, -0.5887957580345118, -0.5931528329405162, -0.5894589097846025, -0.5886441991367873, -0.5929739865900632, -0.5923547300741758, -0.5941656876851513, -0.5919085124464456, -0.5898947260554932, -0.5880289069009943, -0.5911654361585053, -0.5922518638805665, -0.5939704156934431, -0.5885902166947063, -0.591693353065146, -0.5871158028551955, -0.5915359221071272, -0.5937376734079387, -0.5955365820745423, -0.5934448073578981, -0.5888059870910569, -0.5936737101276957, -0.5919933834853257, -0.5929208134302478, -0.5922303028850529, -0.5924158724648307, -0.5849091915263727, -0.5901199571563968, -0.5927695466559352, -0.5943345869152504]
# Generation 0
# Max fitness value -0.5388131207711906
# Generation 10
# Max fitness value 0.786250478846403
# Generation 20
# Max fitness value 0.9825195295942509
# Generation 30
# Max fitness value 0.9924393882158462
# Generation 40
# Max fitness value 0.9934427874995346
# Generation 50
# Max fitness value 0.9935373977940072
# Generation 60
# Max fitness value 0.9939859852879881
# Generation 70
# Max fitness value 0.9942606009489035
# Generation 80
# Max fitness value 0.994360746746857
# Generation 90
# Max fitness value 0.994360746746857
# Generation 100
# Max fitness value 0.9945070450506059
# Generation 110
# Max fitness value 0.9947931934720529
# Generation 120
# Max fitness value 0.9948480723043841
# Generation 130
# Max fitness value 0.9948480723043841
# Generation 140
# Max fitness value 0.9948537455768224
# Generation 150
# Max fitness value 0.9948657004643505
# Generation 160
# Max fitness value 0.9949343197284825
# Generation 170
# Max fitness value 0.9949343197284825
# Generation 180
# Max fitness value 0.9949343197284825
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 2
# predicted label: 3
# Time:  956.2080209255219  seconds
# Initial fitness:
#  [0.5054196156412969, 0.5497599283427186, 0.801128740762687, 0.48730182889214657, 0.5524103337599339, 0.621375429419831, 0.5934431254619225, 0.577387893085527, 0.6116028906092574, 0.6258555133845158, 0.7267380515692803, 0.7207282588339623, 0.7046884689395063, 0.5913030371144057, 0.6994212439856801, 0.45936835167981316, 0.49941018547306176, 0.3827686746867587, 0.5614233117106036, 0.6957606185734655, 0.672228486280148, 0.567700054784379, 0.834698812003224, 0.7110443540214904, 0.6635932632558001, 0.5903348220724832, 0.6164502145083383, 0.7773400434562268, 0.5860504671533486, 0.8048928096722683, 0.26017099364176743, 0.7367769707756214, 0.6277788045124995, 0.5294426419652296, 0.6927487241691475, 0.7547644939871384, 0.6297614180541268, 0.7108370531084692, 0.5392072756775126, 0.6094380858877757, 0.6856828959252079, 0.6719719838458416, 0.7869170855913903, 0.6990366751800048, 0.706756647211541, 0.5099488936086677, 0.6239706684873872, 0.46370765102891787, 0.5131697649191197, 0.7248590141012339]
# Generation 0
# Max fitness value 0.9087396792339448
# Generation 10
# Max fitness value 0.9953744694128338
# Generation 20
# Max fitness value 0.9957060000114482
# Generation 30
# Max fitness value 0.9958159865356172
# Generation 40
# Max fitness value 0.9958159865356172
# Generation 50
# Max fitness value 0.9958159865356172
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 2
# predicted label: 6
# Time:  300.5149943828583  seconds
# Initial fitness:
#  [-0.3948362268129712, -0.32074890376959775, -0.22380874158070205, -0.16115034867316363, -0.2474140854492256, -0.27177593831860736, -0.22623096783204255, -0.18321583174554917, -0.2159369491075177, -0.2980537771586223, -0.09883097261444956, -0.22655483963444947, -0.10854652722817326, -0.1588746845533759, -0.2975625247026691, -0.05614440716528987, -0.2255297525750365, -0.127237134075614, -0.4421078818321996, -0.2089284454735138, 0.2568377282109403, -0.25813299037857074, -0.2204792792953581, -0.2908864955342054, -0.28324052038273884, -0.27660611862504214, -0.15095325868352716, -0.2091216370459733, -0.11051757316394747, -0.2056730938409151, -0.10596696020628968, -0.13622524149045348, -0.165142069936708, -0.039106658672928646, -0.3036138430118156, 0.045178058090554335, -0.35734684476745227, -0.23058782744580997, -0.32048246536107405, -0.162169195536578, -0.0818223943804739, -0.26734872712010704, -0.2698089427663519, -0.23666966063555114, -0.33366761186965455, -0.15313540349085564, -0.10040138233735824, -0.2189311933875425, 0.09178022056335458, 0.014632255502185304]
# Generation 0
# Max fitness value 0.6419892117807001
# Generation 10
# Max fitness value 0.9928376739013768
# Generation 20
# Max fitness value 0.9934570672839769
# Generation 30
# Max fitness value 0.9934570672839769
# Generation 40
# Max fitness value 0.9934570672839769
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 2
# predicted label: 6
# Time:  231.25514936447144  seconds
# Initial fitness:
# ...
# Generation 20
# Max fitness value -0.5999995648120373
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 9
# Time:  90.42949485778809  seconds
# Initial fitness:
#  [-0.42758776295927076, -0.46806199056964914, -0.4485073835773029, -0.45892841913559146, -0.5096637479305923, -0.5029558071448414, -0.48061834365528294, -0.40714053348220214, -0.4684452752200764, -0.5007166626643076, -0.5353058477775845, -0.4822713470656916, -0.4764817037244507, -0.4656692006665255, -0.4683189880725509, -0.5038762017529365, -0.4851127577941078, -0.4736405459380381, -0.4752952425868844, -0.5175930426226538, -0.469246132311898, -0.5033269713255388, -0.551575405658718, -0.4884000039837081, -0.5150910890185902, -0.4643026904593688, -0.5056061899512452, -0.4723453402811887, -0.4130286272764139, -0.45077441548511155, -0.4808835779581603, -0.41195895592855614, -0.48592499975652315, -0.4716635269253562, -0.42860328788415697, -0.4680856254379128, -0.49929085816600066, -0.48902427844001056, -0.47722143087943303, -0.5215145151423299, -0.4677979706567372, -0.4635351962695381, -0.5269561909010373, -0.4758708397005442, -0.4649807993795626, -0.43204468893326753, -0.443168038356604, -0.4886703839656432, -0.49189964119856366, -0.39120899928451813]
# Generation 0
# Max fitness value -0.2119284532470032
# Generation 10
# Max fitness value 0.9621697411085661
# Generation 20
# Max fitness value 0.9905957196520846
# Generation 30
# Max fitness value 0.9914761515674986
# Generation 40
# Max fitness value 0.9920474643582287
# Generation 50
# Max fitness value 0.992879511516237
# Generation 60
# Max fitness value 0.9930999340479498
# Generation 70
# Max fitness value 0.9932349216290025
# Generation 80
# Max fitness value 0.9934811987336559
# Generation 90
# Max fitness value 0.9934811987336559
# Generation 100
# Max fitness value 0.9935110372220745
# Generation 110
# Max fitness value 0.9935110372220745
# Generation 120
# Max fitness value 0.9936162776842581
# Generation 130
# Max fitness value 0.9936467113258071
# Generation 140
# Max fitness value 0.9936467113258071
# Generation 150
# Max fitness value 0.9936467113258071
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  462.854620218277  seconds
# Initial fitness:
#  [-0.5998886436477807, -0.6000049041886288, -0.5998668851777136, -0.5998932729598995, -0.5997455608505131, -0.599919070616816, -0.5998755208786162, -0.5998154235029949, -0.600089375034731, -0.5997301609667791, -0.5998488140665511, -0.599783069655864, -0.5999415839603579, -0.5997337612281745, -0.6001499515066165, -0.5997580367808214, -0.5998275804978556, -0.5997881497150304, -0.5998133775600114, -0.5998755927845044, -0.5998480817321958, -0.5999268929459594, -0.5999731460028912, -0.5998650522259019, -0.5997820936059868, -0.5999241940194057, -0.5999121903574058, -0.5998453225872891, -0.5998413317354637, -0.5999685538268632, -0.5997758506687876, -0.5998680601556501, -0.5999930303784808, -0.5998189655040428, -0.5997903423211117, -0.5998652544275898, -0.5998834604372493, -0.5997958050094817, -0.599839373095156, -0.59979361988611, -0.5998872323451268, -0.599773466356492, -0.5998084457238169, -0.5999122401276498, -0.599836674184534, -0.5998548618774422, -0.6000247976339066, -0.5998343786438456, -0.5998319732769561, -0.6001127918142493]
# Generation 0
# Max fitness value -0.5996747914996874
# Generation 10
# Max fitness value -0.40734803896694427
# Generation 20
# Max fitness value 0.8805097176079355
# Generation 30
# Max fitness value 0.9916238637557474
# Generation 40
# Max fitness value 0.9945410410195048
# Generation 50
# Max fitness value 0.9947269392828869
# Generation 60
# Max fitness value 0.9947269392828869
# Generation 70
# Max fitness value 0.9947933931235917
# Generation 80
# Max fitness value 0.994830279035491
# Generation 90
# Max fitness value 0.9949503205378785
# Generation 100
# Max fitness value 0.9950176989885164
# Generation 110
# Max fitness value 0.995117411444457
# Generation 120
# Max fitness value 0.9951273748567083
# Generation 130
# Max fitness value 0.9951273748567083
# Generation 140
# Max fitness value 0.9951273748567083
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  425.4431903362274  seconds
# Initial fitness:
#  [-0.5588124577244228, -0.5238628536130399, -0.5255909534794689, -0.5314211436594997, -0.4832700604051804, -0.5006717561406839, -0.520442796554671, -0.5204750702792649, -0.5323489201760632, -0.5086048002007342, -0.49919845263040885, -0.5351053862939369, -0.5219217045908545, -0.537571043953063, -0.5252729937313027, -0.5321502015757201, -0.490028044500532, -0.5222181872494013, -0.5086454884916087, -0.4881822548248021, -0.5198600502268366, -0.5226993030844088, -0.48485153083612575, -0.5149945057434383, -0.531828388111719, -0.5139382607087685, -0.5097581995317616, -0.5266428263682066, -0.5172326189998749, -0.5447552614162664, -0.522175546947199, -0.5392599791004493, -0.5114530273181583, -0.542010530925398, -0.5180640022413462, -0.4977171961997249, -0.506190430846271, -0.5306136160835675, -0.5198144152710703, -0.5228805996651994, -0.5105435418377675, -0.511929503424474, -0.5095003514952903, -0.5107488557234852, -0.5223822531496507, -0.5297004662455016, -0.514249981262676, -0.5461942378403444, -0.5032480411313837, -0.5296287339362601]
# Generation 0
# Max fitness value -0.4480318890531559
# Generation 10
# Max fitness value 0.7608954385862693
# Generation 20
# Max fitness value 0.9886565458586432
# Generation 30
# Max fitness value 0.9943438491403024
# Generation 40
# Max fitness value 0.9946647237196764
# Generation 50
# Max fitness value 0.9949806953353513
# Generation 60
# Max fitness value 0.9950956921933144
# Generation 70
# Max fitness value 0.9952602533647597
# Generation 80
# Max fitness value 0.9953430618776726
# Generation 90
# Max fitness value 0.9955120724572215
# Generation 100
# Max fitness value 0.9956040275190527
# Generation 110
# Max fitness value 0.9956645783437614
# Generation 120
# Max fitness value 0.9956645783437614
# Generation 130
# Max fitness value 0.9957821459906131
# Generation 140
# Max fitness value 0.9958168829655547
# Generation 150
# Max fitness value 0.9958228472279242
# Generation 160
# Max fitness value 0.9959750452526904
# Generation 170
# Max fitness value 0.9961458261656537
# Generation 180
# Max fitness value 0.9961458261656537
# Generation 190
# Max fitness value 0.9961570702467402
# Generation 200
# Max fitness value 0.9961570702467402
# Generation 210
# Max fitness value 0.9961570702467402
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 2
# Time:  653.0496373176575  seconds
# Initial fitness:
#  [-0.5958469798384676, -0.59201532385247, -0.5983974310998919, -0.5968461751280895, -0.5961683689468729, -0.5982459871535368, -0.5931739463176959, -0.5976245804124458, -0.5984497648617243, -0.5987553099646608, -0.5953905508041086, -0.5985685689309912, -0.5982383527247006, -0.5971133931596115, -0.5969807807336613, -0.597840144481157, -0.5958621441421676, -0.596630409764759, -0.5984169237694454, -0.5990261310761233, -0.5963923208978493, -0.5993452551571772, -0.5975910246848226, -0.5978880006720417, -0.5986913232054754, -0.5991392018593773, -0.5972675777501066, -0.599250076078705, -0.5989902251139027, -0.599280547775285, -0.5975020370991219, -0.5986136925437237, -0.598899183143458, -0.5982331229074871, -0.5986486819555864, -0.598899928579864, -0.5981221633450959, -0.5985302426851491, -0.5973557748700323, -0.5982319939796822, -0.5989100042806538, -0.5993137355206097, -0.5981511673672246, -0.5981332623501152, -0.5983223922146237, -0.597840484556789, -0.5985897746512095, -0.5963491746106995, -0.5980508673427899, -0.586510271599476]
# Generation 0
# Max fitness value -0.5669291447755207
# Generation 10
# Max fitness value 0.8205007253414216
# Generation 20
# Max fitness value 0.992462399947813
# Generation 30
# Max fitness value 0.9933472373402534
# Generation 40
# Max fitness value 0.9937741623781717
# Generation 50
# Max fitness value 0.9938855784502563
# Generation 60
# Max fitness value 0.9940102498821061
# Generation 70
# Max fitness value 0.9941891504864464
# Generation 80
# Max fitness value 0.9943738944169642
# Generation 90
# Max fitness value 0.9944748281407357
# Generation 100
# Max fitness value 0.994549743681607
# Generation 110
# Max fitness value 0.994615931084897
# Generation 120
# Max fitness value 0.9947001204901078
# Generation 130
# Max fitness value 0.9947535079200717
# Generation 140
# Max fitness value 0.9947535079200717
# Generation 150
# Max fitness value 0.9948031081057236
# Generation 160
# Max fitness value 0.9948031081057236
# Generation 170
# Max fitness value 0.9948031081057236
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  520.1106865406036  seconds
# Initial fitness:
#  [0.16354423056978, 0.27341566316334875, 0.18002557466239982, 0.11583417089850294, 0.3391221196615226, 0.2508978039640076, 0.12961182320462827, 0.34564673409176694, 0.059835990423714625, 0.16187031585642753, 0.15493641908453765, 0.19436577737030641, 0.21458430986848748, -0.14134453210784648, 0.18821793780029686, 0.26486066055750807, 0.1954007000570976, 0.3708582711555245, 0.1854914189026222, -0.027367897145966075, 0.1427381329690493, 0.08385274433212833, 0.051148528952317585, -0.09904750308431587, 0.13713999138708344, 0.30798202103980243, 0.10429865447961563, 0.2663395498821807, -0.003934756107808579, 0.07141078807238041, 0.11118274463792703, -0.07176767912997295, 0.25464298885198045, 0.08826503288211374, 0.11604374672074329, 0.03592042331034312, 0.1906591532838008, 0.28843826689019875, 0.09780664811574274, -0.09533327357120089, 0.23315356089501602, -0.08197289587459558, -0.014669156611349071, 0.17027911928281758, 0.2984742230312916, 0.13670188383883689, -0.05186573832101268, 0.07850121207344897, 0.13136615656374406, 0.12473193107131958]
# FOUND ADVERSARIAL
# Fitness of the adversarial 0.3708582711555245
# Generation 0
# Max fitness value 0.5854816894787451
# Generation 10
# Max fitness value 0.9680487026176179
# Generation 20
# Max fitness value 0.9959033739524371
# Generation 30
# Max fitness value 0.996333746707731
# Generation 40
# Max fitness value 0.9965145180572036
# Generation 50
# Max fitness value 0.9965145180572036
# Generation 60
# Max fitness value 0.9965145180572036
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 7
# Time:  204.6617395877838  seconds
# Initial fitness:
#  [-0.600988856601975, -0.6005818741738758, -0.6003206378508215, -0.600300743277074, -0.602281061452511, -0.6016128562271555, -0.6004640095999343, -0.6004917764333052, -0.6001204931715896, -0.6002467420208288, -0.6020618694803055, -0.6006913703430591, -0.6005642512790847, -0.5999330601251717, -0.6022880780960675, -0.600079745626582, -0.6003092914358936, -0.600397733705286, -0.5999023557037092, -0.6006339179177347, -0.600391221774156, -0.6001042234820646, -0.6001774111651046, -0.6006505609873689, -0.6000668012020847, -0.6002906967500723, -0.6002430873548366, -0.6007780722066441, -0.6003386876559471, -0.6002027551130178, -0.6002978201767021, -0.6016858007787511, -0.6003598153112083, -0.6002057063643012, -0.6000692441110616, -0.6004193909756653, -0.6000329079843154, -0.6001335227627912, -0.5999839076679327, -0.6027280511233455, -0.6008631243985134, -0.6011256579599086, -0.6001895340835729, -0.6005322588877426, -0.600248115571544, -0.600331785488824, -0.6002772447766457, -0.6003704319260007, -0.6008804908480064, -0.6019351025310212]
# Generation 0
# Max fitness value -0.5993563621190736
# Generation 10
# Max fitness value 0.6552083630648396
# Generation 20
# Max fitness value 0.972466335734804
# Generation 30
# Max fitness value 0.9873122345312257
# Generation 40
# Max fitness value 0.988056775716645
# Generation 50
# Max fitness value 0.9881198196753699
# Generation 60
# Max fitness value 0.9881198196753699
# Generation 70
# Max fitness value 0.9881198196753699
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  228.50080466270447  seconds
# Initial fitness:
#  [-0.600003412290613, -0.6002304164440875, -0.6000809461371969, -0.6000963676881534, -0.6001126698919879, -0.6004036458204501, -0.6000455251575152, -0.6001919265104297, -0.6003669172278729, -0.6001038742465861, -0.6000972660548785, -0.600061246556253, -0.600265771068152, -0.6006159987426698, -0.6003467796347575, -0.6000956616580106, -0.6000029409466563, -0.6000568660763596, -0.6002324427047783, -0.6003266657563694, -0.6002320193013883, -0.6000056996569785, -0.6001364702719921, -0.6001671075516067, -0.6000533851389567, -0.6002985191391187, -0.6001993941059212, -0.6004430279320077, -0.6001241095439289, -0.6001089100290862, -0.6004536639020474, -0.6002005737353043, -0.6002034827257345, -0.6007244549443372, -0.6001275758440028, -0.6000313282036936, -0.6000062090086409, -0.6000434090575593, -0.6000401260392908, -0.6000830540155918, -0.6000731696916808, -0.6000089321213915, -0.6001420154613257, -0.6003786207196965, -0.6005599185106689, -0.6000317444018267, -0.600102955758242, -0.6001088824501217, -0.6000738500026186, -0.6000468998088926]
# Generation 0
# Max fitness value -0.6000029409466563
# Generation 10
# Max fitness value -0.6000029409466563
# Generation 20
# Max fitness value -0.5727378717166474
# Generation 30
# Max fitness value 0.949552043635431
# Generation 40
# Max fitness value 0.9930178622993282
# Generation 50
# Max fitness value 0.9937822314871543
# Generation 60
# Max fitness value 0.9938993939174042
# Generation 70
# Max fitness value 0.9942937175154547
# Generation 80
# Max fitness value 0.9943496132023332
# Generation 90
# Max fitness value 0.9944739925746506
# Generation 100
# Max fitness value 0.9945924439835161
# Generation 110
# Max fitness value 0.9948127904689776
# Generation 120
# Max fitness value 0.9948847932383156
# Generation 130
# Max fitness value 0.9948847932383156
# Generation 140
# Max fitness value 0.9948847932383156
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 6
# Time:  433.55608224868774  seconds
# Initial fitness:
#  [0.1990269147376369, 0.18663870900003984, 0.43275978106372603, 0.39705920244965287, 0.3675143282503018, 0.35975823205621554, 0.4129346638304363, 0.2941121196487152, 0.3783203826542061, 0.4493902936905759, 0.5395966944960185, 0.28307549921708497, 0.3224669871536796, 0.3757617126436831, 0.150207208392526, 0.3625812607963671, 0.1825506082159115, 0.4194569590999535, 0.3410062883651214, 0.39083690807649807, 0.31719074517242357, 0.2930141592702557, 0.2658908666965746, 0.5675957450674917, 0.4113269326126209, 0.4002549976034455, 0.42265417211411654, 0.29577919067106506, 0.4853470108653815, 0.42605623028158546, 0.43584952579270164, 0.3906414039742608, 0.39334737708887335, 0.5783424552377306, 0.3852181486475563, 0.11544341279885034, 0.20354011306894992, 0.37817036285192984, 0.13056170730166522, 0.2386897876070929, 0.490099562467035, 0.35313338946454703, 0.34627210509245443, 0.2162821477525244, 0.2995963476778452, 0.27205169993202855, 0.39209943972482936, 0.25302448306927994, 0.5381491842731398, 0.23153831905508745]
# Generation 0
# Max fitness value 0.6306145352743431
# Generation 10
# Max fitness value 0.9915392064490176
# Generation 20
# Max fitness value 0.9958739305521647
# Generation 30
# Max fitness value 0.9963358829776939
# Generation 40
# Max fitness value 0.9966299521662966
# Generation 50
# Max fitness value 0.9966299521662966
# Generation 60
# Max fitness value 0.9966572483765939
# Generation 70
# Max fitness value 0.9966572483765939
# Generation 80
# Max fitness value 0.9966572483765939
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  267.4874222278595  seconds

# %% [markdown]
# # Save files

# %%
import pickle
file_ = open('GA_cifar_ssim_2K_seed1', 'wb')
pickle.dump(evolved_examples, file_)
pickle.dump(times, file_)
pickle.dump(ssim_values, file_)
pickle.dump(fitness_of_evolved , file_)
pickle.dump(predicted_class, file_)
pickle.dump(number_of_rounds, file_)
file_.close()

print(f"Max time: {np.max(times)}")
print(f"Min time: {np.min(times)}")
print(f"Mean time: {np.mean(times)}")
print(f"Std time: {np.std(times)}\n")

print(f"Max fitness evolved: {np.max(fitness_of_evolved)}")
print(f"Min fitness evolved:: {np.min(fitness_of_evolved)}")
print(f"Mean fitness evolved: {np.mean(fitness_of_evolved)}")
print(f"Std fitness evolved:: {np.std(fitness_of_evolved)}\n")

print(f"Max ssim: {np.max(ssim_values)}")
print(f"Min ssim: {np.min(ssim_values)}")
print(f"Mean ssim: {np.mean(ssim_values)}")
print(f"Std ssim: {np.std(ssim_values)}\n")

print(f"Max round: {np.max(number_of_rounds)}")
print(f"Min rounds: {np.min(number_of_rounds)}")
print(f"Mean rounds: {np.mean(number_of_rounds)}")
print(f"Std rounds: {np.std(number_of_rounds)}\n")




print(f"Percentage of adversarial founds sucessfully : {numb_of_adv_found/len(adversarial_y)} %")
print(f"Percentage of adversarial founds after fitness not improving for 30 generations: {numb_of_found_after30/len(adversarial_y)} %")
# Out:
# Max time: 2012.1440184116364
# Min time: 4.397225379943848
# Mean time: 405.5270040232436
# Std time: 267.3346625842816
#
# Max fitness evolved: 0.9983826874210932
# Min fitness evolved:: -0.6040776435124633
# Mean fitness evolved: 0.8905611478002908
# Std fitness evolved:: 0.3794180576880395
#
# Max ssim: 0.32026436400866265
# Min ssim: 6.850831352211983e-07
# Mean ssim: 0.04174032844434388
# Std ssim: 0.044636766382348696
#
# Max round: 415
# Min rounds: 0
# Mean rounds: 98.96992481203007
# Std rounds: 62.61289831442634
#
# Percentage of adversarial founds sucessfully : 0.022556390977443608 %
# Percentage of adversarial founds after fitness not improving for 30 generations: 0.9774436090225563 %

# %% [markdown]
# Open adversarial

# %%
with open('GA_cifar_ssim_2K_seed1', 'rb') as f:
    evolved_examples = pickle.load(f)
    times= pickle.load(f)
    ssim_values = pickle.load(f)
    fitness_of_evolved = pickle.load(f)
    predicted_class = pickle.load(f)
    number_of_rounds = pickle.load(f)

# %%
#Correction of ssim values
new_ssim=[]
for s in ssim_values:
    new_ssim.append(1-s)
    
print(f"Max ssim: {np.max(new_ssim)}")
print(f"Min ssim: {np.min(new_ssim)}")
print(f"Mean ssim: {np.mean(new_ssim)}")
print(f"Std ssim: {np.std(new_ssim)}\n")
# Out:
# Max ssim: 0.9999993149168648
# Min ssim: 0.6797356359913374
# Mean ssim: 0.9582596715556562
# Std ssim: 0.044636766382348696

# %%
#Correctionf of rounds  (replacing 0 with 1)
number_of_rounds = np.where(np.array(number_of_rounds)==0, 1, number_of_rounds) 
number_of_rounds
# Out:
# array([ 95,  64,  60,  68,  56,  49, 187, 103,  96,  45,  99,  50,  75,
#         67,  60, 183,  52,  41,  78, 238, 102,  30,  74,  30,  30, 182,
#         57,  44,  59, 115,  50,  71,  81, 132, 146,  48,  30,  30,  98,
#         41,  55, 151, 415,  65,  52, 172,  50,  91,  56, 234,  70,  52,
#        193,  70,  69, 103,  43,  55,  66,   1,  90, 101,  46, 101,  58,
#         40,  55, 163,  64, 210,  62,  73, 145,   1, 111, 101,  84, 270,
#          1,  57,  30,  73,  51, 210,  77,  88, 155,  62, 192, 154, 275,
#         91, 151, 148, 124, 189,  77, 151,  97,  57, 113,  47, 116, 154,
#        120, 116, 114,  87,  66, 118, 102, 126,  53, 165,  74,  63,  30,
#        194,  43, 181, 156, 100, 112,  59,  30, 154, 142, 217, 173,  68,
#         76, 144,  89])

# %%
print(f"Max round: {np.max(number_of_rounds)}")
print(f"Min rounds: {np.min(number_of_rounds)}")
print(f"Mean rounds: {np.mean(number_of_rounds)}")
print(f"Std rounds: {np.std(number_of_rounds)}\n")
# Out:
# Max round: 415
# Min rounds: 1
# Mean rounds: 98.99248120300751
# Std rounds: 62.57741025557673

# %% [markdown]
# # Examples of what functions do

# %%
population = init_pop_from_sample(50,adversarial[15],adversarial_y[15][0])
fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),adversarial_y[15][0])
print(fitness)
# Out:
# [-0.798589499374908, -0.7988727559763226, -0.7984810218297677, -0.7986315342007448, -0.7986279289432717, -0.7985914274374093, -0.798606650507479, -0.7987246207463189, -0.7985943433347527, -0.7988289481653322, -0.7989086883514026, -0.7989558951474792, -0.7984373477803057, -0.7991061355275767, -0.7987120693251201, -0.7986139874771967, -0.7985031437320624, -0.7987608556024536, -0.798926518650104, -0.7984752288638653, -0.7985814046701483, -0.7985062269246829, -0.7987287800995657, -0.7984803588154962, -0.7986875300099113, -0.7984974987554811, -0.7987084484772291, -0.7988023728692697, -0.7986879633194739, -0.7986555380879901, -0.7986410842334577, -0.7987537461170664, -0.7984868833854177, -0.7988325666953346, -0.7984884594055661, -0.7985680843602089, -0.7985962916660284, -0.7985921301381308, -0.798627025243182, -0.7988216631188144, -0.7987493633287841, -0.7987658402674043, -0.7987592042602855, -0.7986431521489095, -0.7986835423122435, -0.7988001115889775, -0.7987130082092924, -0.7987558063721876, -0.7985623020894022, -0.7985681027133978]

# %%
plt.imshow(population[0].reshape(CIFAR_IMG,CIFAR_IMG))
plt.show()
print(f"Class for this {adversarial_y[15][0]}")
print(model.predict(population[0].reshape(1,CIFAR_IMG,CIFAR_IMG,1) /255.0))
# Out:
# Class for this 1
# [[2.5462141e-09 9.9999988e-01 8.3519942e-13 3.9970069e-11 1.2132794e-11
#   2.5392459e-12 1.2059702e-11 1.9484352e-11 2.6762141e-12 1.0691502e-07]]

# %%
parent1 = tournament(population, model, adversarial[15], adversarial_y[15]) 
parent2 = tournament(population, model, adversarial[15], adversarial_y[15])

# %%
fd, idx =  plt.subplots(1,2)
idx[0].imshow(parent1.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")
idx[1].imshow(parent2.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")

# %%
child1, child2 = multi_crossover(parent1, parent2,adversarial[15]) # crossover 
#child1, child2 = add_noise(child1), add_noise(child2) # apply mutation to pixels

# %%
fd, idx =  plt.subplots(1,2)
idx[0].imshow(child1.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")
idx[1].imshow(child2.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")

# %%
print(f"diff between children {np.unique(child1-child2)}")
print(f"diff between parents {np.unique(parent1-parent2)}")
print(f"diff between p1 and c1 {np.unique(parent1-child1)}")
print(f"diff between p1 and c2 {np.unique(parent1-child2)}")
print(f"diff between p2 and c1 {np.unique(parent2-child1)}")
print(f"diff between p2 and c2 {np.unique(parent2-child2)}")
# Out:
# diff between children [-8.56735992 -7.78720093 -7.38879395 -6.20487213 -4.79821777  0.
#   5.9879303   6.45558167  6.62472534]
# diff between parents [-13.0349884   -6.62472534  -6.45558167  -5.9879303   -3.91404724
#    0.           0.69035339   2.00694275   2.51696777   3.21684265
#    4.79821777   6.20487213   7.38879395   7.78720093   8.19781494
#    8.56735992   9.47076416]
# diff between p1 and c1 [-6.62472534 -6.45558167 -5.9879303   0.          2.00694275  2.51696777
#   3.21684265  4.79821777  6.20487213  7.38879395  7.78720093  8.56735992]
# diff between p1 and c2 [0.         2.00694275 2.51696777 3.21684265]
# diff between p2 and c1 [-9.47076416 -8.19781494 -0.69035339  0.          3.91404724 13.0349884 ]
# diff between p2 and c2 [-9.47076416 -8.56735992 -8.19781494 -7.78720093 -7.38879395 -6.20487213
#  -4.79821777 -0.69035339  0.          3.91404724  5.9879303   6.45558167
#   6.62472534 13.0349884 ]

# %%
bb = choose_better_child(child1, child2,adversarial[15],adversarial_y[15][0],model)

# %%
fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label) 
print(fitness)
# Out:
# [0.8014101191553656, 0.801126862553951, 0.8015186920679375, 0.8013681796969603, 0.8013719756892966, 0.8014084771951591, 0.8013932541250893, 0.8012753792536812, 0.8014056566652474, 0.8011707657323729, 0.8010912162811658, 0.8010440094850891, 0.8015622707499679, 0.8008937691049917, 0.8012878353074483, 0.8013859171553717, 0.8014967609005059, 0.8012390490301148, 0.8010730998801696, 0.801524675768703, 0.8014184999624201, 0.8014936777078855, 0.8012709337981394, 0.8015195458170722, 0.8013121838877938, 0.8015024058770872, 0.8012914561553393, 0.8011975317632987, 0.8013119413130945, 0.8013440804422836, 0.8013586296642474, 0.801246158515502, 0.8015130212471506, 0.8011673379372337, 0.8015114452270022, 0.8014318202723595, 0.80140361296654, 0.8014077744944376, 0.8013728793893864, 0.8011782415137539, 0.8012505413037843, 0.8012340643651641, 0.8012407003722829, 0.8013567524836589, 0.8013163623203249, 0.8011997930435909, 0.8012866103209813, 0.8012440982603808, 0.801437411808303, 0.8014318019191705]
