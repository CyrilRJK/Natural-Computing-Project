# %% [markdown]
# # IMPORT

# %% [markdown]
# In this notebook I did not normalized images before evolving, just when predicting

# %%
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
import pickle
import time
from skimage.measure import compare_ssim
import tensorflow as tf
from keras.models import Model,load_model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input, Activation
from keras.utils import to_categorical
import keras
import random
# Out:
# Using TensorFlow backend.

# %%
#Set seeds
random.seed(1)
np.random.seed(1)

# %% [markdown]
# # GLOBAL VARS

# %%
INDIVIDUALS = 50
P_CROSS = 0.6
P_MUTATION = 0.01
CIFAR_IMG= 32

# %% [markdown]
# # THE DATA

# %%
from keras.datasets import cifar10

# The data, split between train and test sets:
(x_train_C, y_train_C), (x_test_C, y_test_C) = cifar10.load_data()
print('x_train shape:', x_train_C.shape)
print(x_train_C.shape[0], 'train samples')
print(x_test_C.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
num_classes=10
epochs=10
img_shape=32 
y_train_C = to_categorical(y_train_C, num_classes)
y_test_C = to_categorical(y_test_C, num_classes)


input_shape=(32,32,1)

x_train_C = x_train_C.astype('float32')
x_test_C = x_test_C.astype('float32')
x_train_C /= 255
x_test_C /= 255


print('x_train shape:', x_train_C.shape)
print('Number of images in x_train', x_train_C.shape[0])
print('Number of images in x_test', x_test_C.shape[0])
print('y_train shape:', y_train_C.shape)
print("input shape: ",input_shape)


# CONVERT TO GRAY SCALE

import matplotlib.pyplot as plt
import numpy as np

def grayscale(data, dtype='float32'):
    # luma coding weighted average in video systems
    r, g, b = np.asarray(.3, dtype=dtype), np.asarray(.59, dtype=dtype), np.asarray(.11, dtype=dtype)
    rst = r * data[:, :, :, 0] + g * data[:, :, :, 1] + b * data[:, :, :, 2]
    # add channel dimension
    rst = np.expand_dims(rst, axis=3)
    return rst

x_train_C = grayscale(x_train_C)
x_test_C = grayscale(x_test_C)

# now we have only one channel in the images
img_channels = 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-6879ee866196> in <module>
#       2
#       3 # The data, split between train and test sets:
# ----> 4 (x_train_C, y_train_C), (x_test_C, y_test_C) = cifar10.load_data()
#       5 print('x_train shape:', x_train_C.shape)
#       6 print(x_train_C.shape[0], 'train samples')
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\datasets\cifar10.py in load_data()
#      30         fpath = os.path.join(path, 'data_batch_' + str(i))
#      31         (x_train[(i - 1) * 10000: i * 10000, :, :, :],
# ---> 32          y_train[(i - 1) * 10000: i * 10000]) = load_batch(fpath)
#      33
#      34     fpath = os.path.join(path, 'test_batch')
#
# ~\AppData\Roaming\Python\Python37\site-packages\keras\datasets\cifar.py in load_batch(fpath, label_key)
#      21         A tuple `(data, labels)`.
#      22     """
# ---> 23     with open(fpath, 'rb') as f:
#      24         if sys.version_info < (3,):
#      25             d = cPickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Lora\\.keras\\datasets\\cifar-10-batches-py\\data_batch_1'

# %% [markdown]
# # READ PICKLE FILES

# %%
with open('subset_cifar', 'rb') as f:
    original = pickle.load(f)
    adversarial= pickle.load(f)
    original_y = pickle.load(f)
    adversarial_y = pickle.load(f)

# %%
print(f"Original shape {original.shape}")
print(f"Adversarial shape {adversarial.shape}")
print(f"Original labels shape {original_y.shape}")
print(f"Adversarial labels shape {adversarial_y.shape}")
# Out:
# Original shape (914, 32, 32, 1)
# Adversarial shape (133, 32, 32, 1)
# Original labels shape (914, 1)
# Adversarial labels shape (133, 1)

# %% [markdown]
# # LOAD THE MODEL

# %% [markdown]
# 3. CNN v2
#
# This network is made for CIFAR 10. The network is taken from [this blog]( https://appliedmachinelearning.blog/2018/03/24/achieving-90-accuracy-in-object-recognition-task-on-cifar-10-dataset-with-keras-convolutional-neural-networks/) . In this version below I didn't use some things used in the blog e.g. z-score and data augmentation.
#
#
# This network has training accuracy: 0.8940 , validation accuracy: 0.8245.
#
# **NOTE:** Training really slow, try to avoid it.

# %%
# Network 3 
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np

input_shape = (CIFAR_IMG,CIFAR_IMG,1)
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=input_shape))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
 
model.summary()


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


'''
history = model.fit(x=x_train_C,y=y_train_C, epochs=150, batch_size=64, validation_data=[x_test_C,y_test_C])

score= model.evaluate(x_test_C, y_test_C,verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save_weights("CNN_CIFAR10_net3.h5")
files.download('CNN_CIFAR10_net3.h5')
'''

model = load_model("CNN_CIFAR10_net3.h5")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        320
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 308,714
# Trainable params: 307,818
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# # GENETIC ALGORITHM FUNCTIONS

# %%
def computing_SSIM(individual,target):
    return compare_ssim(individual.reshape(CIFAR_IMG,CIFAR_IMG), target.reshape(CIFAR_IMG,CIFAR_IMG))

def calculate_fitness(model,ind,target_image,label,l1=0.2, l2=0.8, N=50, num_classes=10):
  # predict the population
  predictions=model.predict(ind.reshape(1,CIFAR_IMG,CIFAR_IMG,1) / 255.0)  
  # po is the ground truth prediction, so for label = 0, it will be prediciton[0]
  predictions=predictions[0]
  po=predictions[label]
  # set that value to 0
  predictions[label]=0
  # take next highest one
  pd = np.max(predictions)
  diff=pd-po
  return l1*computing_SSIM(ind.reshape(CIFAR_IMG,CIFAR_IMG),target_image.reshape(CIFAR_IMG,CIFAR_IMG)) +l2*(diff)
  


def pop_fitness(model,pop,target,label):
    return [calculate_fitness(model, p, target, label) for p in pop]

def flatten(imgs):
    # flatten all images in np array or list
    return np.array([im.flatten() for im in imgs])

def gaussian_noise():
    # draw one sample of noise from zero mean 1 variance Gaussian
    return np.random.normal(0, 10)

def p_noise(x):
  if 0.01 > np.random.uniform():
    return x + gaussian_noise()
  else:
    return x
    
def add_noise(image):
    noise_v=np.vectorize(p_noise)
    return noise_v(image) #np.array([x + gaussian_noise() if P_MUTATION > np.random.uniform(0.0, 1.0) else x+0 for x in image])

def k_crossover(im1, im2, k=2):
    c1, c2 = [], []
    # get k crossover points
    points = sorted([np.random.randint(0, CIFAR_IMG*CIFAR_IMG-1, 1) for p in range(k)])
    points = sorted([np.random.randint(0,CIFAR_IMG*CIFAR_IMG-1,1) for p in range(k)])
    im_1_split = np.split(im1, [int(p) for p in points])
    im_2_split = np.split(im2, [int(p) for p in points])
    
    # alternate between lists to realise crossover (theres got to be a more clever way to do this)
    for i in range(k+1):
        if i % 2 == 0:
            c1.append(im_1_split[i])
            c2.append(im_2_split[i])
        else:
            c1.append(im_2_split[i])
            c2.append(im_1_split[i])
    return np.concatenate(c1, axis=0), np.concatenate(c2, axis=0)

def tournament(pop, model, ground_truth, target, k=3):

    indices = np.random.choice(range(len(pop)), k, replace=False) #we get 3 indxes [2 34 46]    
    individuals = pop.take(indices,axis=0)
    scores = pop_fitness(model,np.expand_dims(individuals.reshape(individuals.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3), ground_truth.reshape(CIFAR_IMG,CIFAR_IMG), target)
    index_max = np.argmax(scores)
    winner = individuals[index_max]
    return winner


def check_adv_termination(ind, label,ground_truth, model):
  # individual - the best one from the generation
  # label - class we want
  # ground_truth - the image (32,32)
  # model we are using 
  dist = 1-compare_ssim(ind.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG))
  predictions= model.predict(ind.reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0)
  predicted_label= np.argmax(predictions[0])
  if label != predicted_label and dist < 0.001:
    print("FOUND ADVERSARIAL")
    print(f"Fitness of the adversarial {calculate_fitness(model,ind,ground_truth,label)}")
    return ind
  return []

def init_pop_from_sample(n,img,label):
    x = np.array([add_noise(img) for i in range(n)])
    return x.reshape(n, CIFAR_IMG*CIFAR_IMG)

# %% [markdown]
# Functions from the past, just didn't want to erase them yet

# %%
'''
def check_adverserial(pop, model, fitness, target,ground_truth):
    #print(f"this is adversarial function")
    preds=model.predict(pop.reshape(pop.shape[0],28,28,1))
    #print(f"These are predictions made here {preds}")
    for ind, pr in zip(pop,preds): 
      #print(f"prediction for an individual {pr}")
      preds=np.argmax(pr)
      #print(f"getting the index of highest value in predictions {preds}")
      #setting the value to 0
      pr[0]=0
      #print(f"this is our target {target}")
      #print(f"this is out ground_truth {ground_truth.shape}")
      fitness=computing_SSIM(ind.reshape(28,28),ground_truth.reshape(28,28))
      #print(f"these are the fitness values {fitness}")
      next_highest = np.argmax(pr)
      #print(f"getting the next highest value {next_highest}")
      if next_highest != target and fitness > 0.98:
          return ind, True
      return None, False

def init_pop(n, num, data, labels):
    indices = np.where(labels==num)[0]
    n_indices = np.random.choice(indices, n, replace=True)
    sample = np.take(data, n_indices, axis=0)
    return sample, np.full((n), num, dtype=int) # return sample+array of labels


Cyrils model

def save_trained_model(model, filename='SVC_model.sav'):
    pickle.dump(model, open(filename, 'wb'))
    
def load_trained_model(filename='SVC_model.sav'):
    return pickle.load(open(filename, 'rb'))

'''
# Out:
# '\ndef check_adverserial(pop, model, fitness, target,ground_truth):\n    #print(f"this is adversarial function")\n    preds=model.predict(pop.reshape(pop.shape[0],28,28,1))\n    #print(f"These are predictions made here {preds}")\n    for ind, pr in zip(pop,preds): \n      #print(f"prediction for an individual {pr}")\n      preds=np.argmax(pr)\n      #print(f"getting the index of highest value in predictions {preds}")\n      #setting the value to 0\n      pr[0]=0\n      #print(f"this is our target {target}")\n      #print(f"this is out ground_truth {ground_truth.shape}")\n      fitness=computing_SSIM(ind.reshape(28,28),ground_truth.reshape(28,28))\n      #print(f"these are the fitness values {fitness}")\n      next_highest = np.argmax(pr)\n      #print(f"getting the next highest value {next_highest}")\n      if next_highest != target and fitness > 0.98:\n          return ind, True\n      return None, False\n\ndef init_pop(n, num, data, labels):\n    indices = np.where(labels==num)[0]\n    n_indices = np.random.choice(indices, n, replace=True)\n    sample = np.take(data, n_indices, axis=0)\n    return sample, np.full((n), num, dtype=int) # return sample+array of labels\n\n\nCyrils model\n\ndef save_trained_model(model, filename=\'SVC_model.sav\'):\n    pickle.dump(model, open(filename, \'wb\'))\n    \ndef load_trained_model(filename=\'SVC_model.sav\'):\n    return pickle.load(open(filename, \'rb\'))\n\n'

# %%
''' my part of the code ''' 
''' I know it is ugly, I will fix it . this is the intial version'''
# from Goorge Clooney paper
def quadrant_crossover(parent_1,parent_2):

  # reshape parents
  parent_1,parent_2= parent_1.reshape((CIFAR_IMG,CIFAR_IMG)), parent_2.reshape((CIFAR_IMG,CIFAR_IMG))
  # quadrants for both parents
  p1,p2,p3,p4,q1,q2,q3,q4 = [],[],[],[],[],[],[],[]
  child1, child2 = [],[]
  # getting random (x,y) point in 2D matrix
  x,y = np.random.randint(0,CIFAR_IMG-1), np.random.randint(0,CIFAR_IMG-1)  

  # choose which quadrant we want to crossover
  N = np.random.randint(0,3)
  #make quadrants
  for i in range(CIFAR_IMG):
    if (i<=x):
      p1.append(parent_1[i][:y+1])
      p2.append(parent_1[i][y+1:])
      q1.append(parent_2[i][:y+1])
      q2.append(parent_2[i][y+1:])
    else:
      p3.append(parent_1[i][:y+1])
      p4.append(parent_1[i][y+1:])
      q3.append(parent_2[i][:y+1])
      q4.append(parent_2[i][y+1:])

  if (N==0):
    ch1 = connect_quadrants(p1,q2,q3,q4)
    ch2 = connect_quadrants(q1,p2,p3,p4)
  elif (N==1):
    ch1 = connect_quadrants(q1,p2,q3,q4)
    ch2 = connect_quadrants(p1,q2,p3,p4)
  elif (N==2):
    ch1 = connect_quadrants(q1,q2,p3,q4)
    ch2 = connect_quadrants(p1,p2,q3,p4)
  else:
    ch1 = connect_quadrants(q1,q2,q3,p4)
    ch2 = connect_quadrants(p1,p2,p3,q4)

  return ch1,ch2

def connect_quadrants(q1,q2,q3,q4):
  left = np.concatenate((q1,q3))
  right = np.concatenate((q2,q4))
  image = np.concatenate((left,right),axis=1)
  return image.flatten()


def multi_crossover(parent1,parent2,target):
  pop= []
  # 2-k crossover
  pop.append(k_crossover(parent1, parent2))
  # Gorge Clooney crossover
  pop.append(quadrant_crossover(parent1,parent2))
  # uniform crossover
  pop.append(k_crossover(parent1, parent2,1))
  # SSIM similarity 
  flattened_list = [y for x in pop for y in x] # need to flatten the list because pop is list of lists, cause every crossover function returns 2 obj
  ssim = [computing_SSIM(ind,target) for ind in flattened_list ]
  # taking the index of largest two score
  id1=np.argmax(ssim)
  ssim[id1]=0
  id2 = np.argmax(ssim)
  #returning parents
  return flattened_list[id1],flattened_list[id2]

# %%
def return_best_individual(pop,fitness):
  index = np.argmax(fitness)
  best = pop[index]
  return best, np.max(fitness)

# %%
def choose_better_child(ch1, ch2,ground_truth,label,model):
  # I named it better child, but we choose by this parents as well
  ch1_f = calculate_fitness(model,ch1.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG),label)
  ch2_f = calculate_fitness(model,ch2.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG),label)
  # change this into ternary operator
  if ch1_f>ch2_f:
    return ch1
  else:
    return ch2

# %% [markdown]
# # THE MAIN LOOP

# %%
'''
This not necessary when using subset 
'''
'''
X = flatten(x_train)
X_t = flatten(x_test)
print(f"X train shape {X.shape}")
print(f"X test shape {X_t.shape}")
print(f"y train shape {y.shape}")
print(f"y test shape {y_t.shape}")
'''
# Out:
# '\nX = flatten(x_train)\nX_t = flatten(x_test)\nprint(f"X train shape {X.shape}")\nprint(f"X test shape {X_t.shape}")\nprint(f"y train shape {y.shape}")\nprint(f"y test shape {y_t.shape}")\n'

# %%
# for each image and label in adversarial
n=50
import time
# these are the examples that are found as adversarialwe will save these at the end in a file
evolved_examples= []
# fitness of the adversarials
fitness_of_evolved=[]
# time necessary to evolve the adversarial
times=[]
# the distance between the original image and the adversarial
ssim_values=[]
# number of round necessary to produce adversarial 
number_of_rounds=[]
# this will serve to see if the fitness changes or not 
best_fitness = 0


numb_of_found_after30=0
numb_of_adv_found=0

#dictionary to keep the best individual to check if the fitness is improving or not 


predicted_class= []
for img,label in zip(adversarial,adversarial_y):
  winner_of_gen = {"image":[],"label": None, "fitness": None}
  #temporary variable to check generations:
  fitness_no_change = 0
  start = time.time()
  label=label[0]
  #intialize population from the image and with the given label
  population = init_pop_from_sample(n,img,label)
  # calculate fitness of these individuals
  fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label)
  print(f"Initial fitness: \n {fitness}")
  #retun the best one from the population
  best,fit_max = return_best_individual(population,fitness)
  #check if adversarial
  check_adv = check_adv_termination(best,label,img, model)
  #define max generation
  max_gen=0
  winner_of_gen.update(image= best)
  winner_of_gen.update(label= label)
  winner_of_gen.update(fitness= fit_max)

  while (len(check_adv)==0 or max_gen<10000):
      new_pop=[]
      for i in range(50):
        parent1= tournament(population, model, img, label) 
        parent2 = tournament(population, model, img, label)
        if 0.8 > np.random.uniform(0.0, 1.0):
          child1, child2 = k_crossover(parent1, parent2) # crossover
          new_pop.append(add_noise(choose_better_child(child1, child2,img,label,model)))
        else:
          new_pop.append(add_noise(choose_better_child(parent1, parent2,img,label,model)))

      # to reshape into an array 
      population= np.array(new_pop)
      #check fitness of the generation
      fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label) 
      #find the highest fitness
      best,fit_max1 = return_best_individual(population,fitness)
      # check adversarial - check if pred != target, distance < 0.001 or fitness didn't improve 0.001 after 30 generations(this is in else condition)
      check_adv = check_adv_termination(best,label,img,model)

      #check if the first termination true 
      if(len(check_adv) != 0):
        print("Adversarial example image: \n")
        evolved_examples.append(check_adv) #add evolved example
        ssim_values.append(1-compare_ssim(check_adv.reshape(CIFAR_IMG,CIFAR_IMG),img.reshape(CIFAR_IMG,CIFAR_IMG))) #add the distance
        end=time.time()
        times.append(end-start) #add the time 
        fitness_of_evolved.append(calculate_fitness(model,check_adv,img,label)) #add the fitness value of adversarial
        number_of_rounds.append(max_gen)
        pred_l=np.argmax(model.predict(check_adv.reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0))
        predicted_class.append(pred_l)
        print("Left: adversarial \t Right: ground truth")
        fd, idx = plt.subplots(1,2)
        idx[0].imshow(check_adv.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        idx[1].imshow(img.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        plt.show()
        print(f"True label: {label}")
        print(f"predicted label: {pred_l}") 
        print("Time: ",end-start ," seconds")
        numb_of_adv_found+=1
        break
      #check the second termination 
      else:
          #check if fitness increases, if not , add +1 to temporary var
        if fit_max1>fit_max:
          fit_max=fit_max1
          winner_of_gen.update(image= best)
          winner_of_gen.update(label= label)
          winner_of_gen.update(fitness= fit_max1)
          fitness_no_change=0
        else:
          fitness_no_change+=1
      
      #print after every 10 generations to see the progress
      if (max_gen % 10 == 0):
        print(f"Generation {max_gen}")
        print(f"Max fitness value {fit_max}")
      max_gen+=1

      # if fitness did not improve for 30 generations, save the image that was best , saved it in a dicitonary
      if fitness_no_change==30:
        print("FITNESS DID NOT IMPROVE FOR 30 GENERATIONS")
        print("Best adversarial image we could find: \n")
        evolved_examples.append(winner_of_gen["image"])
        ssim_values.append(1-compare_ssim(np.array(winner_of_gen["image"]).reshape(CIFAR_IMG,CIFAR_IMG),img.reshape(CIFAR_IMG,CIFAR_IMG)))
        number_of_rounds.append(max_gen)
        end=time.time()
        times.append(end-start)
        fitness_of_evolved.append(winner_of_gen["fitness"])
        pred_l=np.argmax(model.predict(np.array(winner_of_gen["image"]).reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0))
        predicted_class.append(pred_l)
        print("Left: adversarial \t Right: ground truth")
        fd, idx = plt.subplots(1,2)
        idx[0].imshow(np.array(winner_of_gen["image"]).reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        idx[1].imshow(img.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        plt.show()
        print(f"True label: {label}")
        print(f"predicted label: {pred_l}")
        print("Time: ",end-start ," seconds")
        numb_of_found_after30 +=1
        break
# Out:
# Initial fitness:
#  [-0.6003743197968582, -0.6012464092882421, -0.6019087320246557, -0.6014880197951772, -0.6022836148095521, -0.6005888507054344, -0.6011141911803378, -0.6006199347239177, -0.6024622861388831, -0.6006025092861443, -0.601838997838289, -0.6018174764350027, -0.6013234496572247, -0.6006019042140215, -0.5999523317169378, -0.6002859145884996, -0.6013769320549351, -0.6023342732597164, -0.6028743711739928, -0.6006267923136724, -0.6006465127265974, -0.6028326187758263, -0.6002066879991809, -0.6002987692340014, -0.6009014088932532, -0.6013053149923098, -0.600691811030488, -0.6014717255143034, -0.6002385191190581, -0.6046284579990849, -0.6013145129157351, -0.6014545502478296, -0.6005576411811194, -0.601324872687319, -0.6006042460735911, -0.6020674037859883, -0.6004529333429227, -0.6028085351237225, -0.6003050958096371, -0.6002419404270258, -0.6012601326004444, -0.6008832743961511, -0.6003449169657735, -0.6022335928817804, -0.6003703453762899, -0.6009268965988709, -0.6021095345215102, -0.6027317837550541, -0.6002714978273793, -0.6012993287648497]
# Generation 0
# Max fitness value -0.5999523317169378
# C:\Users\Lora\Anaconda3\lib\site-packages\skimage\measure\_structural_similarity.py:155: UserWarning: Inputs have mismatched dtype.  Setting data_range based on X.dtype.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "
# Generation 10
# Max fitness value 0.12134662296644658
# Generation 20
# Max fitness value 0.9713984951154714
# Generation 30
# Max fitness value 0.9728434877294486
# Generation 40
# Max fitness value 0.9750802314091324
# Generation 50
# Max fitness value 0.9753748610386556
# Generation 60
# Max fitness value 0.9758256014608316
# Generation 70
# Max fitness value 0.9758587869017206
# Generation 80
# Max fitness value 0.9758587869017206
# Generation 90
# Max fitness value 0.9758587869017206
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  261.440393447876  seconds
# Initial fitness:
#  [-0.4542096302875347, -0.5118649294848312, -0.4859645147011143, -0.5291416322547045, -0.47712309932899555, -0.494933582891391, -0.5309372058861141, -0.4770900550135294, -0.5111672075360955, -0.5099235077663395, -0.41905601140368787, -0.5378453405663699, -0.49832521844344635, -0.4587786724591114, -0.4394852845390459, -0.48318852447021776, -0.5244225705415324, -0.43434210844582416, -0.4468333668312646, -0.4549537898734656, -0.4982759077280746, -0.5643752167725551, -0.5126740899885184, -0.46133085406974106, -0.5461811954229049, -0.5182206271098692, -0.44681441481206396, -0.46059075772404023, -0.516387309727833, -0.48496330321527653, -0.4435162197218452, -0.45132172547480387, -0.5099683118133508, -0.4923960007699171, -0.48933913284287456, -0.502586973448847, -0.47055300862274335, -0.4600334684928629, -0.5146541539342155, -0.3637632955172141, -0.5086824505243408, -0.47923291752812935, -0.5315380251896186, -0.46621287332603145, -0.5453988722273608, -0.4501697208673535, -0.46990180050492925, -0.5080029448115524, -0.337736661544507, -0.5355987111886851]
# Generation 0
# Max fitness value -0.12041791147703187
# Generation 10
# Max fitness value 0.9166426074282258
# Generation 20
# Max fitness value 0.991288087824501
# Generation 30
# Max fitness value 0.9947515159709089
# Generation 40
# Max fitness value 0.9950755876289789
# Generation 50
# Max fitness value 0.9950755876289789
# Generation 60
# Max fitness value 0.9950755876289789
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  178.58905863761902  seconds
# Initial fitness:
#  [-0.3119379717520466, -0.12190596493736694, 0.14330461703819597, 0.02886975439494044, -0.2901983729379814, 0.011626026427856428, -0.40031522394009067, -0.34006732916233545, -0.38571807344855347, -0.38653680330530665, -0.2772070544018124, -0.28251471070463224, -0.40027115486553233, -0.32410566360854853, -0.4111597119411481, -0.4065706329275873, -0.31155290725779783, -0.4298268859873533, -0.34701962037670864, -0.3303453378562543, -0.33278552161998953, -0.3302200752899135, -0.33521619172705275, -0.4209096951402892, -0.4033614209038341, -0.39032368458157507, -0.2704942619763768, -0.3496190519100558, -0.19969398029954694, -0.39532044221542373, -0.3083691385445473, -0.3346608099140207, -0.3728024763869211, -0.3225803854914777, -0.27537888067133975, -0.3752214432836225, -0.04922770897670539, -0.3126314393945574, -0.2275230770727478, -0.38299795611813936, -0.329609581343407, -0.30313436550773226, -0.3519197605290393, -0.3015191829971816, -0.19851100552544176, -0.3738254794536452, -0.3538133166035914, -0.329046631795275, -0.3119688516909662, -0.267868211977026]
# Generation 0
# Max fitness value 0.25614366042368614
# Generation 10
# Max fitness value 0.9897429672231872
# Generation 20
# Max fitness value 0.993262392390475
# Generation 30
# Max fitness value 0.993262392390475
# Generation 40
# Max fitness value 0.993262392390475
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  127.76859855651855  seconds
# Initial fitness:
#  [-0.5940815088058781, -0.5924110462439006, -0.5903928688203278, -0.5958774276042084, -0.5968350708190353, -0.5953886596259668, -0.5956278850574781, -0.5936864389226293, -0.5910192622762375, -0.5959638378232315, -0.5944337626855949, -0.5939422335533185, -0.5945050914644826, -0.5934705875558695, -0.5950631646498523, -0.5948207157632128, -0.5945247303217196, -0.5937605780021354, -0.5935383778048523, -0.5933159332661563, -0.5936780520231909, -0.5940288389714983, -0.5912206868151397, -0.5921137207801765, -0.5915631057042194, -0.5932733190328965, -0.5935044229353312, -0.5939894646910244, -0.5939006586588834, -0.5877335491149271, -0.5930187226888087, -0.5888913897890516, -0.5957570950385714, -0.5928879643729797, -0.59510761755839, -0.5954294429160161, -0.5939471517869275, -0.5960381073224623, -0.5947892437009199, -0.5973857394716362, -0.5950914600011817, -0.5911290189720303, -0.5950989331591086, -0.5918321631945838, -0.5945269761542032, -0.595462761387141, -0.5972894750077025, -0.5969578539797495, -0.5939504490480267, -0.5955007111636125]
# Generation 0
# Max fitness value -0.5828947923391078
# Generation 10
# Max fitness value 0.7438182866523266
# Generation 20
# Max fitness value 0.9870116861064561
# Generation 30
# Max fitness value 0.9913314365097543
# Generation 40
# Max fitness value 0.9918092381663527
# Generation 50
# Max fitness value 0.9921252586229552
# Generation 60
# Max fitness value 0.9926471596844297
# Generation 70
# Max fitness value 0.992899756082311
# Generation 80
# Max fitness value 0.9934670675436976
# Generation 90
# Max fitness value 0.9935891289630163
# Generation 100
# Max fitness value 0.993685679061946
# Generation 110
# Max fitness value 0.993685679061946
# Generation 120
# Max fitness value 0.9937252455694026
# Generation 130
# Max fitness value 0.9938050947155461
# Generation 140
# Max fitness value 0.9938050947155461
# Generation 150
# Max fitness value 0.9938050947155461
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  433.9701988697052  seconds
# Initial fitness:
#  [-0.5315259857194927, -0.532530297227448, -0.5373993272852161, -0.5711437955873382, -0.5135675552476338, -0.502489623274644, -0.5589804666466651, -0.5285916209016026, -0.5325686244419318, -0.5159983024634973, -0.5323167901142821, -0.5449977356098675, -0.5115763993861056, -0.5442432370357033, -0.542727791551482, -0.5293208386248683, -0.5561766750583187, -0.5713868162067195, -0.5276628623910352, -0.5063724449816734, -0.5445474721481259, -0.578241052799654, -0.5540642397152528, -0.5597151464553621, -0.5337201617639982, -0.556635901677151, -0.4965957770248759, -0.5319294914725009, -0.539721461500877, -0.4690003592660956, -0.5537176034559004, -0.524134438060972, -0.5527476003580463, -0.5464759042796115, -0.5453164749048629, -0.5521315675527089, -0.5306499638115337, -0.5554473362631391, -0.5409565660822918, -0.5321378886992323, -0.4182162898584928, -0.5234078046040996, -0.5449309176751524, -0.421208908156143, -0.5622482944327871, -0.5323343180085872, -0.5637509024348663, -0.5390118457697667, -0.55188664584271, -0.5416255715253006]
# Generation 0
# Max fitness value -0.07066146172213647
# Generation 10
# Max fitness value 0.9496710778565133
# Generation 20
# Max fitness value 0.9556946078172476
# Generation 30
# Max fitness value 0.9571768889000228
# Generation 40
# Max fitness value 0.9573977107288983
# Generation 50
# Max fitness value 0.9580377549592494
# Generation 60
# Max fitness value 0.9588596199082905
# Generation 70
# Max fitness value 0.9591440158396562
# Generation 80
# Max fitness value 0.9592808487465606
# Generation 90
# Max fitness value 0.9597271561896752
# Generation 100
# Max fitness value 0.9597271561896752
# Generation 110
# Max fitness value 0.9601206052422279
# Generation 120
# Max fitness value 0.9601206052422279
# Generation 130
# Max fitness value 0.9601206052422279
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  466.3745267391205  seconds
# Initial fitness:
#  [-0.6098931585284421, -0.6078987204649361, -0.5953896374004396, -0.6021581933184652, -0.6090160510549907, -0.5958035387734215, -0.6176537828096953, -0.5930111195378983, -0.6069482654879803, -0.5950321820390464, -0.5980162102555897, -0.6092215920136024, -0.6091220129566504, -0.6008213614527838, -0.5975091612985883, -0.590963141422502, -0.5848792399250288, -0.5966672484188199, -0.5969190660048301, -0.6002780281988456, -0.5951623990399119, -0.5933783772264415, -0.6217684455213042, -0.5997400333161258, -0.6039296375776411, -0.5908205917617029, -0.598418272558303, -0.6012339651257611, -0.6005413603755783, -0.6145348594988631, -0.5867244245508195, -0.591895721741248, -0.594072965888364, -0.5985485117269702, -0.5965414399969862, -0.5928009248206356, -0.6002893343021553, -0.5895533581261398, -0.6103485376320232, -0.5989483596012561, -0.596823431442423, -0.6045372958505835, -0.592312622459078, -0.6047482416218997, -0.608770540477571, -0.6005610438107093, -0.5987570793319386, -0.5945405996827295, -0.5928768273310281, -0.594511494765447]
# Generation 0
# Max fitness value -0.5125786123211817
# Generation 10
# Max fitness value 0.9163049810261185
# Generation 20
# Max fitness value 0.9357774091038282
# Generation 30
# Max fitness value 0.9357774091038282
# Generation 40
# Max fitness value 0.9357774091038282
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  166.60206270217896  seconds
# Initial fitness:
#  [-0.6021221613966616, -0.6023408650928759, -0.6030028707857904, -0.6013131771701461, -0.6008805506329922, -0.6009071484694328, -0.6020442282802638, -0.6102738672701035, -0.6009834723932017, -0.6023119297627411, -0.6036647334051095, -0.6009778505603942, -0.6006306941841949, -0.6032779149477687, -0.605667073975363, -0.6094033095842888, -0.6034291863633228, -0.6073860825529365, -0.6002661276379461, -0.6000647306124799, -0.6058551364394046, -0.6035611248065733, -0.6082202801269728, -0.6008974278755994, -0.600097434627, -0.6013043002803844, -0.6013631060362657, -0.603602128246973, -0.6006108900544256, -0.6015281952242743, -0.608902011081854, -0.602872204056199, -0.6084505613390961, -0.6065182013748766, -0.6011955863510523, -0.6039635924219366, -0.6016945036424223, -0.6065421994547332, -0.6065534279785181, -0.599844431861412, -0.6009509222746567, -0.6020614587595046, -0.6010251952463115, -0.6073966588687719, -0.6080759907613026, -0.6024821461964216, -0.6017592151343447, -0.6022255605200739, -0.602373073659505, -0.5998868691868031]
# Generation 0
# Max fitness value -0.599844431861412
# Generation 10
# Max fitness value -0.599844431861412
# Generation 20
# Max fitness value 0.25131081039274933
# Generation 30
# Max fitness value 0.9443133734150952
# Generation 40
# Max fitness value 0.9690340741794221
# Generation 50
# Max fitness value 0.9697541220901811
# Generation 60
# Max fitness value 0.9704433379678157
# Generation 70
# Max fitness value 0.9712709368971094
# Generation 80
# Max fitness value 0.9713937996766144
# Generation 90
# Max fitness value 0.9717784881780617
# Generation 100
# Max fitness value 0.9717784881780617
# Generation 110
# Max fitness value 0.9722036529327004
# Generation 120
# Max fitness value 0.9723974382516718
# Generation 130
# Max fitness value 0.972646537568944
# Generation 140
# Max fitness value 0.9730503961547303
# Generation 150
# Max fitness value 0.9730503961547303
# Generation 160
# Max fitness value 0.9730503961547303
# Generation 170
# Max fitness value 0.9730503961547303
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  596.9636309146881  seconds
# Initial fitness:
#  [-0.5965480333606483, -0.596485855476212, -0.5961486385931658, -0.5964175948243733, -0.5944301348291935, -0.5958655881423363, -0.5975110337790026, -0.595321275555433, -0.5963631158070796, -0.5958776011018271, -0.5963368213586959, -0.5946515503661831, -0.5965134877042906, -0.592867487155231, -0.5954063774433226, -0.595418615373601, -0.59838728473176, -0.5961786388797072, -0.5962108206653824, -0.5977416279412249, -0.5957325147172212, -0.5929501676763526, -0.5963896999762642, -0.5961812620637872, -0.5965239804105277, -0.5962293880991916, -0.596786756208183, -0.5966306574619243, -0.5966088568449354, -0.5965835146388183, -0.5967127542341116, -0.596765593912604, -0.5966516902246142, -0.5966750899936544, -0.594643197888633, -0.5961302661807015, -0.5965220840857015, -0.5958124414704389, -0.5949674904664257, -0.5958811453257138, -0.5973009593466626, -0.596132683724744, -0.595720419912475, -0.5960327777234194, -0.5955699902966088, -0.5962122918519652, -0.5976309016887488, -0.5963306397055375, -0.593464620031332, -0.5946648922593375]
# Generation 0
# Max fitness value -0.5867001052271079
# Generation 10
# Max fitness value 0.3118779195619926
# Generation 20
# Max fitness value 0.9656672414238577
# Generation 30
# Max fitness value 0.9901396645036229
# Generation 40
# Max fitness value 0.9919919712671289
# Generation 50
# Max fitness value 0.9923867445791134
# Generation 60
# Max fitness value 0.992561666028932
# Generation 70
# Max fitness value 0.9927009376879128
# Generation 80
# Max fitness value 0.9928324357006155
# Generation 90
# Max fitness value 0.9928960936311013
# Generation 100
# Max fitness value 0.9931329560894991
# Generation 110
# Max fitness value 0.9932380386336729
# Generation 120
# Max fitness value 0.9932694316330748
# Generation 130
# Max fitness value 0.9933705246757589
# Generation 140
# Max fitness value 0.9933968306951166
# Generation 150
# Max fitness value 0.9933968306951166
# Generation 160
# Max fitness value 0.9936195285286563
# Generation 170
# Max fitness value 0.9936566368428189
# Generation 180
# Max fitness value 0.9936566368428189
# Generation 190
# Max fitness value 0.9936566368428189
# Generation 200
# Max fitness value 0.9936991959726506
# Generation 210
# Max fitness value 0.9937548540995458
# Generation 220
# Max fitness value 0.9938533861889887
# Generation 230
# Max fitness value 0.9940211146599433
# Generation 240
# Max fitness value 0.9940211146599433
# Generation 250
# Max fitness value 0.9940211146599433
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  907.4285228252411  seconds
# Initial fitness:
#  [-0.5811972337272853, -0.584413779084973, -0.5753893651000287, -0.5829199752277874, -0.5740628012854324, -0.5773949107587414, -0.5855176305475178, -0.5743105730029183, -0.5646894070210109, -0.5776663639644227, -0.5854504493382126, -0.5863198285212597, -0.5657340236230286, -0.5768634241255977, -0.566761607227963, -0.5784340436929316, -0.5755824201058749, -0.5765871755948697, -0.5841191953070237, -0.5870153436012812, -0.5805894460236299, -0.5774888382996912, -0.5892762348182512, -0.581182521820052, -0.5783775206092053, -0.5813077419234318, -0.5805207303935798, -0.5843545974537563, -0.5939200930274002, -0.5768713734611487, -0.5797521985612266, -0.572441762063278, -0.5834510188900756, -0.577620331903872, -0.5671204755350453, -0.5815700534143582, -0.5908602551735629, -0.5715241259336149, -0.5715111879064843, -0.5842485422706752, -0.5820366113791853, -0.583286532250514, -0.5863583306561818, -0.5847073021480472, -0.5903243940370053, -0.5766154219089913, -0.5768539145534367, -0.581101802180515, -0.5724441717456449, -0.5856872417265205]
# Generation 0
# Max fitness value -0.5464818266835804
# Generation 10
# Max fitness value 0.26734576402077065
# Generation 20
# Max fitness value 0.9750187492184109
# Generation 30
# Max fitness value 0.9853062623101427
# Generation 40
# Max fitness value 0.9861983258812429
# Generation 50
# Max fitness value 0.9864455527186086
# Generation 60
# Max fitness value 0.9867403005201347
# Generation 70
# Max fitness value 0.986942657152726
# Generation 80
# Max fitness value 0.9873010249373063
# Generation 90
# Max fitness value 0.9875381709285525
# Generation 100
# Max fitness value 0.9875381709285525
# Generation 110
# Max fitness value 0.9875381709285525
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  408.52352952957153  seconds
# Initial fitness:
#  [0.03403560142874046, -0.09780588515627614, -0.32901419075162147, -0.0648480738716723, -0.07407595292020072, -0.25396068941059863, -0.043259123120190424, -0.25256556211297115, -0.18484035692526696, -0.3459128831953694, -0.15728253171214893, 0.015471945254957264, -0.13373269416079975, -0.07472693359246252, 0.4905717273101049, 0.005582828298013515, -0.05332361380207443, -0.024738678121633606, -0.19546988701727458, -0.11904344911421172, -0.4060476676189245, -0.12841126997122207, -0.1774660394665582, -0.16377984238243354, -0.03646443619893999, -0.08720815101918622, -0.1697005577527529, -0.250936370417274, -0.2067619978654704, -0.14705629502807524, -0.047737301325366355, -0.21173093405850676, -0.06389385893978511, -0.20659770568460964, -0.24829052220406825, -0.13907331523288763, -0.1947123868629762, 0.018420991511735124, -0.17274602519246118, -0.2814162813706367, -0.19168044258090575, -0.05292808230315904, 0.0772768288246483, -0.11665561365519678, 0.09364279472381697, 0.04430382897308474, -0.17705232024390016, -0.047820931406299116, -0.09208406185235582, 0.002914380974083225]
# Generation 0
# Max fitness value 0.7182213644048577
# Generation 10
# Max fitness value 0.9818911751829429
# Generation 20
# Max fitness value 0.9823450429691049
# Generation 30
# Max fitness value 0.9823450429691049
# Generation 40
# Max fitness value 0.9823450429691049
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  154.15689086914062  seconds
# Initial fitness:
#  [-0.514524876190976, -0.5312963435738762, -0.5590890189813715, -0.55014485774985, -0.48000376502221154, -0.48521285038131823, -0.5280622720300108, -0.5325224568016693, -0.5307426551972279, -0.4633824621068032, -0.4948168885466252, -0.5259700912537908, -0.5183489690386313, -0.5693083439446214, -0.5170819419848458, -0.56829326378285, -0.48133271085564766, -0.5457823013561103, -0.5164744680484779, -0.5274762390287691, -0.5805920700743665, -0.4095428345303447, -0.4757403736212036, -0.503208255846441, -0.5281680437881752, -0.5139385414018486, -0.4909367876814265, -0.5266775032759872, -0.5191056221522281, -0.5543475899795132, -0.49361605136318365, -0.4798806280396789, -0.43757595147311146, -0.5444602431921378, -0.4805185489029835, -0.5233784340938918, -0.4716540329250574, -0.538368977413512, -0.5115929416786698, -0.564468907280059, -0.4494701906452041, -0.5245308934010411, -0.46435539508125806, -0.49109636179915084, -0.46176516504880777, -0.4418619844012225, -0.540161795013649, -0.5029079955931061, -0.5121438577799875, -0.4737254484494192]
# Generation 0
# Max fitness value -0.2654318995676147
# Generation 10
# Max fitness value 0.984661547691384
# Generation 20
# Max fitness value 0.994738435099278
# Generation 30
# Max fitness value 0.994738435099278
# Generation 40
# Max fitness value 0.9951044516634939
# Generation 50
# Max fitness value 0.9951044516634939
# Generation 60
# Max fitness value 0.9951044516634939
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 9
# Time:  235.33411264419556  seconds
# Initial fitness:
#  [0.33086604232869976, 0.3879376760966444, 0.41452655850021347, 0.4576331262681679, 0.596181007143525, 0.4416497902316657, 0.2949700450334003, 0.43297483469783343, 0.41795232760271284, 0.41940588792141653, 0.4348400723981306, 0.4289436496278316, 0.46787496336912976, 0.36642916707678286, 0.3979926243182018, 0.4678246628408971, 0.4499433196523045, 0.5503132045585666, 0.42706543188910745, 0.3779648082783348, 0.38533537111782035, 0.48689535468481815, 0.4283783275653279, 0.47649728382435197, 0.48769165966377515, 0.5797049346251302, 0.4861602946418302, 0.47700302493608526, 0.4263637126023218, 0.456254287788953, 0.529926882331538, 0.5382520643174915, 0.5396306812984786, 0.342242673656038, 0.4937130606985614, 0.4428657980606301, 0.33867714459895704, 0.4073904384159398, 0.4168349366762275, 0.47569111170597156, 0.3803233634657419, 0.40367313500022367, 0.4674181120100235, 0.4061812905667528, 0.3432851019792299, 0.378659501119116, 0.42612473249464067, 0.34812578312913267, 0.39745619797170284, 0.4124027187098046]
# Generation 0
# Max fitness value 0.7153252004171596
# Generation 10
# Max fitness value 0.9935099845669815
# Generation 20
# Max fitness value 0.9940696893185407
# Generation 30
# Max fitness value 0.9940696893185407
# Generation 40
# Max fitness value 0.9940696893185407
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  181.86225605010986  seconds
# Initial fitness:
#  [-0.15622384031939043, -0.3139833485283873, -0.24084566038026695, -0.29850717115294545, -0.3711380944607142, -0.44452937977876683, -0.2719940371392392, -0.12342359564095218, -0.1901826993745921, -0.17191427794048944, -0.15251371937486335, -0.13497060668172683, -0.2860559114923045, -0.1923855386725496, -0.25663285972223393, -0.1715696487076327, -0.3992312755073705, 0.30366335722015614, -0.3908045976173945, -0.3896580687623508, -0.34841699618608646, 0.06250245837139443, -0.24989943558158714, -0.2039661560817887, -0.014762610518409797, -0.40205079889089024, -0.04656957138261453, -0.2969327607599257, -0.2420390114750903, -0.2347318663792884, 0.15697225404771858, 0.13248655300231132, -0.36101538127593713, -0.37300856208041167, 0.22694428245099027, -0.21126732592433678, -0.24974533870447144, -0.3506353045117312, 0.08342673612703545, -0.04232494170857745, -0.4036002416256962, -0.12477645178084387, -0.2399510505431537, -0.3864055283554457, -0.17957560903789133, -0.20927875369928178, -0.18665847525961127, -0.3351613003141049, -0.3707800736424096, -0.20971234699964714]
# Generation 0
# Max fitness value 0.6521831523042132
# Generation 10
# Max fitness value 0.9951553828935602
# Generation 20
# Max fitness value 0.9970208433667898
# Generation 30
# Max fitness value 0.997124215570229
# Generation 40
# Max fitness value 0.9971561044364786
# Generation 50
# Max fitness value 0.9971561044364786
# Generation 60
# Max fitness value 0.9971561044364786
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  231.31820225715637  seconds
# Initial fitness:
#  [-0.6013933184141509, -0.6014023892287472, -0.603580174201802, -0.6016552594559038, -0.6004583742360006, -0.6025888371896412, -0.6030548049496253, -0.6017412412895086, -0.6009337633580027, -0.6002893887294511, -0.6016789345854787, -0.6009364170496884, -0.6026731157101243, -0.6018102645157999, -0.6007519632743552, -0.6003672959090827, -0.6013061090155114, -0.6016044535987, -0.6005758109193996, -0.6008230855550947, -0.6011699238923234, -0.602140360171759, -0.6017138714746166, -0.6041770652995198, -0.6028081362852308, -0.6025178724589926, -0.6013193828517917, -0.6000176780286608, -0.6012236433952475, -0.601763413434468, -0.6006224672421846, -0.6006762302746596, -0.601788116485877, -0.600084485116516, -0.6000504547258432, -0.600432055638525, -0.6004848791639695, -0.6018517467823472, -0.6003130002451018, -0.6001418266511609, -0.6000335833448492, -0.601413919132376, -0.6021366870201834, -0.6006109986303587, -0.600683943148181, -0.5999993432013525, -0.6039493615752252, -0.6003523451346017, -0.6027525937960918, -0.6015716972103616]
# Generation 0
# Max fitness value -0.5999993432013525
# Generation 10
# Max fitness value -0.5999993432013525
# Generation 20
# Max fitness value -0.18815440579497217
# Generation 30
# Max fitness value 0.9826597407283107
# Generation 40
# Max fitness value 0.9871204346101718
# Generation 50
# Max fitness value 0.9875902993277252
# Generation 60
# Max fitness value 0.9881837806409084
# Generation 70
# Max fitness value 0.9882565248308687
# Generation 80
# Max fitness value 0.9883507631053954
# Generation 90
# Max fitness value 0.9884602034075141
# Generation 100
# Max fitness value 0.9885902351457956
# Generation 110
# Max fitness value 0.98876479928522
# Generation 120
# Max fitness value 0.9888191545895247
# Generation 130
# Max fitness value 0.9889795520750836
# Generation 140
# Max fitness value 0.9889795520750836
# Generation 150
# Max fitness value 0.9889795520750836
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 8
# Time:  558.903736114502  seconds
# Initial fitness:
#  [-0.5449754347405085, -0.5532767030055651, -0.47088864923683116, -0.5452296500460861, -0.4948767431437324, -0.2839601373329199, -0.5632189613543894, -0.39195390429798516, -0.5780477120038621, -0.5606621564398645, -0.5478812263965651, -0.564407072684594, -0.5789626020918871, -0.5419181417938687, -0.5598062503703691, -0.5434472690636475, -0.5402072071259907, -0.5457788370028007, -0.5346725031296665, -0.5742511894309373, -0.5046607541783403, -0.5496497035114871, -0.5085910811852697, -0.5245629229289472, -0.5558101706853158, -0.5669824818902129, -0.5524333334032862, -0.5433835976301646, -0.5615991840640485, -0.5502776880463897, -0.5491099437848815, -0.5278559692771956, -0.5445706554262764, -0.5418948743503539, -0.5143265061139555, -0.55273633290705, -0.5664464488928138, -0.5450156405321981, -0.5752099379343638, -0.5571837336479243, -0.5440591888269909, -0.4832898119655342, -0.4667322064224197, -0.5413085631426097, -0.5525507890438327, -0.5412957803509002, -0.49693804102643346, -0.5380103143504372, -0.5504017017094022, -0.5275226406084823]
# Generation 0
# Max fitness value 0.010400855704318535
# Generation 10
# Max fitness value 0.9953161159996597
# Generation 20
# Max fitness value 0.9973497160855535
# Generation 30
# Max fitness value 0.9974584244861746
# Generation 40
# Max fitness value 0.9975322550809724
# Generation 50
# Max fitness value 0.9975322550809724
# Generation 60
# Max fitness value 0.9975322550809724
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  231.0176751613617  seconds
# Initial fitness:
#  [-0.6004243869732051, -0.6061378226657321, -0.6036018595732373, -0.6006154206294336, -0.6011342180924042, -0.6010740702858107, -0.6031992854003169, -0.6060589399150205, -0.6003028800298732, -0.6001598840769563, -0.6055216149008361, -0.6012374213899653, -0.6020784464568194, -0.6002467441052961, -0.6011296166628324, -0.6015100690614948, -0.6038965501983549, -0.6016218042876815, -0.6014139627678312, -0.6000541032964558, -0.6050138171044761, -0.6017906643210011, -0.6030882472331209, -0.6039387014987754, -0.6015953886500811, -0.6050759522281861, -0.6031822069702298, -0.6028105082551879, -0.6055806711986852, -0.6047701408652353, -0.6009262155569454, -0.6007598466495621, -0.6015470174006299, -0.600678504489421, -0.6034652190172494, -0.6020184026844783, -0.6022946462714202, -0.6017280301427863, -0.6002765181707435, -0.6011050417062074, -0.6006789889653258, -0.6060183618118113, -0.6016101855910267, -0.6027279672758792, -0.601152778562091, -0.6012627172209568, -0.6010222882340807, -0.6014204183886409, -0.6000149124084173, -0.6011890886744793]
# Generation 0
# Max fitness value -0.6000149124084173
# Generation 10
# Max fitness value -0.6000149124084173
# Generation 20
# Max fitness value -0.6000149124084173
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  111.79949378967285  seconds
# Initial fitness:
#  [0.21895448063963496, 0.49782506799697956, 0.277092697615121, 0.26943356614620084, 0.09051338114655655, 0.37904722704977734, 0.3410065162621865, 0.29042058677253596, 0.5022156564908442, 0.27466699595521704, 0.25955797598495944, 0.15686761312368644, 0.5880493043231949, 0.39490183902093157, 0.3925097662050979, 0.33776139767879176, 0.35131582202463735, 0.20841726732849886, 0.15075128126209408, 0.3588935566615875, 0.3680427756499488, -0.007797126284125211, 0.2678910416668495, 0.3224761529802427, 0.5013796049505561, 0.3309696593951833, 0.33463369733121373, 0.3397274476624872, 0.30211667772230294, 0.45001628806354843, 0.3650117157306167, 0.34038309366112723, 0.4798146442666743, 0.3789063091653232, 0.12914001502112155, 0.3673866101786586, 0.5226140956567946, 0.5045344067496496, 0.37186428885047274, 0.26728095933815044, 0.08986517545142245, 0.2988086697871707, 0.6897691635268088, 0.3144933828397961, 0.3303702773568082, 0.11513488644676093, 0.25344875998457683, 0.6490574317408877, 0.5634935937996903, 0.4107296013209577]
# FOUND ADVERSARIAL
# Fitness of the adversarial 0.6897691635268088
# Generation 0
# Max fitness value 0.8143915128774977
# Generation 10
# Max fitness value 0.9948278785775275
# Generation 20
# Max fitness value 0.9968930020593669
# Generation 30
# Max fitness value 0.9971758277575671
# Generation 40
# Max fitness value 0.9972060099633498
# Generation 50
# Max fitness value 0.9972060099633498
# Generation 60
# Max fitness value 0.9972060099633498
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 7
# Time:  240.88749766349792  seconds
# Initial fitness:
#  [0.5548101359952118, 0.5720652207604808, 0.5380974579066536, 0.5754543132730487, 0.5365693257834698, 0.5196913385046247, 0.5630300112208227, 0.5595933342660183, 0.5378329481722866, 0.48567650977624244, 0.5688887810424849, 0.467737778124403, 0.40485950021019146, 0.5437303722879385, 0.5199291449832557, 0.5560219570370613, 0.3650293959221134, 0.5833277303120374, 0.4698874653112339, 0.6297049684406834, 0.5718703605724758, 0.43035743550664296, 0.6207514213026334, 0.47875915139005765, 0.6840040775108975, 0.6928527797073009, 0.7056929238698642, 0.6018956769288142, 0.5628852306404571, 0.4776223042991097, 0.41247099851435004, 0.5046227922808632, 0.5568796301289304, 0.5223334538153275, 0.4823860754981905, 0.44379796191154336, 0.5326398717693911, 0.4161565345957604, 0.5838520863807052, 0.4639042608847198, 0.47562283072281997, 0.548917080139106, 0.5891199057512566, 0.5685184724995811, 0.5619931220895102, 0.5400870921613687, 0.6063644064082003, 0.4882070461793099, 0.5510148472236274, 0.5960004900056908]
# Generation 0
# Max fitness value 0.8540244290139658
# Generation 10
# Max fitness value 0.9937967797909716
# Generation 20
# Max fitness value 0.994364420004463
# Generation 30
# Max fitness value 0.994364420004463
# Generation 40
# Max fitness value 0.994364420004463
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 6
# Time:  155.39265251159668  seconds
# Initial fitness:
#  [-0.594102670207709, -0.5883288076824527, -0.5919906124517685, -0.5935834319162103, -0.5901539130562613, -0.5907161212540698, -0.5927572297780824, -0.5952369495124499, -0.5783950562235732, -0.5915624822427443, -0.5889356527401306, -0.5929362754285751, -0.5921084171953507, -0.581620157186578, -0.5884025331075762, -0.5900432981639523, -0.5937750477406314, -0.5933335127898812, -0.5884031226812056, -0.5965456347140324, -0.591027338947379, -0.5813123081967249, -0.5949704828158593, -0.5887760418874137, -0.593127660550072, -0.5898998254457486, -0.5946914602932172, -0.5954541464365237, -0.5882695357280137, -0.5980194245051043, -0.5929734620213096, -0.5941727927979104, -0.5960641706419032, -0.5953110431425979, -0.5908138529905275, -0.5893734765009224, -0.5945339727089521, -0.5964137267581543, -0.5921004447534606, -0.5963664319939788, -0.5907319264335509, -0.594244152378363, -0.5944199816034164, -0.5962698273594307, -0.5947338679755839, -0.5918947914210593, -0.5947106400804243, -0.5754511094518668, -0.5944830216392601, -0.583271469568094]
# Generation 0
# Max fitness value -0.5443477769947891
# Generation 10
# Max fitness value 0.9825816003048754
# Generation 20
# Max fitness value 0.9954603500407486
# Generation 30
# Max fitness value 0.9955187473938811
# Generation 40
# Max fitness value 0.9955252332757643
# Generation 50
# Max fitness value 0.9956102718084745
# Generation 60
# Max fitness value 0.9956102718084745
# Generation 70
# Max fitness value 0.9956663884985495
# Generation 80
# Max fitness value 0.9956663884985495
# Generation 90
# Max fitness value 0.9956663884985495
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 0
# Time:  342.0496242046356  seconds
# Initial fitness:
#  [-0.6000081945208452, -0.6000216069959291, -0.600020348629398, -0.6000131185431125, -0.6000610535073518, -0.6001099982524274, -0.6000339917067428, -0.6000624961803794, -0.6000335776419048, -0.6000315828785101, -0.6000285119308061, -0.6000299711566792, -0.6000042743781844, -0.6000633567450839, -0.6000192071012486, -0.6000217244235787, -0.6001120670657543, -0.6000524034897478, -0.6000735278846029, -0.600075213887018, -0.6000655843649786, -0.6000194800558589, -0.6000616878237609, -0.6000211251398008, -0.6000355969320682, -0.6000501057132067, -0.6000588138304921, -0.6000168692754902, -0.6000527216504403, -0.6000393559029179, -0.6000329359645686, -0.6000374012264881, -0.6000676142265547, -0.60004661827936, -0.6000913433143165, -0.6000433809568269, -0.6000761934797982, -0.6000828969921173, -0.6001537483199242, -0.6000266196846283, -0.6000841896418814, -0.6000396505719349, -0.6000799624738646, -0.6000113687564421, -0.60002098160509, -0.6000173328148859, -0.6001545313892293, -0.6000661083174076, -0.6000218468083228, -0.6000213542700579]
# Generation 0
# Max fitness value -0.6000042743781844
# Generation 10
# Max fitness value -0.6000042743781844
# Generation 20
# Max fitness value -0.4659544234789571
# Generation 30
# Max fitness value 0.8576854864131662
# Generation 40
# Max fitness value 0.9861870613548576
# Generation 50
# Max fitness value 0.9960288947818757
# Generation 60
# Max fitness value 0.9972088051205452
# Generation 70
# Max fitness value 0.9972088051205452
# Generation 80
# Max fitness value 0.9972799228760718
# Generation 90
# Max fitness value 0.9973601441941955
# Generation 100
# Max fitness value 0.9973861298300833
# Generation 110
# Max fitness value 0.9973872996772102
# Generation 120
# Max fitness value 0.9974618286890186
# Generation 130
# Max fitness value 0.9974783711040272
# Generation 140
# Max fitness value 0.997558670659208
# Generation 150
# Max fitness value 0.9976040217815412
# Generation 160
# Max fitness value 0.9976068092614607
# Generation 170
# Max fitness value 0.9976068092614607
# Generation 180
# Max fitness value 0.9976068092614607
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  660.8013906478882  seconds
# Initial fitness:
#  [-0.6008080927281705, -0.6003909006855168, -0.6002247419453429, -0.6000422217265173, -0.6000515971239515, -0.600180731550161, -0.6006308117803041, -0.6001691659115613, -0.6007248249793038, -0.6020646879644248, -0.6001088671353352, -0.6003679551798339, -0.6008157569461345, -0.6001699594768218, -0.6002483444043555, -0.6004621928217607, -0.6001336716525869, -0.6016522676972593, -0.6004849396032855, -0.6009724868341316, -0.6002995248531511, -0.6001774918925549, -0.6000049046272192, -0.6005064896867833, -0.6008906286829641, -0.6013076867269977, -0.6004932119181897, -0.6000439142984106, -0.6006574747302766, -0.6000222517042777, -0.6000512750705636, -0.6000041153632829, -0.6001490236192761, -0.6000151301485419, -0.6021190653647472, -0.6011587242900922, -0.6001620002596927, -0.6002393689309663, -0.6003344648489074, -0.600507699598144, -0.6001667785233221, -0.6003736584106761, -0.600036819918095, -0.6002206380381372, -0.6000735112662717, -0.6006340910542499, -0.6012030834935985, -0.6000112021612615, -0.6000934466593559, -0.6000976904149643]
# Generation 0
# Max fitness value -0.6000041153632829
# Generation 10
# Max fitness value 0.8628301046196216
# Generation 20
# Max fitness value 0.9942160466652521
# Generation 30
# Max fitness value 0.9949150052898792
# Generation 40
# Max fitness value 0.9949150052898792
# Generation 50
# Max fitness value 0.9949150052898792
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 0
# Time:  163.32269835472107  seconds
# Initial fitness:
#  [-0.6000165480102103, -0.600054824574013, -0.6002097965642628, -0.6000481596014386, -0.6000291563259308, -0.6000245235282, -0.6000375626594893, -0.6000845182988971, -0.6000474246092261, -0.6000096412657583, -0.6001144230749617, -0.6000089951812895, -0.6000388761522937, -0.600022906743674, -0.6000131371973995, -0.6000173781014604, -0.6002120047808135, -0.6000367987724886, -0.6000778706775426, -0.6000256335012204, -0.6000561103134912, -0.6000807625311466, -0.6000416356433265, -0.6000845310173681, -0.6000476384157084, -0.6000170598447389, -0.6002094537415004, -0.60004950205518, -0.600023152192717, -0.6000369050401818, -0.6000563296821887, -0.6000270638348979, -0.6001824339995774, -0.6000067345728309, -0.6001187157270931, -0.6000490390825758, -0.6000567646018573, -0.6000657683544524, -0.6000227618509066, -0.6000452214842547, -0.600192129645856, -0.6000342003494623, -0.6000377436447382, -0.600085880808088, -0.600152340575746, -0.600040901942579, -0.6000168758271596, -0.600015842621062, -0.600073846617277, -0.6000266746566429]
# Generation 0
# Max fitness value -0.600006506617109
# Generation 10
# Max fitness value -0.600006506617109
# Generation 20
# Max fitness value -0.600006506617109
# Generation 30
# Max fitness value -0.600006506617109
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  92.17158317565918  seconds
# Initial fitness:
#  [-0.6003609394344591, -0.5998085854624244, -0.5995455639772085, -0.599748570138657, -0.5997132985170474, -0.5996237136868751, -0.5990386561539641, -0.5993786239956105, -0.5995467123367886, -0.6000522603608415, -0.5993120529723112, -0.599337819698669, -0.5996413846503225, -0.5995817860411282, -0.5997127188330849, -0.5994232336525356, -0.5996586435621245, -0.5996492175485668, -0.5994825426790775, -0.6002172284224321, -0.5997224621206373, -0.6004902875848629, -0.5993191310294494, -0.5996470376491001, -0.5998336368473983, -0.6000050783021862, -0.6001264210293705, -0.5994314768819733, -0.5994558599718652, -0.5996673174871542, -0.5994865239152413, -0.600055582501296, -0.5997147580317388, -0.6000820626853982, -0.5999870738319254, -0.599970457535037, -0.5999529739532136, -0.5997455842357683, -0.5996567358290663, -0.5995680781531214, -0.5986330478012472, -0.599540279625285, -0.5995136060368729, -0.5994769168375882, -0.5997305651817384, -0.5993400216702344, -0.5996168432632142, -0.5993652711212681, -0.5994493464233476, -0.5996335336812972]
# Generation 0
# Max fitness value -0.5961282673448671
# Generation 10
# Max fitness value 0.961453023500267
# Generation 20
# Max fitness value 0.9949465000875852
# Generation 30
# Max fitness value 0.9955678553585511
# Generation 40
# Max fitness value 0.9956018964263722
# Generation 50
# Max fitness value 0.9956018964263722
# Generation 60
# Max fitness value 0.9956018964263722
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  184.71845507621765  seconds
# Initial fitness:
#  [-0.6001797085384966, -0.6001701852765514, -0.6002752143245209, -0.6001755891108732, -0.6000292979358527, -0.6000748529763532, -0.6002394456616638, -0.6001250346203518, -0.6000278603794769, -0.6000461677543344, -0.6001055372189226, -0.6001310551546384, -0.6001494448979686, -0.6004914823358504, -0.6000731622811668, -0.6001058334447409, -0.6004610001988092, -0.6002286508320526, -0.6000339458315145, -0.6002468641272469, -0.6001174824200689, -0.600028090465519, -0.6001500820998595, -0.6001724050725681, -0.6001370799693697, -0.6001585943640362, -0.6000056181574651, -0.6001677177384371, -0.6001022745441899, -0.6000181798239332, -0.6001856724128265, -0.6001335959882712, -0.6000446567231503, -0.6000809248040181, -0.6000359407966648, -0.6001302506465143, -0.6003493104793862, -0.6001489422673028, -0.6004505822997378, -0.6000670645242663, -0.6000230337281411, -0.6000663658888362, -0.6000392955947484, -0.6001836996387266, -0.6000837820109535, -0.6001725672982667, -0.60014838777633, -0.600128789218017, -0.6001617563550783, -0.600212180142652]
# Generation 0
# Max fitness value -0.6000056181574651
# Generation 10
# Max fitness value -0.6000056181574651
# Generation 20
# Max fitness value -0.6000056181574651
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  89.42580986022949  seconds
# Initial fitness:
#  [-0.6002858642887043, -0.6001007119501619, -0.6004734804280412, -0.6002360481190774, -0.6001952591945354, -0.6002600945280391, -0.6001517410944215, -0.6002644444101952, -0.6001684455762197, -0.6001061934695368, -0.6001295659484724, -0.6000612481614979, -0.6001233251256202, -0.6004543098745068, -0.600191040020773, -0.600133767104277, -0.6000091233245305, -0.6004808034024491, -0.6000446590954959, -0.6002774341218595, -0.60014158118623, -0.6002059402489348, -0.6000504145112658, -0.6003953876168626, -0.6002305212871832, -0.60027826266871, -0.6000763060911359, -0.6000474170016963, -0.6000706226622228, -0.6001385734809424, -0.600198810719033, -0.6004051430503295, -0.600359464175809, -0.6002136613601806, -0.600702281399248, -0.6000303317721662, -0.6000390271017271, -0.6000647708784891, -0.6001499383468275, -0.600350368275453, -0.6001439617540105, -0.600266937158855, -0.6001171619436321, -0.6002599703351852, -0.6001215167519555, -0.6000414262650063, -0.600092093793009, -0.6000816114449473, -0.6002229038331478, -0.600138593835101]
# Generation 0
# Max fitness value -0.6000091233245305
# Generation 10
# Max fitness value -0.6000091233245305
# Generation 20
# Max fitness value -0.6000091233245305
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  89.2366259098053  seconds
# Initial fitness:
#  [-0.5951454160179365, -0.5943315744875322, -0.5877408308840345, -0.5912234469932293, -0.5928780565789541, -0.5844656650699338, -0.5735547183320882, -0.594997020199995, -0.5940825057696748, -0.5942303382228867, -0.5937300675645454, -0.5924556636997717, -0.5930423962051995, -0.5927646218122089, -0.5949046092454251, -0.5937604645646299, -0.5924404252431741, -0.590302698019308, -0.594627592563849, -0.5932390814685645, -0.5930196547992859, -0.5948605319216671, -0.5910057049753599, -0.5942355799607799, -0.5937596276322085, -0.5900308521753219, -0.592115721143598, -0.5872343127988802, -0.5922409184351377, -0.5925764643050639, -0.594475635435218, -0.5931979815627215, -0.5941428334757999, -0.5843137087172987, -0.5871073620128857, -0.5927650314257622, -0.5914296814584271, -0.5905663876452292, -0.5964676980073238, -0.592207322200752, -0.5921857189742429, -0.5924867276128093, -0.5908503876663863, -0.5938164139040534, -0.5925560186744193, -0.5813833558381759, -0.5814463884994896, -0.5921873753494576, -0.5942736770717675, -0.5929925317964335]
# Generation 0
# Max fitness value -0.5519342320512496
# Generation 10
# Max fitness value 0.8953142259246626
# Generation 20
# Max fitness value 0.983340043221955
# Generation 30
# Max fitness value 0.9924530730750851
# Generation 40
# Max fitness value 0.9934186411581202
# Generation 50
# Max fitness value 0.9936121293125164
# Generation 60
# Max fitness value 0.9938368840468058
# Generation 70
# Max fitness value 0.9938907477232702
# Generation 80
# Max fitness value 0.9941265433227793
# Generation 90
# Max fitness value 0.9942815938325114
# Generation 100
# Max fitness value 0.9943892542748772
# Generation 110
# Max fitness value 0.9943919193432245
# Generation 120
# Max fitness value 0.9945410709414026
# Generation 130
# Max fitness value 0.9945559476591858
# Generation 140
# Max fitness value 0.9946243755885241
# Generation 150
# Max fitness value 0.9947258921336768
# Generation 160
# Max fitness value 0.9947298243964416
# Generation 170
# Max fitness value 0.9947429142415463
# Generation 180
# Max fitness value 0.9947944489173863
# Generation 190
# Max fitness value 0.9949336892104865
# Generation 200
# Max fitness value 0.9949336892104865
# Generation 210
# Max fitness value 0.9949336892104865
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 2
# predicted label: 3
# Time:  643.9055881500244  seconds
# Initial fitness:
#  [0.704874560609535, 0.553979541553128, 0.5779787202190255, 0.38633333802713354, 0.8245759691227468, 0.5827011532286778, 0.41292212447610177, 0.5439951542871989, 0.5976918887689912, 0.8073876498396713, 0.6133572075078326, 0.6906550697392869, 0.5134617042733084, 0.6436522403159273, 0.5707709318555549, 0.5435720359371731, 0.6296182595260864, 0.5145810699303954, 0.7623112678958796, 0.41417739875269316, 0.5707774949856683, 0.7156150429423225, 0.562426730030791, 0.5123042372289264, 0.2504175458723268, 0.5907753029785099, 0.6149429785646882, 0.6303596739834175, 0.6238884907382212, 0.6014554614958891, 0.39029704923125896, 0.6103524947879195, 0.5800236276626936, 0.5591738640169372, 0.5973085239513637, 0.5339836167686421, 0.5720689634392636, 0.6618496830213043, 0.4969840479649056, 0.7826051144878627, 0.7327598602075284, 0.38913968362926715, 0.6742474961061962, 0.5406898033153666, 0.6403877736682854, 0.4849457467752316, 0.6933897019692639, 0.6004022991789805, 0.5783530501696965, 0.39940599510747665]
# Generation 0
# Max fitness value 0.9523754658895609
# Generation 10
# Max fitness value 0.9947685954827421
# Generation 20
# Max fitness value 0.9950269113557226
# Generation 30
# Max fitness value 0.9950269113557226
# Generation 40
# Max fitness value 0.9950269113557226
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 2
# predicted label: 6
# Time:  129.8587942123413  seconds
# Initial fitness:
# ...
# Generation 0
# Max fitness value -0.6000136833828235
# Generation 10
# Max fitness value -0.6000136833828235
# Generation 20
# Max fitness value -0.6000136833828235
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 9
# Time:  88.88789463043213  seconds
# Initial fitness:
#  [-0.4575432570814161, -0.466587398958099, -0.49165041443229096, -0.4966246192145536, -0.47893739521958856, -0.5241726337110527, -0.4733842655309305, -0.5137480698944555, -0.48643680949136836, -0.4847680733931514, -0.428855622941577, -0.5239352892474755, -0.4513862623597952, -0.5003597230047527, -0.5221391208458173, -0.5055767169686384, -0.4957829969564028, -0.4760555933985926, -0.4535784889734421, -0.5015563722256752, -0.5008035758323484, -0.47519636508471297, -0.5042097862826604, -0.4706221759095701, -0.5032641202772523, -0.3729964052947541, -0.5002052594560766, -0.5336401138155619, -0.5137491838722812, -0.4787039314178929, -0.48248721056785143, -0.44868664224465293, -0.48270161344170204, -0.4552141947862075, -0.490259302384498, -0.49035172073221656, -0.4416575874987193, -0.5393631838268669, -0.47211932065544804, -0.4431264281416, -0.46924932427889915, -0.4821646163153649, -0.5257906714311675, -0.49920880576117543, -0.44856448611811334, -0.5316673214901743, -0.46010580343227026, -0.4611965580479702, -0.5161175838789036, -0.4833243494623884]
# Generation 0
# Max fitness value -0.2889734902427912
# Generation 10
# Max fitness value 0.9058228464299561
# Generation 20
# Max fitness value 0.9886210911925885
# Generation 30
# Max fitness value 0.9899808823045941
# Generation 40
# Max fitness value 0.9907993788865535
# Generation 50
# Max fitness value 0.9914133080125098
# Generation 60
# Max fitness value 0.9917269230117102
# Generation 70
# Max fitness value 0.9919807511426855
# Generation 80
# Max fitness value 0.991990633445148
# Generation 90
# Max fitness value 0.991990633445148
# Generation 100
# Max fitness value 0.9921713790836197
# Generation 110
# Max fitness value 0.992308178860742
# Generation 120
# Max fitness value 0.992308178860742
# Generation 130
# Max fitness value 0.9923748391971807
# Generation 140
# Max fitness value 0.9924048134060195
# Generation 150
# Max fitness value 0.99246528358866
# Generation 160
# Max fitness value 0.99246528358866
# Generation 170
# Max fitness value 0.992552761795903
# Generation 180
# Max fitness value 0.992552761795903
# Generation 190
# Max fitness value 0.9925537870529542
# Generation 200
# Max fitness value 0.9925800600506904
# Generation 210
# Max fitness value 0.9925907169904503
# Generation 220
# Max fitness value 0.9926076726060445
# Generation 230
# Max fitness value 0.9926848650161963
# Generation 240
# Max fitness value 0.9926848650161963
# Generation 250
# Max fitness value 0.9926848650161963
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  770.9089086055756  seconds
# Initial fitness:
#  [-0.5998789288304136, -0.5997422448768652, -0.5998524785418577, -0.5999240098666816, -0.5997535290120151, -0.5998378480344129, -0.599873645390034, -0.5998631745352686, -0.5999084267259434, -0.6000031370174672, -0.5998165874092496, -0.6000299473909838, -0.5997236248916094, -0.5998240493612429, -0.599956014039147, -0.5998160225574147, -0.5998161823793722, -0.5999837716088596, -0.5998498217016393, -0.5997912155571049, -0.5997402009303692, -0.5997451990672888, -0.5997838505277464, -0.5999991426433928, -0.5997428898621474, -0.5999081376757264, -0.5999208427335265, -0.5998982827254744, -0.5997720187917599, -0.599901797850354, -0.5999224507877685, -0.5998176350558526, -0.5997750076772304, -0.5998115854556285, -0.5997780943877703, -0.5995966722841941, -0.599956668195547, -0.5998798989651875, -0.5998926561916494, -0.5997758277364997, -0.5997684265382329, -0.599760631688603, -0.5998305057168928, -0.599858607720311, -0.5999055427527533, -0.5997642478910338, -0.6000655542549477, -0.5998395524693743, -0.5999658634983395, -0.5998910454735592]
# Generation 0
# Max fitness value -0.5995505067151923
# Generation 10
# Max fitness value -0.4518176930887978
# Generation 20
# Max fitness value 0.8931248312827709
# Generation 30
# Max fitness value 0.9890233191703437
# Generation 40
# Max fitness value 0.9939255532975123
# Generation 50
# Max fitness value 0.9943554640433192
# Generation 60
# Max fitness value 0.9944931166780703
# Generation 70
# Max fitness value 0.9945540164255952
# Generation 80
# Max fitness value 0.9945540164255952
# Generation 90
# Max fitness value 0.9947141033247137
# Generation 100
# Max fitness value 0.9947339163624096
# Generation 110
# Max fitness value 0.9947448982706336
# Generation 120
# Max fitness value 0.9947574483897675
# Generation 130
# Max fitness value 0.9947864455071501
# Generation 140
# Max fitness value 0.9948673905617362
# Generation 150
# Max fitness value 0.9948673905617362
# Generation 160
# Max fitness value 0.9948673905617362
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  489.32224130630493  seconds
# Initial fitness:
#  [-0.532332369101334, -0.5108781639182614, -0.5197264181631573, -0.5114863582466953, -0.4851445991570431, -0.5251193783867556, -0.521961093397878, -0.5323769992258103, -0.5192068126085263, -0.5170820293420724, -0.5166723173044038, -0.5000862555247967, -0.5165483967481073, -0.5170771945375162, -0.5322968567386017, -0.5313095980916375, -0.49664678388956207, -0.5378480959939198, -0.5179970634709178, -0.43138387733816147, -0.5252755873241606, -0.5067966025666524, -0.5353193456989348, -0.5277782634733346, -0.5214849758519893, -0.49817497292732627, -0.4860687592837224, -0.5211859743751426, -0.49503774851710214, -0.5250585116105749, -0.5112252598383168, -0.5303482191877773, -0.5278877295368986, -0.5374230133894, -0.5091006342486295, -0.49255548811324057, -0.5210590738866544, -0.5173053311865581, -0.5477244928119035, -0.5412483089634365, -0.5104302510327101, -0.5305169991065011, -0.45892977067248136, -0.5223819036852867, -0.5471367719670879, -0.5198491036248161, -0.517246767291704, -0.5265462783518426, -0.5143162956961598, -0.5284602435639404]
# Generation 0
# Max fitness value -0.3575564066590886
# Generation 10
# Max fitness value 0.7257975575814996
# Generation 20
# Max fitness value 0.9417985603013739
# Generation 30
# Max fitness value 0.9874331268158623
# Generation 40
# Max fitness value 0.9937632911686158
# Generation 50
# Max fitness value 0.9946152978658089
# Generation 60
# Max fitness value 0.9949410505334988
# Generation 70
# Max fitness value 0.9950567579633045
# Generation 80
# Max fitness value 0.9950864522892955
# Generation 90
# Max fitness value 0.9950864522892955
# Generation 100
# Max fitness value 0.9953574429264708
# Generation 110
# Max fitness value 0.9953574429264708
# Generation 120
# Max fitness value 0.9953574429264708
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 0
# Time:  382.5965838432312  seconds
# Initial fitness:
#  [-0.5981034709800889, -0.5954644685048138, -0.5974433024211057, -0.5975836190225482, -0.5977417620033638, -0.5979174673671906, -0.5973627226699045, -0.5984280114381776, -0.5974415627878374, -0.5986146502153182, -0.59832377744333, -0.5980160024804138, -0.5989520999080558, -0.5966445326958959, -0.5987950326973401, -0.5984079508149316, -0.5984711559074942, -0.597617294850667, -0.5983030431280778, -0.5985311315926511, -0.5989989940053323, -0.5968214622138887, -0.5960821882335274, -0.5943006693939547, -0.5986351576445125, -0.5975226750053318, -0.5985409678301696, -0.5971494907503307, -0.5976853481338875, -0.5982518424609427, -0.5981952548388547, -0.5982677663903093, -0.5970934748147334, -0.5983183637384393, -0.5967886967035995, -0.5987505254041737, -0.5962530001131164, -0.598495005559584, -0.598154874808876, -0.5908663255346793, -0.5970578596558658, -0.5978887462134999, -0.5983534550727457, -0.5978035700489236, -0.5980859807570648, -0.5979840511821524, -0.598095462467503, -0.5972326439534124, -0.5975617890857101, -0.5987192407311348]
# Generation 0
# Max fitness value -0.5884776541439282
# Generation 10
# Max fitness value 0.9007538631909336
# Generation 20
# Max fitness value 0.9941267633102864
# Generation 30
# Max fitness value 0.9947003556595808
# Generation 40
# Max fitness value 0.994710508292216
# Generation 50
# Max fitness value 0.995013324974162
# Generation 60
# Max fitness value 0.9951900866535474
# Generation 70
# Max fitness value 0.9951932276669856
# Generation 80
# Max fitness value 0.9952610599259755
# Generation 90
# Max fitness value 0.9952610599259755
# Generation 100
# Max fitness value 0.9952610599259755
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  309.0465567111969  seconds
# Initial fitness:
#  [0.12081491605095963, -0.019059391869862025, 0.09544015996768002, 0.4312063861481911, 0.04289100495741377, 0.12493446336317295, -0.048620274662894564, 0.21424812156823628, 0.22265530705554282, 0.21143782727834154, 0.017037982213229413, 0.21997541097320783, 0.18118849180522156, -0.012752044205188884, 0.419223889968909, 0.15888376414328925, 0.16083851622078477, 0.26889175912979546, 0.09347908501657981, 0.22596024713022597, 0.27951571297972333, 0.24931300098216927, 0.050921142328619634, 0.23828001982550417, 0.1451396854711011, 0.13806138543959667, 0.19371642417207718, 0.08728343433046548, 0.08403887448053401, 0.29310487601308227, 0.22657943526705115, 0.17490752925393113, 0.2074025501095872, 0.19307598843848764, 0.13943019141013757, 0.1282953338343563, 0.016019002151333922, 0.10634633289500033, 0.1455085940621722, 0.0683501882055497, 0.2202404629559816, -0.014808592724591674, 0.1572403161819511, 0.07001157934305055, 0.38677468016213645, 0.04338667683298472, 0.22888063908349027, 0.10436271092359314, 0.2326872737581847, 0.13700956532027975]
# FOUND ADVERSARIAL
# Fitness of the adversarial 0.5935946399037868
# Adversarial example image:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 7
# Time:  3.6972899436950684  seconds
# Initial fitness:
#  [-0.6002774007631547, -0.6003253700754021, -0.6003688786177834, -0.6000298011554459, -0.6000077381374304, -0.6003605368896894, -0.6001017944129936, -0.6016822792674564, -0.600251825394837, -0.6003049413167683, -0.6000186272832316, -0.6000926095737809, -0.603483446420393, -0.6009539340760015, -0.6001711866672577, -0.6000197448051625, -0.600128043038273, -0.6001361467109058, -0.600314498501458, -0.6000522450347257, -0.600695974072964, -0.6005034230670517, -0.6000901281295324, -0.6002357348984679, -0.6008031673117151, -0.6021239609953444, -0.6018492937567799, -0.6000703656811707, -0.6002359043176614, -0.6001677920449094, -0.6001685261998699, -0.6005849014180172, -0.6008994679190063, -0.6007274265390885, -0.6007085994365022, -0.6001978925855654, -0.6000838350333445, -0.600024646469557, -0.6006964839859512, -0.600105601356207, -0.6004174192793623, -0.6003118218251816, -0.600274569089663, -0.6000554961442524, -0.6001925756744798, -0.6000385187679628, -0.6041875785436001, -0.6000861880393746, -0.6001506052191847, -0.600148282938624]
# Generation 0
# Max fitness value -0.5999546664284927
# Generation 10
# Max fitness value 0.8192756723470451
# Generation 20
# Max fitness value 0.9937386763634521
# Generation 30
# Max fitness value 0.9941270787598872
# Generation 40
# Max fitness value 0.9941270787598872
# Generation 50
# Max fitness value 0.9941270787598872
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 6
# Time:  171.82275819778442  seconds
# Initial fitness:
#  [-0.6002208374763457, -0.6000529473376304, -0.6004315694435788, -0.6000560527763565, -0.6000215217866902, -0.600336791663214, -0.6000436947788892, -0.600198281562353, -0.6005438402824976, -0.6001665765827392, -0.6001693363536048, -0.6001106319683387, -0.6000655664987425, -0.6003055800331007, -0.6000291429703556, -0.6002793152150453, -0.600215410779676, -0.60019929965287, -0.600175242840282, -0.6003691837585815, -0.6001138427810442, -0.6000807782148703, -0.600221611661041, -0.6007072880427979, -0.600042403329178, -0.6002803676987588, -0.6002689149977847, -0.600245408298815, -0.6006646167564079, -0.6000972382161444, -0.6002105265869521, -0.6003249833759667, -0.6005964690261518, -0.6001613258561691, -0.6002173941265214, -0.6010685424051955, -0.6002756514486456, -0.600078105087375, -0.6000756194333007, -0.6001344089884503, -0.601298069643226, -0.6002368617575589, -0.6000341426847446, -0.6001565411572741, -0.6001062146319456, -0.6003830203795724, -0.600480432829188, -0.6001921236975447, -0.6001166637432628, -0.6002644547276492]
# Generation 0
# Max fitness value -0.6000215217866902
# Generation 10
# Max fitness value -0.5937161090898074
# Generation 20
# Max fitness value 0.3435422145544257
# Generation 30
# Max fitness value 0.9668942979882358
# Generation 40
# Max fitness value 0.990637421204413
# Generation 50
# Max fitness value 0.9916909553121132
# Generation 60
# Max fitness value 0.9917562848765976
# Generation 70
# Max fitness value 0.9918365634781579
# Generation 80
# Max fitness value 0.9920136626000257
# Generation 90
# Max fitness value 0.9920250806604263
# Generation 100
# Max fitness value 0.9922903612725592
# Generation 110
# Max fitness value 0.9923793911056519
# Generation 120
# Max fitness value 0.9924805905486507
# Generation 130
# Max fitness value 0.992582264102393
# Generation 140
# Max fitness value 0.992582264102393
# Generation 150
# Max fitness value 0.9925845589892952
# Generation 160
# Max fitness value 0.9925845589892952
# Generation 170
# Max fitness value 0.9925845589892952
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 8
# Time:  511.5336883068085  seconds
# Initial fitness:
#  [0.15902986964064914, -0.17279657662474487, 0.2917479840774197, 0.4766038132458139, 0.04611797185237071, 0.3991169562662251, -0.05675356988877445, 0.4689286351693306, 0.34079532199748364, 0.4097363223895891, 0.23431054605976634, 0.3809898815687397, 0.14746595970698584, 0.4714657893988733, 0.339354970494942, 0.14185135752757708, 0.2924870545705049, 0.37762006895982847, 0.32279531355929736, 0.3778711120229426, 0.273056793861127, 0.21713241202549688, 0.42931132003388306, 0.4231934895710358, 0.4215939861535425, 0.40276093816824815, 0.34134850972531894, 0.4225196099591892, 0.3766528299243139, 0.4004783262293924, 0.31452656338433704, 0.4103481201974982, 0.3563949690035255, 0.20676024338057816, 0.38848321949342335, 0.3108758300913488, 0.4363248719748254, 0.45911289766206165, 0.21240838415310612, 0.3557333171122785, 0.27835166454076643, 0.23340972715942637, 0.4505472280522748, 0.3142148779013216, 0.373557945440678, 0.38683262086976855, 0.3028975750179357, 0.37287117555107663, 0.35172757770367363, 0.3775370724398679]
# FOUND ADVERSARIAL
# Fitness of the adversarial 0.4766038132458139
# Generation 0
# Max fitness value 0.5843998656308433
# Generation 10
# Max fitness value 0.9900015898988264
# Generation 20
# Max fitness value 0.9958168704524637
# Generation 30
# Max fitness value 0.9962375831052415
# Generation 40
# Max fitness value 0.9963860908699185
# Generation 50
# Max fitness value 0.9964771336458814
# Generation 60
# Max fitness value 0.9964771336458814
# Generation 70
# Max fitness value 0.9964771336458814
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  216.65007281303406  seconds

# %% [markdown]
# # Save files

# %%
import pickle
file_ = open('GA_adv_cifar_ssim_Kcrossover', 'wb')
pickle.dump(evolved_examples, file_)
pickle.dump(times, file_)
pickle.dump(ssim_values, file_)
pickle.dump(fitness_of_evolved , file_)
pickle.dump(predicted_class, file_)
pickle.dump(number_of_rounds, file_)
file_.close()

print(f"Max time: {np.max(times)}")
print(f"Min time: {np.min(times)}")
print(f"Mean time: {np.mean(times)}")
print(f"Std time: {np.std(times)}\n")

print(f"Max fitness evolved: {np.max(fitness_of_evolved)}")
print(f"Min fitness evolved:: {np.min(fitness_of_evolved)}")
print(f"Mean fitness evolved: {np.mean(fitness_of_evolved)}")
print(f"Std fitness evolved:: {np.std(fitness_of_evolved)}\n")

print(f"Max ssim: {np.max(ssim_values)}")
print(f"Min ssim: {np.min(ssim_values)}")
print(f"Mean ssim: {np.mean(ssim_values)}")
print(f"Std ssim: {np.std(ssim_values)}\n")

print(f"Max round: {np.max(number_of_rounds)}")
print(f"Min rounds: {np.min(number_of_rounds)}")
print(f"Mean rounds: {np.mean(number_of_rounds)}")
print(f"Std rounds: {np.std(number_of_rounds)}\n")




print(f"Percentage of adversarial founds sucessfully : {numb_of_adv_found/len(adversarial_y)} %")
print(f"Percentage of adversarial founds after fitness not improving for 30 generations: {numb_of_found_after30/len(adversarial_y)} %")
# Out:
# Max time: 907.4285228252411
# Min time: 3.471324920654297
# Mean time: 279.98892218905286
# Std time: 169.84828316927394
#
# Max fitness evolved: 0.9991962911157247
# Min fitness evolved:: -0.6015598190818927
# Mean fitness evolved: 0.8789428622940207
# Std fitness evolved:: 0.4002652666994179
#
# Max ssim: 0.3002472756936275
# Min ssim: 2.8090787325241173e-05
# Mean ssim: 0.04057292569725542
# Std ssim: 0.04437958341615913
#
# Max round: 283
# Min rounds: 0
# Mean rounds: 92.45864661654136
# Std rounds: 54.96485702649275
#
# Percentage of adversarial founds sucessfully : 0.015037593984962405 %
# Percentage of adversarial founds after fitness not improving for 30 generations: 0.9849624060150376 %

# %% [markdown]
# Open adversarial

# %%
with open('./results/GA_adv_cifar_ssim_Kcrossover', 'rb') as f:
    evolved_examples = pickle.load(f)
    times= pickle.load(f)
    ssim_values = pickle.load(f)
    fitness_of_evolved = pickle.load(f)
    predicted_class = pickle.load(f)
    number_of_rounds = pickle.load(f)

# %%
#Correction of ssim values
new_ssim=[]
for s in ssim_values:
    new_ssim.append(1-s)
    
print(f"Max ssim: {np.max(new_ssim)}")
print(f"Min ssim: {np.min(new_ssim)}")
print(f"Mean ssim: {np.mean(new_ssim)}")
print(f"Std ssim: {np.std(new_ssim)}\n")
# Out:
# Max ssim: 0.9999719092126748
# Min ssim: 0.6997527243063725
# Mean ssim: 0.9594270743027448
# Std ssim: 0.04437958341615912

# %%
#Correctionf of rounds  (replacing 0 with 1)
number_of_rounds = np.where(np.array(number_of_rounds)==0, 1, number_of_rounds) 
number_of_rounds
# Out:
# array([ 96,  67,  48, 155, 134,  47, 171, 254, 115,  43,  65,  50,  68,
#        158,  66,  30,  68,  45,  95, 183,  55,  31,  63,  30,  30, 219,
#         44,  50,  70, 157,  43,  56,  62, 153, 158,  50,  30,  30, 157,
#         37,  57,  72, 117,  71,  79,  77,  53,  64,  65, 182,  59,  59,
#        113,   1,  72,  89,  39,  47,  53,  35,  78, 105,  52,  98,  58,
#         53,  46,  88,  66, 183,  54,  74,  96,  57, 166, 120, 105, 230,
#        110,  52,  30,  76,  47, 232,  94, 128, 170,  77, 174, 105, 283,
#         69, 109, 142,  49, 150,  80,  85,  87,  52,  55,  51, 102,  84,
#        120,  73, 161, 127,  64, 147, 170, 166,  51, 126,  58,  63,  30,
#         94,  49, 124, 141,  98,  56,  79,  30, 260, 165, 129, 104,   1,
#         58, 173,  73])

# %%
print(f"Max round: {np.max(number_of_rounds)}")
print(f"Min rounds: {np.min(number_of_rounds)}")
print(f"Mean rounds: {np.mean(number_of_rounds)}")
print(f"Std rounds: {np.std(number_of_rounds)}\n")
# Out:
# Max round: 283
# Min rounds: 1
# Mean rounds: 92.47368421052632
# Std rounds: 54.939690645571574

# %% [markdown]
# # Examples of what functions do

# %%
population = init_pop_from_sample(50,adversarial[15],adversarial_y[15][0])
fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),adversarial_y[15][0])
print(fitness)

# %%
plt.imshow(population[0].reshape(CIFAR_IMG,CIFAR_IMG))
plt.show()
print(f"Class for this {adversarial_y[15][0]}")
print(model.predict(population[0].reshape(1,CIFAR_IMG,CIFAR_IMG,1) /255.0))
# Out:
# Class for this 1
# [[2.2063480e-10 1.0000000e+00 6.6041472e-14 3.5760719e-12 3.9276270e-13
#   1.1313486e-13 8.8119643e-13 6.8588521e-13 1.9681285e-13 3.7839783e-08]]

# %%
parent1 = tournament(population, model, adversarial[15], adversarial_y[15]) 
parent2 = tournament(population, model, adversarial[15], adversarial_y[15])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/skimage/measure/_structural_similarity.py:17: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   **kwargs)

# %%
fd, idx =  plt.subplots(1,2)
idx[0].imshow(parent1.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")
idx[1].imshow(parent2.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")

# %%
child1, child2 = multi_crossover(parent1, parent2,adversarial[15]) # crossover 
#child1, child2 = add_noise(child1), add_noise(child2) # apply mutation to pixels
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/skimage/measure/_structural_similarity.py:17: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   **kwargs)

# %%
fd, idx =  plt.subplots(1,2)
idx[0].imshow(child1.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")
idx[1].imshow(child2.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")

# %%
print(f"diff between children {np.unique(child1-child2)}")
print(f"diff between parents {np.unique(parent1-parent2)}")
print(f"diff between p1 and c1 {np.unique(parent1-child1)}")
print(f"diff between p1 and c2 {np.unique(parent1-child2)}")
print(f"diff between p2 and c1 {np.unique(parent2-child1)}")
print(f"diff between p2 and c2 {np.unique(parent2-child2)}")

# %%
bb = choose_better_child(child1, child2,adversarial[15],adversarial_y[15][0],model)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/skimage/measure/_structural_similarity.py:17: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   **kwargs)

# %%
fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label) 
print(fitness)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/skimage/measure/_structural_similarity.py:17: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   **kwargs)
# [-0.26002962878595726, -0.25999958545736684, -0.26007314251448344, -0.26004007622401076, -0.26003266487525345, -0.26011373574731095, -0.2599816460817825, -0.25998496480763594, -0.2600353571926644, -0.2600021864303609, -0.260040721413234, -0.2600228430135187, -0.26003768485830203, -0.26002701209750284, -0.26006302743228543, -0.2599796432991168, -0.2600043346069123, -0.26003024147792836, -0.2600466627237271, -0.26003812318804226, -0.2600652442884724, -0.2600447098702882, -0.2600085762943468, -0.26001327339828323, -0.2599806557454484, -0.26007237070197037, -0.25996000471207786, -0.2600457997287944, -0.2600101441535663, -0.26005323947618036, -0.2600554130353725, -0.2600860828123626, -0.26003997918862914, -0.26004537198733424, -0.2600515291553301, -0.2600503663988854, -0.26001231736237695, -0.2600170667581806, -0.2600851316879575, -0.2599960477747653, -0.260017809873727, -0.2600171997460062, -0.2600455137861651, -0.26001145913341955, -0.2600466317811507, -0.2600557191632309, -0.26006128108305554, -0.2599700462660023, -0.26005349311420517, -0.2600591984831575]
