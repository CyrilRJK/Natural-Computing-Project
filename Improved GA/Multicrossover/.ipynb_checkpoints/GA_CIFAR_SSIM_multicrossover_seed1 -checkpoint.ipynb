# %% [markdown]
# # IMPORT

# %% [markdown]
# In this notebook I did not normalized images before evolving, just when predicting

# %%
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
import pickle
import time
from skimage.measure import compare_ssim
import tensorflow as tf
from keras.models import Model,load_model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input, Activation
from keras.utils import to_categorical
import keras
import random
# Out:
# Using TensorFlow backend.

# %%
#Set seeds
random.seed(1)
np.random.seed(1)

# %% [markdown]
# # GLOBAL VARS

# %%
INDIVIDUALS = 50
P_CROSS = 0.8
P_MUTATION = 0.01
CIFAR_IMG= 32

# %% [markdown]
# # THE DATA

# %%
from keras.datasets import cifar10

# The data, split between train and test sets:
(x_train_C, y_train_C), (x_test_C, y_test_C) = cifar10.load_data()
print('x_train shape:', x_train_C.shape)
print(x_train_C.shape[0], 'train samples')
print(x_test_C.shape[0], 'test samples')

# Convert class vectors to binary class matrices.
num_classes=10
epochs=10
img_shape=32 
y_train_C = to_categorical(y_train_C, num_classes)
y_test_C = to_categorical(y_test_C, num_classes)


input_shape=(32,32,1)

x_train_C = x_train_C.astype('float32')
x_test_C = x_test_C.astype('float32')
x_train_C /= 255
x_test_C /= 255


print('x_train shape:', x_train_C.shape)
print('Number of images in x_train', x_train_C.shape[0])
print('Number of images in x_test', x_test_C.shape[0])
print('y_train shape:', y_train_C.shape)
print("input shape: ",input_shape)


# CONVERT TO GRAY SCALE

import matplotlib.pyplot as plt
import numpy as np

def grayscale(data, dtype='float32'):
    # luma coding weighted average in video systems
    r, g, b = np.asarray(.3, dtype=dtype), np.asarray(.59, dtype=dtype), np.asarray(.11, dtype=dtype)
    rst = r * data[:, :, :, 0] + g * data[:, :, :, 1] + b * data[:, :, :, 2]
    # add channel dimension
    rst = np.expand_dims(rst, axis=3)
    return rst

x_train_C = grayscale(x_train_C)
x_test_C = grayscale(x_test_C)

# now we have only one channel in the images
img_channels = 1
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# x_train shape: (50000, 32, 32, 3)
# Number of images in x_train 50000
# Number of images in x_test 10000
# y_train shape: (50000, 10)
# input shape:  (32, 32, 1)

# %% [markdown]
# # READ PICKLE FILES

# %%
with open('../../Subsets/subset_cifar', 'rb') as f:
    original = pickle.load(f)
    adversarial= pickle.load(f)
    original_y = pickle.load(f)
    adversarial_y = pickle.load(f)

# %%
print(f"Original shape {original.shape}")
print(f"Adversarial shape {adversarial.shape}")
print(f"Original labels shape {original_y.shape}")
print(f"Adversarial labels shape {adversarial_y.shape}")
# Out:
# Original shape (914, 32, 32, 1)
# Adversarial shape (133, 32, 32, 1)
# Original labels shape (914, 1)
# Adversarial labels shape (133, 1)

# %% [markdown]
# # LOAD THE MODEL

# %% [markdown]
# 3. CNN v2
#
# This network is made for CIFAR 10. The network is taken from [this blog]( https://appliedmachinelearning.blog/2018/03/24/achieving-90-accuracy-in-object-recognition-task-on-cifar-10-dataset-with-keras-convolutional-neural-networks/) . In this version below I didn't use some things used in the blog e.g. z-score and data augmentation.
#
#
# This network has training accuracy: 0.8940 , validation accuracy: 0.8245.
#
# **NOTE:** Training really slow, try to avoid it.

# %%
# Network 3 
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np

input_shape = (CIFAR_IMG,CIFAR_IMG,1)
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=input_shape))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
 
model.summary()


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


'''
history = model.fit(x=x_train_C,y=y_train_C, epochs=150, batch_size=64, validation_data=[x_test_C,y_test_C])

score= model.evaluate(x_test_C, y_test_C,verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save_weights("CNN_CIFAR10_net3.h5")
files.download('CNN_CIFAR10_net3.h5')
'''

model = load_model("../../Models/CNN_CIFAR10_net3.h5")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        320
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 308,714
# Trainable params: 307,818
# Non-trainable params: 896
# _________________________________________________________________

# %%
model

# %% [markdown]
# # GENETIC ALGORITHM FUNCTIONS

# %%
def computing_SSIM(individual,target):
    return compare_ssim(individual.reshape(CIFAR_IMG,CIFAR_IMG), target.reshape(CIFAR_IMG,CIFAR_IMG))

def calculate_fitness(model,ind,target_image,label,l1=0.2, l2=0.8, N=50, num_classes=10):
  # predict the population
  predictions=model.predict(ind.reshape(1,CIFAR_IMG,CIFAR_IMG,1) / 255.0)  
  # po is the ground truth prediction, so for label = 0, it will be prediciton[0]
  predictions=predictions[0]
  po=predictions[label]
  # set that value to 0
  predictions[label]=0
  # take next highest one
  pd = np.max(predictions)
  diff=pd-po
  return l1*computing_SSIM(ind.reshape(CIFAR_IMG,CIFAR_IMG),target_image.reshape(CIFAR_IMG,CIFAR_IMG)) +l2*(diff)
  


def pop_fitness(model,pop,target,label):
    return [calculate_fitness(model, p, target, label) for p in pop]

def flatten(imgs):
    # flatten all images in np array or list
    return np.array([im.flatten() for im in imgs])

def gaussian_noise():
    # draw one sample of noise from zero mean 1 variance Gaussian
    return np.random.normal(0, 10)

def p_noise(x):
  if 0.01 > np.random.uniform():
    return x + gaussian_noise()
  else:
    return x
    
def add_noise(image):
    noise_v=np.vectorize(p_noise)
    return noise_v(image) #np.array([x + gaussian_noise() if P_MUTATION > np.random.uniform(0.0, 1.0) else x+0 for x in image])

def k_crossover(im1, im2, k=2):
    c1, c2 = [], []
    # get k crossover points
    points = sorted([np.random.randint(0, CIFAR_IMG*CIFAR_IMG-1, 1) for p in range(k)])
    points = sorted([np.random.randint(0,CIFAR_IMG*CIFAR_IMG-1,1) for p in range(k)])
    im_1_split = np.split(im1, [int(p) for p in points])
    im_2_split = np.split(im2, [int(p) for p in points])
    
    # alternate between lists to realise crossover (theres got to be a more clever way to do this)
    for i in range(k+1):
        if i % 2 == 0:
            c1.append(im_1_split[i])
            c2.append(im_2_split[i])
        else:
            c1.append(im_2_split[i])
            c2.append(im_1_split[i])
    return np.concatenate(c1, axis=0), np.concatenate(c2, axis=0)

def tournament(pop, model, ground_truth, target, k=3):

    indices = np.random.choice(range(len(pop)), k, replace=False) #we get 3 indxes [2 34 46]    
    individuals = pop.take(indices,axis=0)
    scores = pop_fitness(model,np.expand_dims(individuals.reshape(individuals.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3), ground_truth.reshape(CIFAR_IMG,CIFAR_IMG), target)
    index_max = np.argmax(scores)
    winner = individuals[index_max]
    return winner


def check_adv_termination(ind, label,ground_truth, model):
  # individual - the best one from the generation
  # label - class we want
  # ground_truth - the image (32,32)
  # model we are using 
  dist = 1-compare_ssim(ind.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG))
  predictions= model.predict(ind.reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0)
  predicted_label= np.argmax(predictions[0])
  if label != predicted_label and dist < 0.001:
    print("FOUND ADVERSARIAL")
    print(f"Fitness of the adversarial {calculate_fitness(model,ind,ground_truth,label)}")
    return ind
  return []

def init_pop_from_sample(n,img,label):
    x = np.array([add_noise(img) for i in range(n)])
    return x.reshape(n, CIFAR_IMG*CIFAR_IMG)

def uniform(p1, p2):
    LEN=1024
    for i in range(LEN):
        if np.random.uniform() > P_CROSS:
            a = p1[i]
            p1[i] = p2[i]
            p2[i] = a
    return p1, p2

# %%
''' my part of the code ''' 
''' I know it is ugly, I will fix it . this is the intial version'''
# from Goorge Clooney paper
def quadrant_crossover(parent_1,parent_2):

  # reshape parents
  parent_1,parent_2= parent_1.reshape((CIFAR_IMG,CIFAR_IMG)), parent_2.reshape((CIFAR_IMG,CIFAR_IMG))
  # quadrants for both parents
  p1,p2,p3,p4,q1,q2,q3,q4 = [],[],[],[],[],[],[],[]
  child1, child2 = [],[]
  # getting random (x,y) point in 2D matrix
  x,y = np.random.randint(0,CIFAR_IMG-1), np.random.randint(0,CIFAR_IMG-1)  

  # choose which quadrant we want to crossover
  N = np.random.randint(0,3)
  #make quadrants
  for i in range(CIFAR_IMG):
    if (i<=x):
      p1.append(parent_1[i][:y+1])
      p2.append(parent_1[i][y+1:])
      q1.append(parent_2[i][:y+1])
      q2.append(parent_2[i][y+1:])
    else:
      p3.append(parent_1[i][:y+1])
      p4.append(parent_1[i][y+1:])
      q3.append(parent_2[i][:y+1])
      q4.append(parent_2[i][y+1:])

  if (N==0):
    ch1 = connect_quadrants(p1,q2,q3,q4)
    ch2 = connect_quadrants(q1,p2,p3,p4)
  elif (N==1):
    ch1 = connect_quadrants(q1,p2,q3,q4)
    ch2 = connect_quadrants(p1,q2,p3,p4)
  elif (N==2):
    ch1 = connect_quadrants(q1,q2,p3,q4)
    ch2 = connect_quadrants(p1,p2,q3,p4)
  else:
    ch1 = connect_quadrants(q1,q2,q3,p4)
    ch2 = connect_quadrants(p1,p2,p3,q4)

  return ch1,ch2

def connect_quadrants(q1,q2,q3,q4):
  left = np.concatenate((q1,q3))
  right = np.concatenate((q2,q4))
  image = np.concatenate((left,right),axis=1)
  return image.flatten()


def multi_crossover(parent1,parent2,target):
  pop= []
  # 2-k crossover
  pop.append(k_crossover(parent1, parent2))
  # Gorge Clooney crossover
  pop.append(quadrant_crossover(parent1,parent2))
  # uniform crossover
  pop.append(k_crossover(parent1, parent2,1))
  pop.append(uniform(parent1,parent2))
  # SSIM similarity 
  flattened_list = [y for x in pop for y in x] # need to flatten the list because pop is list of lists, cause every crossover function returns 2 obj
  ssim = [computing_SSIM(ind,target) for ind in flattened_list ]
  # taking the index of largest two score
  id1=np.argmax(ssim)
  ssim[id1]=0
  id2 = np.argmax(ssim)
  #returning parents
  return flattened_list[id1],flattened_list[id2]

# %%
def return_best_individual(pop,fitness):
  index = np.argmax(fitness)
  best = pop[index]
  return best, np.max(fitness)

# %%
def choose_better_child(ch1, ch2,ground_truth,label,model):
  # I named it better child, but we choose by this parents as well
  ch1_f = calculate_fitness(model,ch1.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG),label)
  ch2_f = calculate_fitness(model,ch2.reshape(CIFAR_IMG,CIFAR_IMG),ground_truth.reshape(CIFAR_IMG,CIFAR_IMG),label)
  # change this into ternary operator
  if ch1_f>ch2_f:
    return ch1
  else:
    return ch2

# %% [markdown]
# # THE MAIN LOOP

# %%
'''
This not necessary when using subset 
'''
'''
X = flatten(x_train)
X_t = flatten(x_test)
print(f"X train shape {X.shape}")
print(f"X test shape {X_t.shape}")
print(f"y train shape {y.shape}")
print(f"y test shape {y_t.shape}")
'''
# Out:
# '\nX = flatten(x_train)\nX_t = flatten(x_test)\nprint(f"X train shape {X.shape}")\nprint(f"X test shape {X_t.shape}")\nprint(f"y train shape {y.shape}")\nprint(f"y test shape {y_t.shape}")\n'

# %%
# for each image and label in adversarial
n=50
import time
# these are the examples that are found as adversarialwe will save these at the end in a file
evolved_examples= []
# fitness of the adversarials
fitness_of_evolved=[]
# time necessary to evolve the adversarial
times=[]
# the distance between the original image and the adversarial
ssim_values=[]
# number of round necessary to produce adversarial 
number_of_rounds=[]
# this will serve to see if the fitness changes or not 
best_fitness = 0


numb_of_found_after30=0
numb_of_adv_found=0

#dictionary to keep the best individual to check if the fitness is improving or not 


predicted_class= []
for img,label in zip(adversarial,adversarial_y):
  winner_of_gen = {"image":[],"label": None, "fitness": None}
  #temporary variable to check generations:
  fitness_no_change = 0
  start = time.time()
  label=label[0]
  #intialize population from the image and with the given label
  population = init_pop_from_sample(n,img,label)
  # calculate fitness of these individuals
  fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label)
  print(f"Initial fitness: \n {fitness}")
  #retun the best one from the population
  best,fit_max = return_best_individual(population,fitness)
  #check if adversarial
  check_adv = check_adv_termination(best,label,img, model)
  #define max generation
  max_gen=0
  winner_of_gen.update(image= best)
  winner_of_gen.update(label= label)
  winner_of_gen.update(fitness= fit_max)
  while (len(check_adv)==0 or max_gen<10000):
      new_pop=[]
      for i in range(50):
        parent1= tournament(population, model, img, label) 
        parent2 = tournament(population, model, img, label)
        if 0.8 > np.random.uniform(0.0, 1.0):
          child1, child2 = multi_crossover(parent1, parent2,img) # crossover
          new_pop.append(add_noise(choose_better_child(child1, child2,img,label,model)))
        else:
          new_pop.append(add_noise(choose_better_child(parent1, parent2,img,label,model)))

      # to reshape into an array 
      population= np.array(new_pop)
      #check fitness of the generation
      fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label) 
      #find the highest fitness
      best,fit_max1 = return_best_individual(population,fitness)
      # check adversarial - check if pred != target, distance < 0.001 or fitness didn't improve 0.001 after 30 generations(this is in else condition)
      check_adv = check_adv_termination(best,label,img,model)

      #check if the first termination true 
      if(len(check_adv) != 0):
        print("Adversarial example image: \n")
        evolved_examples.append(check_adv) #add evolved example
        ssim_values.append(1-compare_ssim(check_adv.reshape(CIFAR_IMG,CIFAR_IMG),img.reshape(CIFAR_IMG,CIFAR_IMG))) #add the distance
        end=time.time()
        times.append(end-start) #add the time 
        fitness_of_evolved.append(calculate_fitness(model,check_adv,img,label)) #add the fitness value of adversarial
        number_of_rounds.append(max_gen)
        pred_l=np.argmax(model.predict(check_adv.reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0))
        predicted_class.append(pred_l)
        print("Left: adversarial \t Right: ground truth")
        fd, idx = plt.subplots(1,2)
        idx[0].imshow(check_adv.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        idx[1].imshow(img.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        plt.show()
        print(f"True label: {label}")
        print(f"predicted label: {pred_l}") 
        print("Time: ",end-start ," seconds")
        numb_of_adv_found+=1
        break
      #check the second termination 
      else:
          #check if fitness increases, if not , add +1 to temporary var
        if fit_max1>fit_max:
          fit_max=fit_max1
          winner_of_gen.update(image= best)
          winner_of_gen.update(label= label)
          winner_of_gen.update(fitness= fit_max1)
          fitness_no_change=0
        else:
          fitness_no_change+=1
      
      #print after every 10 generations to see the progress
      if (max_gen % 10 == 0):
        print(f"Generation {max_gen}")
        print(f"Max fitness value {fit_max}")
      max_gen+=1

      # if fitness did not improve for 30 generations, save the image that was best , saved it in a dicitonary
      if fitness_no_change==30:
        print("FITNESS DID NOT IMPROVE FOR 30 GENERATIONS")
        print("Best adversarial image we could find: \n")
        evolved_examples.append(winner_of_gen["image"])
        ssim_values.append(1-compare_ssim(np.array(winner_of_gen["image"]).reshape(CIFAR_IMG,CIFAR_IMG),img.reshape(CIFAR_IMG,CIFAR_IMG)))
        number_of_rounds.append(max_gen)
        end=time.time()
        times.append(end-start)
        fitness_of_evolved.append(winner_of_gen["fitness"])
        pred_l=np.argmax(model.predict(np.array(winner_of_gen["image"]).reshape(1,CIFAR_IMG,CIFAR_IMG,1)/255.0))
        predicted_class.append(pred_l)
        print("Left: adversarial \t Right: ground truth")
        fd, idx = plt.subplots(1,2)
        idx[0].imshow(np.array(winner_of_gen["image"]).reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        idx[1].imshow(img.reshape(CIFAR_IMG,CIFAR_IMG),cmap='gray')
        plt.show()
        print(f"True label: {label}")
        print(f"predicted label: {pred_l}")
        print("Time: ",end-start ," seconds")
        numb_of_found_after30 +=1
        break
# Out:
# Initial fitness:
#  [-0.6003421846829813, -0.6014233009400011, -0.6021710252132082, -0.6010787395273278, -0.6017296644445892, -0.6006246064342724, -0.6016371008769117, -0.6015986491587476, -0.6013498892158472, -0.5999955458140832, -0.601020590562576, -0.6017574466266108, -0.602747413741685, -0.6017573611414601, -0.6005499628970601, -0.6009253942964956, -0.6012076525904644, -0.6017729240012388, -0.601591565086971, -0.6002356500571928, -0.6020833207438715, -0.6014473382482549, -0.6047364836056387, -0.6036656071764964, -0.6028087296464472, -0.6002553189157103, -0.6011277407964598, -0.600873706128894, -0.6002998612753933, -0.5999804860611871, -0.6004737955634604, -0.6011875444301396, -0.6008069189157474, -0.6019352034546327, -0.6000528284646404, -0.6013990531717441, -0.600529128618289, -0.6021990828935389, -0.5999799240095858, -0.6013059022818715, -0.6010262546795597, -0.6028610166065058, -0.6013173335334538, -0.6016748774691136, -0.6015680422549939, -0.6016282783645052, -0.6015389422224486, -0.6002344390427716, -0.60037182666477, -0.602540684945236]
# C:\Users\Lora\Anaconda3\lib\site-packages\skimage\measure\_structural_similarity.py:155: UserWarning: Inputs have mismatched dtype.  Setting data_range based on X.dtype.
#   warn("Inputs have mismatched dtype.  Setting data_range based on "
# Generation 0
# Max fitness value -0.5999799240095858
# Generation 10
# Max fitness value -0.5999799240095858
# Generation 20
# Max fitness value 0.2153502310978928
# Generation 30
# Max fitness value 0.9682427356870155
# Generation 40
# Max fitness value 0.9759143627039011
# Generation 50
# Max fitness value 0.9791792105409863
# Generation 60
# Max fitness value 0.9814824963391958
# Generation 70
# Max fitness value 0.981724744925578
# Generation 80
# Max fitness value 0.981724744925578
# Generation 90
# Max fitness value 0.9820049267880852
# Generation 100
# Max fitness value 0.9821981475429018
# Generation 110
# Max fitness value 0.9826723189601678
# Generation 120
# Max fitness value 0.9828292535959146
# Generation 130
# Max fitness value 0.9837731088223713
# Generation 140
# Max fitness value 0.9837731088223713
# Generation 150
# Max fitness value 0.9842182370150832
# Generation 160
# Max fitness value 0.9842968047184545
# Generation 170
# Max fitness value 0.9842968047184545
# Generation 180
# Max fitness value 0.9842968047184545
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  740.2429060935974  seconds
# Initial fitness:
#  [-0.4960728669120208, -0.43060507225171474, -0.460724620663833, -0.446107571464207, -0.5075206709100762, -0.5357990449241656, -0.5116509898113528, -0.5107807615368463, -0.47690083120761606, -0.49330898638996745, -0.4544520998840308, -0.4940306728635445, -0.5191885913805838, -0.4677480186858297, -0.557640908053145, -0.48433762992144835, -0.5212547731904837, -0.49542984348971164, -0.5226345796061997, -0.5230524754928253, -0.5025222608374851, -0.47808008768437465, -0.48169032831652053, -0.46732326895094006, -0.4354276975686854, -0.4817901767936257, -0.4992294368883363, -0.49718975113122355, -0.5019960627461874, -0.4845352765071764, -0.5017818488627313, -0.4616745226649564, -0.5395418174764339, -0.5078203431708119, -0.5303273146319527, -0.5380868198935348, -0.5062673658707081, -0.5077314955219989, -0.5201051230711081, -0.5308158731874963, -0.48984151502105766, -0.4817347069601565, -0.4921396424401735, -0.5191058389735126, -0.49031645144053626, -0.5228806099658617, -0.5059056093834029, -0.5285939123399763, -0.47292534695706245, -0.5433277407734614]
# Generation 0
# Max fitness value -0.23061892380730187
# Generation 10
# Max fitness value 0.9058673501222241
# Generation 20
# Max fitness value 0.991632609619886
# Generation 30
# Max fitness value 0.9944624960947284
# Generation 40
# Max fitness value 0.996928458757018
# Generation 50
# Max fitness value 0.9973256413230878
# Generation 60
# Max fitness value 0.9973256413230878
# Generation 70
# Max fitness value 0.9974067248633485
# Generation 80
# Max fitness value 0.9974067248633485
# Generation 90
# Max fitness value 0.9974067248633485
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  372.2200698852539  seconds
# Initial fitness:
#  [-0.358035373159195, -0.44637396699829024, -0.4182249119513667, -0.3187639672955791, -0.3265572281488319, 0.14123741723683989, -0.3328344964199592, -0.3510597835276117, -0.3681248252968856, -0.3646131622167807, -0.3346452538424439, -0.43125960561529025, -0.37159955091986496, -0.2670939862673168, 0.07788298345155054, -0.3615906609596039, -0.26345131921500553, -0.2648649785695812, -0.31479635874549367, -0.1281078349474547, -0.3343039490652886, -0.37639498697556006, -0.3624209434126392, -0.3025786783416109, -0.2746251423150656, -0.2192016511651781, 0.09373018096206018, -0.262108220859822, -0.29793988187603926, 0.06692702982146825, -0.4185196957569014, -0.3410249588520705, -0.24391229468878306, -0.3456193128248297, -0.17596608043427076, -0.24659130548709673, -0.43672870908786576, -0.33292285580865577, -0.2045262964799569, -0.2750168084287868, -0.15255122869657325, -0.27666024649288995, -0.3793565721691411, -0.24348867030537116, -0.36185799860323076, -0.36496600056260525, -0.42107950866930005, -0.4444588932453885, -0.293879952988707, -0.3699901923381571]
# Generation 0
# Max fitness value 0.24701042569221127
# Generation 10
# Max fitness value 0.9773329704416165
# Generation 20
# Max fitness value 0.9930756125020772
# Generation 30
# Max fitness value 0.994086057910822
# Generation 40
# Max fitness value 0.9943183982391165
# Generation 50
# Max fitness value 0.9944549063131463
# Generation 60
# Max fitness value 0.9944549063131463
# Generation 70
# Max fitness value 0.9944549063131463
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  320.5667703151703  seconds
# Initial fitness:
#  [-0.5951579605669014, -0.5959149626186766, -0.5895039146729095, -0.5945981584799778, -0.5937947411724032, -0.5936353219578195, -0.5967874487105792, -0.5913001161941085, -0.5954694991842486, -0.5921532444421002, -0.5939554383574178, -0.5938400986034861, -0.5922661401644741, -0.5944745173625796, -0.5969118533639332, -0.5935450890266855, -0.5923695370432828, -0.591718987456819, -0.5936403955341942, -0.5945644975893825, -0.5948536885337945, -0.5848038767264973, -0.5880501326172048, -0.5937968011120262, -0.5932760970957434, -0.5933626760252283, -0.5935363759890322, -0.592469240091215, -0.5940788718995305, -0.5980761989194576, -0.5950852873184409, -0.5951705436503958, -0.5923599030242467, -0.5938525807138737, -0.5897661461354751, -0.59610345872847, -0.5953858950468294, -0.5962319412276892, -0.5908540636291613, -0.5939144697777512, -0.5971568919429572, -0.5901463205109242, -0.5976769333028583, -0.5942114186895182, -0.596724454713777, -0.5957867501510987, -0.5933676502356772, -0.5946555989729431, -0.5922166472872582, -0.5966902943023922]
# Generation 0
# Max fitness value -0.5807195996553516
# Generation 10
# Max fitness value 0.4159580019131047
# Generation 20
# Max fitness value 0.9476841231490176
# Generation 30
# Max fitness value 0.9959026638695383
# Generation 40
# Max fitness value 0.9965978589295756
# Generation 50
# Max fitness value 0.9969218730452125
# Generation 60
# Max fitness value 0.9969218730452125
# Generation 70
# Max fitness value 0.9969218730452125
# Generation 80
# Max fitness value 0.9970131564299578
# Generation 90
# Max fitness value 0.9970955207141059
# Generation 100
# Max fitness value 0.9970955207141059
# Generation 110
# Max fitness value 0.9970955207141059
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  474.0425229072571  seconds
# Initial fitness:
#  [-0.5354052084763041, -0.5488901338832732, -0.5324833847374375, -0.5398728628780186, -0.5588288376196524, -0.5567844588856079, -0.5480859645226454, -0.5247231481266712, -0.547467881846765, -0.5545710318355364, -0.5202570601464387, -0.5268150521855502, -0.5626547168547519, -0.556939822660236, -0.5422835854052661, -0.5580417623452225, -0.45510465485444396, -0.5738115947797875, -0.532520603165912, -0.5389679981951626, -0.5327595297060821, -0.5362203062517878, -0.5339675657759329, -0.5378219330319136, -0.5127492565729992, -0.5358159634978849, -0.5372986309564345, -0.5424027810024017, -0.5534910735862464, -0.43351063532661943, -0.51260342857353, -0.49690593223865737, -0.5248632355779218, -0.5276528449316964, -0.5747104947062633, -0.5508496129875617, -0.603891150325327, -0.5700678076007801, -0.5525656421806047, -0.5558012914588847, -0.5343731830573308, -0.5287512859219581, -0.5282877525622152, -0.528785364759071, -0.5323620721082443, -0.5295773320805321, -0.5299603346736395, -0.5242912755577394, -0.5362474587831885, -0.5346571479303679]
# Generation 0
# Max fitness value -0.2591259879300614
# Generation 10
# Max fitness value 0.9584153491316543
# Generation 20
# Max fitness value 0.9756216162595577
# Generation 30
# Max fitness value 0.9777935648453604
# Generation 40
# Max fitness value 0.9801503047845082
# Generation 50
# Max fitness value 0.9810506833093058
# Generation 60
# Max fitness value 0.9810506833093058
# Generation 70
# Max fitness value 0.9810506833093058
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  292.33405327796936  seconds
# Initial fitness:
#  [-0.6112949610132423, -0.5969014022144383, -0.6038802924522991, -0.5950332587492118, -0.6000132298230939, -0.5960658393296652, -0.6101674494861218, -0.6014102094280991, -0.609648788165384, -0.6174761939365206, -0.5959731957516219, -0.6054726460007368, -0.6032217450089629, -0.5997683279610373, -0.6163835825400424, -0.6048102613960252, -0.6033339022998621, -0.6138151029859328, -0.6098076010956222, -0.6058118292547341, -0.5816087691978712, -0.5965622568128744, -0.6149453900182502, -0.6020168044602129, -0.5990898123583571, -0.6094564329918376, -0.6012033461896664, -0.5946760840995139, -0.5971813400073024, -0.6027155360286189, -0.6083439526023391, -0.6054679674727366, -0.6097058624481497, -0.5964018683548777, -0.6046018750932711, -0.6148465535272227, -0.5919368840434427, -0.5910710094814284, -0.6049179019447503, -0.6006664621043029, -0.5920223659557207, -0.5991127643759477, -0.5948238995327751, -0.5926012522941306, -0.6141686229837088, -0.6065924801320166, -0.5931814917507269, -0.5994978676052033, -0.5983892095017471, -0.6012461500586936]
# Generation 0
# Max fitness value -0.5727253021546569
# Generation 10
# Max fitness value 0.8301073870048874
# Generation 20
# Max fitness value 0.9444208948438834
# Generation 30
# Max fitness value 0.9493672051797213
# Generation 40
# Max fitness value 0.951801931484978
# Generation 50
# Max fitness value 0.951801931484978
# Generation 60
# Max fitness value 0.951801931484978
# Generation 70
# Max fitness value 0.951801931484978
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  299.83602809906006  seconds
# Initial fitness:
#  [-0.6015217293784336, -0.6079020827090562, -0.6017807618740186, -0.601505954984159, -0.6021306114356376, -0.6120137709075417, -0.6052798377875617, -0.6040495091037396, -0.6000269196510648, -0.6050217944073397, -0.599732347200748, -0.606210682322918, -0.6027372081430522, -0.5997085828789099, -0.6071033877863206, -0.5999990315712544, -0.6013480743517818, -0.6020047481514224, -0.6000055887397016, -0.6027623917055194, -0.6031626722570742, -0.6026808487323885, -0.6013395631959327, -0.602458183076104, -0.6014443713913777, -0.5996983350245597, -0.6004385298192896, -0.6009740456590107, -0.6089067860782336, -0.606114655153276, -0.6048223495717203, -0.5997475773550316, -0.6053163174766311, -0.6096307882995818, -0.5999236848833882, -0.6067317713437785, -0.5997695438972535, -0.6007129205734002, -0.6011296789656226, -0.6002907271453942, -0.6026455577005648, -0.6054407275166441, -0.6030030365243817, -0.604580130562145, -0.601035103432862, -0.6065055674210943, -0.6030627104215448, -0.609558021067532, -0.6052282996844184, -0.6004325535401508]
# Generation 0
# Max fitness value -0.5996983350245597
# Generation 10
# Max fitness value -0.5964592725905976
# Generation 20
# Max fitness value -0.459325143462848
# Generation 30
# Max fitness value 0.6715146977129888
# Generation 40
# Max fitness value 0.9778904393012475
# Generation 50
# Max fitness value 0.9815858942691664
# Generation 60
# Max fitness value 0.9844956952313593
# Generation 70
# Max fitness value 0.9864877195463507
# Generation 80
# Max fitness value 0.9868620619460826
# Generation 90
# Max fitness value 0.9874081031012555
# Generation 100
# Max fitness value 0.987654307264588
# Generation 110
# Max fitness value 0.9879698958665711
# Generation 120
# Max fitness value 0.9879698958665711
# Generation 130
# Max fitness value 0.9879698958665711
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  540.7037267684937  seconds
# Initial fitness:
#  [-0.5909643881338285, -0.5974759452629272, -0.5966719781704558, -0.5972176121460449, -0.5959761652855521, -0.5961407190187138, -0.5930548922797816, -0.5956817596823958, -0.5960645529753835, -0.5948552603338131, -0.5955616477014596, -0.5960100312916199, -0.5949534251914761, -0.5961889038036338, -0.5962147198360501, -0.5942959706443542, -0.5967450122865492, -0.5969493809193687, -0.5956626741435421, -0.5929260535053503, -0.5970685893200337, -0.593787792198802, -0.5968583003419683, -0.5954310362911266, -0.5960475536434402, -0.5965417633704988, -0.5949611150527274, -0.5952460109987238, -0.5963257172166958, -0.5951582390016742, -0.5962624986338719, -0.5961973991503384, -0.596271572515005, -0.5966832447360937, -0.5959870987068869, -0.5948916811533359, -0.594394024404767, -0.5970255141551793, -0.596322258028329, -0.5958533769375562, -0.5967870709702907, -0.5936444988119599, -0.5965763674268907, -0.5973979888694991, -0.5965063888120425, -0.5948183999767138, -0.5960603108826036, -0.5970149705009137, -0.5968325619615992, -0.5973735721297431]
# Generation 0
# Max fitness value -0.5742952776190765
# Generation 10
# Max fitness value -0.2692020541761706
# Generation 20
# Max fitness value 0.761839160276112
# Generation 30
# Max fitness value 0.962021178679547
# Generation 40
# Max fitness value 0.9914650732218031
# Generation 50
# Max fitness value 0.9949499697762987
# Generation 60
# Max fitness value 0.9959241021863722
# Generation 70
# Max fitness value 0.9961179642336158
# Generation 80
# Max fitness value 0.9963968191125944
# Generation 90
# Max fitness value 0.9964395581479847
# Generation 100
# Max fitness value 0.9964905817412897
# Generation 110
# Max fitness value 0.9965394165179823
# Generation 120
# Max fitness value 0.9965660587275629
# Generation 130
# Max fitness value 0.9966538209341842
# Generation 140
# Max fitness value 0.9967018635432423
# Generation 150
# Max fitness value 0.9967018635432423
# Generation 160
# Max fitness value 0.9967608683624705
# Generation 170
# Max fitness value 0.9968897867758479
# Generation 180
# Max fitness value 0.9968897867758479
# Generation 190
# Max fitness value 0.9968897867758479
# Generation 200
# Max fitness value 0.9969687852431965
# Generation 210
# Max fitness value 0.9969687852431965
# Generation 220
# Max fitness value 0.9969995089626629
# Generation 230
# Max fitness value 0.9970777973138081
# Generation 240
# Max fitness value 0.9970777973138081
# Generation 250
# Max fitness value 0.9970777973138081
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  1044.2660434246063  seconds
# Initial fitness:
#  [-0.5744730199927737, -0.5761860997049038, -0.5859167547399965, -0.5854116742923303, -0.585513830927443, -0.5786151110678243, -0.5814334643545485, -0.560017135831214, -0.5861562339923938, -0.5674054225839593, -0.5843676854208225, -0.5767753250258937, -0.5891176222505634, -0.5729195588135754, -0.5816248673520432, -0.5832040442845385, -0.5857701564989569, -0.5744215909430654, -0.5695542512803666, -0.5721678880970552, -0.5765645339259088, -0.588762319270923, -0.5794419055552466, -0.5899748913013465, -0.5762280628372587, -0.5582618691913679, -0.5917232676321335, -0.5752191730841103, -0.5501642201401721, -0.58500906525172, -0.5747513901222322, -0.5845812680948221, -0.5829600813718538, -0.577182269799168, -0.5719223689767491, -0.578664598216778, -0.5838182154624442, -0.5760382438620447, -0.5866189306253857, -0.5733687522304236, -0.5745085719224275, -0.5880802867296713, -0.5543021955221491, -0.5737628661961224, -0.5782151465254415, -0.5724678692685119, -0.5674862581540376, -0.5762696865767549, -0.5848736933356259, -0.5815912384460982]
# Generation 0
# Max fitness value -0.5130039706094668
# Generation 10
# Max fitness value 0.3544627547048607
# Generation 20
# Max fitness value 0.8331613765860453
# Generation 30
# Max fitness value 0.9665153727734884
# Generation 40
# Max fitness value 0.9857599312359446
# Generation 50
# Max fitness value 0.9900964731955699
# Generation 60
# Max fitness value 0.9916313171619393
# Generation 70
# Max fitness value 0.9920109896044056
# Generation 80
# Max fitness value 0.9920231887323245
# Generation 90
# Max fitness value 0.992399696703571
# Generation 100
# Max fitness value 0.992399696703571
# Generation 110
# Max fitness value 0.992399696703571
# Generation 120
# Max fitness value 0.9924724375649483
# Generation 130
# Max fitness value 0.9928171949356194
# Generation 140
# Max fitness value 0.9929935641514066
# Generation 150
# Max fitness value 0.9929935641514066
# Generation 160
# Max fitness value 0.9929935641514066
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 9
# Time:  653.2036883831024  seconds
# Initial fitness:
#  [-0.274526921624783, -0.4407720889950214, -0.19104945798626044, -0.1997373515280887, -0.14014668502863115, -0.09893778016691937, -0.37033685439971475, -0.0005481993926661488, -0.1360587991897705, -0.05912871641698231, -0.19979587997522857, -0.1938635326451432, -0.11878741623819467, -0.23680488236358999, 0.11915719897779443, -0.2521129266233207, -0.1707526325744113, -0.16650555399696113, -0.37802891341562006, -0.07902141832428486, -0.18122448466809038, -0.09155840549886735, -0.09912883428523456, -0.08438834074214688, 0.09680569108591966, -0.05535893379609158, -0.27383595934015825, -0.059667542249774136, 0.11693610273411756, -0.14526989881205749, -0.1409897923645309, -0.1528652672946896, -0.12763530001358253, -0.09096455621880542, -0.2185952609200853, -0.14589157382815948, 0.06892075659256322, -0.052698020658036165, 0.3348898060584722, -0.09956429096039934, -0.22851888115174546, 0.15319192736145074, -0.08793252763435794, -0.24864284119579833, 0.014441572590687984, -0.4325134071523884, -0.1426655241783604, -0.07247171975466501, -0.23082992337417235, 0.32194478287908823]
# Generation 0
# Max fitness value 0.40199319546841517
# Generation 10
# Max fitness value 0.9808490764263429
# Generation 20
# Max fitness value 0.9870673084451981
# Generation 30
# Max fitness value 0.9870673084451981
# Generation 40
# Max fitness value 0.9870673084451981
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  182.04774498939514  seconds
# Initial fitness:
#  [-0.5218836121152147, -0.5432004649446078, -0.546382964027234, -0.49654777889421664, -0.5544400599763576, -0.5197071080150826, -0.5090263302849314, -0.5073896955588691, -0.5027606611181962, -0.4964837359919134, -0.5439258151803221, -0.48569117763737263, -0.5041193755393637, -0.5102737254292977, -0.4976091291528727, -0.4435975091521111, -0.4688008126026689, -0.5232194487972628, -0.31342542424765474, -0.5280514882513638, -0.5133596812152802, -0.4949076331646562, -0.5273658778263608, -0.5432244096214234, -0.5443735474644069, -0.550857980775129, -0.5193322350652727, -0.47104806721718184, -0.5046533978955188, -0.4731747849089595, -0.5223217674802458, -0.5090691519557194, -0.5107576586306315, -0.48012819329223955, -0.527886382743777, -0.4890419136351415, -0.514473556194651, -0.46633957973283646, -0.49628312903865324, -0.5204971202207596, -0.5330022278982623, -0.5378079846000621, -0.5260171965453173, -0.5253891752549427, -0.47836111026441874, -0.5381527705479378, -0.5292137929381323, -0.47691734778999084, -0.5562661019998264, -0.4544446321289012]
# Generation 0
# Max fitness value -0.12344907652362258
# Generation 10
# Max fitness value 0.9784176147465775
# Generation 20
# Max fitness value 0.9965486957983649
# Generation 30
# Max fitness value 0.9978777803605368
# Generation 40
# Max fitness value 0.9979790485793669
# Generation 50
# Max fitness value 0.9979790485793669
# Generation 60
# Max fitness value 0.9979790485793669
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 9
# Time:  268.6119818687439  seconds
# Initial fitness:
#  [0.4281466541634464, 0.4298672584768086, 0.44775591976041335, 0.44695436296519375, 0.3819509376963762, 0.5756639675730133, 0.6756625930479709, 0.4270081985409951, 0.46447085497910495, 0.36652218509177364, 0.4656042632357377, 0.36603530096381376, 0.4515842037147879, 0.35729867789234643, 0.5105728715993847, 0.4598874539093472, 0.4985141721009452, 0.4180951230980745, 0.4534725511619809, 0.39206860169284946, 0.5604797834578452, 0.6123343047733457, 0.4463503793957545, 0.3745276949725277, 0.4472464631326887, 0.4163156475252068, 0.5043084820003223, 0.36979064329389816, 0.42206183453169177, 0.52027497819682, 0.4663081330143073, 0.3933779775452244, 0.36484044840968854, 0.5635371384963489, 0.4241635724303777, 0.43316063711171693, 0.4511905327169639, 0.4263417737821197, 0.4686874389933534, 0.518285843651753, 0.4364005342952989, 0.39364874472875094, 0.373672252136714, 0.7114563730958297, 0.46288608065885806, 0.37068641395619895, 0.4620505003426683, 0.3917138873670362, 0.3879375170764106, 0.40069587056893796]
# Generation 0
# Max fitness value 0.7931379556706251
# Generation 10
# Max fitness value 0.9943520531818043
# Generation 20
# Max fitness value 0.9961505260274126
# Generation 30
# Max fitness value 0.9965089414772158
# Generation 40
# Max fitness value 0.9965089414772158
# Generation 50
# Max fitness value 0.9965089414772158
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 2
# Time:  248.0180869102478  seconds
# Initial fitness:
#  [0.1972689729905289, -0.24850064275615316, -0.175386292297986, 0.06763318626420228, -0.3884681559443125, -0.03917920336218167, -0.3212584037031173, -0.16835049496957544, -0.1514690670787206, -0.11149756007702585, -0.41400260235236447, -0.1896181129995853, -0.3070847953408602, -0.19317008093814725, -0.354560417985183, -0.31357056367514186, -0.03313434769764281, -0.22625420421756126, -0.4435185832709596, -0.3156060936424434, -0.31224863950558013, -0.2638991210084605, -0.12949450442819274, -0.26941107015040566, -0.42142383145777845, -0.33123549630555627, -0.2397602616014416, -0.38325354600009964, 0.03861252003150162, -0.2787004901098693, -0.09045490742163248, -0.21252730810694462, -0.4481324569345347, -0.35265375772467145, -0.15913551413929006, -0.06027883758300048, -0.19083211046069803, -0.2259943224112207, -0.19580331794948308, -0.1544134047928137, -0.25756180748799656, -0.035281982803664624, -0.34125774709755685, 0.14107069155743127, -0.33966992023166476, -0.4861286956110721, -0.2136432499098552, -0.1267762236978868, -0.21251908591151394, -0.38424909057992623]
# Generation 0
# Max fitness value 0.37049135492377405
# Generation 10
# Max fitness value 0.9907612812540614
# Generation 20
# Max fitness value 0.9975703605228161
# Generation 30
# Max fitness value 0.9980714416860947
# Generation 40
# Max fitness value 0.998076481701911
# Generation 50
# Max fitness value 0.998076481701911
# Generation 60
# Max fitness value 0.9981045024851256
# Generation 70
# Max fitness value 0.9982229301032025
# Generation 80
# Max fitness value 0.9982229301032025
# Generation 90
# Max fitness value 0.9982229301032025
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 0
# predicted label: 8
# Time:  577.8687541484833  seconds
# Initial fitness:
#  [-0.6007600034228022, -0.6000697322750189, -0.6011633921200815, -0.6034303362969917, -0.601659118965825, -0.6000544407052866, -0.6014435368047897, -0.6022476079912041, -0.6024138625465079, -0.6002510202700908, -0.6011914427139156, -0.6000925012176765, -0.6023556946925517, -0.6003314182838214, -0.6008042685100075, -0.603336958100415, -0.6014198588001927, -0.6000142206521947, -0.6009045342295456, -0.6016704957125973, -0.6010117916791542, -0.602578560744909, -0.6002973115321623, -0.6029259831977721, -0.6005261712568052, -0.6022001497899115, -0.6011334398854323, -0.6018063490660264, -0.6002584304697585, -0.6004127623178841, -0.6003895768427502, -0.6013570723040121, -0.6046104268635731, -0.6020270614746535, -0.6000893771142481, -0.6034161283108869, -0.6013076875537448, -0.6014108206141879, -0.6004721143183789, -0.6017348901474425, -0.601463985090219, -0.6006985521645285, -0.6001319834135848, -0.6001432428723227, -0.6003647427744189, -0.6027191955714032, -0.6034380619610406, -0.6014782648157231, -0.6002311991071332, -0.6021103424951111]
# Generation 0
# Max fitness value -0.6000142206521947
# Generation 10
# Max fitness value -0.6000142206521947
# Generation 20
# Max fitness value -0.5407590784442324
# Generation 30
# Max fitness value 0.9467194410298857
# Generation 40
# Max fitness value 0.99029545846558
# Generation 50
# Max fitness value 0.9926221577085341
# Generation 60
# Max fitness value 0.9930143784245085
# Generation 70
# Max fitness value 0.9932433687251393
# Generation 80
# Max fitness value 0.9932433687251393
# Generation 90
# Max fitness value 0.9932978924667087
# Generation 100
# Max fitness value 0.993452463733481
# Generation 110
# Max fitness value 0.993452463733481
# Generation 120
# Max fitness value 0.993452463733481
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 6
# Time:  748.418137550354  seconds
# Initial fitness:
#  [-0.5149170101633491, -0.5717785497322734, -0.48001913455615164, -0.5526858277306926, -0.552679169541138, -0.5382211401622025, -0.5577557881151209, -0.5341417924200876, -0.5498234451524621, -0.5310678986992573, -0.5348328427151896, -0.5183821549930123, -0.4900070331124594, -0.5102453292232109, -0.548823744521319, -0.5554051308081152, -0.5586683148794993, -0.4982850217419753, -0.5613114814835014, -0.5410167594697083, -0.514876761681758, -0.5633553290075742, -0.5429906776802266, -0.5160999236907081, -0.5185816393131069, -0.5475738289192905, -0.517393553761153, -0.5549426215539566, -0.4701958216004757, -0.5625366346210627, -0.421440807989252, -0.558056854262154, -0.538471769272198, -0.548007022670168, -0.44466956561075216, -0.48431229668554077, -0.534638810686121, -0.5757202601829191, -0.5617540096951383, -0.522568620532631, -0.5336424930675688, -0.5511596942477669, -0.5659940392555771, -0.5505863256531563, -0.547381831817435, -0.5512945022696785, -0.483828598119313, -0.536591287536503, -0.5177576846611925, -0.5592464016888264]
# Generation 0
# Max fitness value -0.3029477548359193
# Generation 10
# Max fitness value 0.951147527175773
# Generation 20
# Max fitness value 0.9974210016446297
# Generation 30
# Max fitness value 0.9981074751290836
# Generation 40
# Max fitness value 0.9982246947986344
# Generation 50
# Max fitness value 0.9983950465172159
# Generation 60
# Max fitness value 0.9984675516859157
# Generation 70
# Max fitness value 0.9984675516859157
# Generation 80
# Max fitness value 0.9984675516859157
# Generation 90
# Max fitness value 0.9984702213984609
# Generation 100
# Max fitness value 0.9984739539177213
# Generation 110
# Max fitness value 0.9984739539177213
# Generation 120
# Max fitness value 0.998521881962944
# Generation 130
# Max fitness value 0.9985781012524788
# Generation 140
# Max fitness value 0.9985781012524788
# Generation 150
# Max fitness value 0.9985781012524788
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  908.2590844631195  seconds
# Initial fitness:
#  [-0.6029030503557311, -0.6008937727120989, -0.6013324079152131, -0.6015063316355476, -0.6020142095218626, -0.6022314165160755, -0.6024262511243565, -0.6037544081687264, -0.6013526366537674, -0.6040308410870348, -0.6010013124523652, -0.6010412244846913, -0.6015682592289153, -0.600724330980011, -0.6030887252819006, -0.6036900494314242, -0.6056287002516404, -0.6020328257107038, -0.6046699041839962, -0.6010923781170919, -0.6014324846885493, -0.6085869306594885, -0.6033775056043102, -0.6014224667845782, -0.6003480128756635, -0.6006474047279514, -0.6005686505412403, -0.6013059279410187, -0.6051415342693327, -0.6028509604044062, -0.6046997825248697, -0.6017479256463655, -0.6018012419383602, -0.6024521358743666, -0.6016559099926065, -0.6001635203906868, -0.605314159111958, -0.6025964315571934, -0.6000138201506928, -0.6021640825213144, -0.6031376480572582, -0.601554120052124, -0.6038034913471569, -0.6024553285614218, -0.6008793558168092, -0.6011715351656848, -0.6004501209786262, -0.6013363676006894, -0.60073667185602, -0.606624250048808]
# Generation 0
# Max fitness value -0.6000138201506928
# Generation 10
# Max fitness value -0.6000138201506928
# Generation 20
# Max fitness value -0.6000138201506928
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  176.4779839515686  seconds
# Initial fitness:
#  [0.660744728036833, 0.3465355232569858, 0.14189975893542245, 0.5236920344243206, 0.35616279976768245, 0.2606450746572906, 0.3549650268983249, 0.5340257577338094, 0.433449943655905, 0.6504703804874231, 0.2467925566217288, 0.4042041681445311, 0.3600343760247574, 0.2735880547676649, 0.03314251048083938, 0.6795636460263133, 0.4247023842199739, 0.4500593966499715, 0.360229970517942, 0.3958722127445471, 0.3935673531878313, 0.47056750783926604, 0.3283656194130543, 0.553950792063493, 0.19961325981568143, 0.31735731160645725, 0.2798653903442989, 0.47560956705833113, 0.25615797396042284, 0.3211282715603558, 0.3511085226744256, 0.41862469699528615, 0.45361824011539065, 0.3892280803026802, 0.28108956653144757, 0.3154834135519589, 0.42823972003551236, 0.4241914602159784, 0.18572046635701928, 0.5183055150291017, 0.3477205459219127, 0.35442501224354295, 0.3945979854735402, 0.015118353214599894, 0.5415686198158406, 0.49659216529990413, 0.29847260552694765, 0.3198553319460121, 0.41124999741345336, 0.21027605413260708]
# Generation 0
# Max fitness value 0.8287950419586775
# Generation 10
# Max fitness value 0.9956509740715194
# Generation 20
# Max fitness value 0.9981506994740371
# Generation 30
# Max fitness value 0.9982282904228975
# Generation 40
# Max fitness value 0.9982847966491367
# Generation 50
# Max fitness value 0.9982847966491367
# Generation 60
# Max fitness value 0.9982847966491367
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 7
# Time:  382.53395533561707  seconds
# Initial fitness:
#  [0.5021248478055497, 0.5056977918501057, 0.4893095083365837, 0.5447326164050634, 0.46044419383422996, 0.5696151395431909, 0.5455600294095215, 0.5152489982932812, 0.5018385752573549, 0.5362552052758502, 0.5120271718640422, 0.41451531970246436, 0.6262723766407874, 0.45625908123617637, 0.5109026536044012, 0.5583179140050735, 0.4168542021549292, 0.4864945112806867, 0.653082454036486, 0.4146406279812018, 0.5439908392164359, 0.6337495479797273, 0.5049150419746544, 0.5539202547157333, 0.5671779321861684, 0.47025040398208756, 0.5593735021922297, 0.5128829058655802, 0.4502011630689795, 0.4193644452082561, 0.6244294518085161, 0.5177039644702496, 0.4117916276045944, 0.5922570489063738, 0.5345966549309861, 0.46453259023879956, 0.42795956723492434, 0.6398610731568816, 0.4794584615460166, 0.5613536124737024, 0.5501477419592362, 0.37504591369880946, 0.46538936285725085, 0.5343724968751784, 0.2843003093253181, 0.5123143752715464, 0.5178542329914748, 0.4847248655935419, 0.5867245380735259, 0.6271852571900667]
# FOUND ADVERSARIAL
# Fitness of the adversarial 0.653082454036486
# Generation 0
# Max fitness value 0.7689150456687526
# Generation 10
# Max fitness value 0.9912109888205202
# Generation 20
# Max fitness value 0.9955653704027959
# Generation 30
# Max fitness value 0.9958118100609333
# Generation 40
# Max fitness value 0.9961708782212961
# Generation 50
# Max fitness value 0.9961837733891976
# Generation 60
# Max fitness value 0.9961837733891976
# Generation 70
# Max fitness value 0.9961837733891976
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 6
# Time:  312.63805890083313  seconds
# Initial fitness:
#  [-0.5962394670867346, -0.5909764444507171, -0.5918244070169107, -0.5921983902993604, -0.5825154564671585, -0.5943719300194605, -0.5800711150147655, -0.5831116831302773, -0.5907832389965856, -0.594147594010694, -0.5894051203768047, -0.5960629498614061, -0.5798064747344116, -0.5937443046032499, -0.5976859331243047, -0.5966992436857717, -0.5930207256981581, -0.5913949978838752, -0.5922591269191914, -0.5919724849501216, -0.5868617514198992, -0.5867370228113888, -0.5947733183732321, -0.5822418608837778, -0.5921706847911333, -0.5521521664432772, -0.593818881886054, -0.5893301145798001, -0.5914115926750423, -0.5899962744215497, -0.5957928445042366, -0.591786852805775, -0.5898592313228269, -0.5939521050963954, -0.5945831299540256, -0.5951430056543171, -0.5964750658328182, -0.5930296001188192, -0.589763074995332, -0.5941254410187313, -0.5938980096706784, -0.5905879846486505, -0.5933940512222805, -0.5860894333099692, -0.5952376294728594, -0.5947418853406795, -0.5971482152082693, -0.5898000543096183, -0.5915121261990473, -0.5842689892589766]
# Generation 0
# Max fitness value -0.511547188851507
# Generation 10
# Max fitness value 0.92429498910821
# Generation 20
# Max fitness value 0.9929683268995735
# Generation 30
# Max fitness value 0.9967515911707494
# Generation 40
# Max fitness value 0.9972012367729417
# Generation 50
# Max fitness value 0.9973803842474956
# Generation 60
# Max fitness value 0.9973803842474956
# Generation 70
# Max fitness value 0.9973803842474956
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 0
# Time:  294.7457594871521  seconds
# Initial fitness:
#  [-0.6000350564692342, -0.6000232412803059, -0.600026031312928, -0.6000310223626072, -0.6000161962614915, -0.6001188963910493, -0.6000212910499294, -0.6000644409333492, -0.6000577870555396, -0.6000489862361662, -0.6000509123218356, -0.6000371077494386, -0.6001352379120224, -0.6001562895630793, -0.6000153670369239, -0.6000146345548836, -0.6000089609572966, -0.6000590092450575, -0.6000468282406799, -0.6000529557512125, -0.600064051743737, -0.600066094418624, -0.6000170454343605, -0.6000589212829823, -0.6000700761289268, -0.600098817884216, -0.6000181378655893, -0.600078503395256, -0.600052805935334, -0.6000224061986623, -0.6000373265137163, -0.6000387455117635, -0.6001731395522867, -0.6000323865244286, -0.6000351492771758, -0.600038216522921, -0.6000260383981038, -0.6000846063085894, -0.6000155474808975, -0.6000422494890755, -0.6000318041907323, -0.6000502390265945, -0.6000613656132021, -0.600025856114965, -0.6001410998674884, -0.6000260968718293, -0.6000430777746492, -0.6000176030472787, -0.600049101225525, -0.6000105178370388]
# Generation 0
# Max fitness value -0.6000089609572966
# Generation 10
# Max fitness value -0.6000089609572966
# Generation 20
# Max fitness value -0.6000089609572966
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  120.28280305862427  seconds
# Initial fitness:
#  [-0.6004805399894134, -0.6000583711174242, -0.6000995226397399, -0.6000752732346712, -0.6003456915060776, -0.6000097853313678, -0.6001639092917788, -0.6000599111330365, -0.6001969466328283, -0.6002643127732066, -0.600154339334565, -0.601122345948388, -0.60156985890321, -0.6002325683859713, -0.6007138017492644, -0.60062081421746, -0.6004515562241868, -0.6001633435332193, -0.6001270744116723, -0.6001710490710532, -0.6001680535542664, -0.6002812266970107, -0.6000977039508396, -0.6001090757840595, -0.6001095032012509, -0.6007645758212021, -0.6000823048204064, -0.602783023849635, -0.600236267741102, -0.6001588714979682, -0.6001517163843352, -0.6000479971339521, -0.6014895597080899, -0.6001466796817754, -0.6001677159420532, -0.60127970769016, -0.6003602149522592, -0.601203421926955, -0.5999769887414127, -0.6009163757399012, -0.6000457765867908, -0.6002245153762881, -0.6000766695589209, -0.6007601283719911, -0.6000290720359085, -0.6000853996870665, -0.6004623444787168, -0.6007566555382594, -0.6006473058467344, -0.60036451188975]
# Generation 0
# Max fitness value -0.5999283891491105
# Generation 10
# Max fitness value -0.12387242028178716
# Generation 20
# Max fitness value 0.9945398190010362
# Generation 30
# Max fitness value 0.9972525145093393
# Generation 40
# Max fitness value 0.9974412211932092
# Generation 50
# Max fitness value 0.9974412211932092
# Generation 60
# Max fitness value 0.9974412211932092
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 0
# Time:  254.97113704681396  seconds
# Initial fitness:
#  [-0.6000458114169833, -0.6000355758967068, -0.6000484429482833, -0.6000597619762997, -0.6001800550389165, -0.6000259793133482, -0.6000358201331308, -0.6001099073813815, -0.6000034744826868, -0.6000625822879251, -0.6000960598031907, -0.6000487294274852, -0.6000476211384349, -0.6000664673299183, -0.6000416569434286, -0.6000230837439726, -0.6000516899432751, -0.6000688045145628, -0.6001306130983588, -0.6000689820773699, -0.6000778379196191, -0.6000757567728452, -0.6001317476219337, -0.6000949522481945, -0.6000575260351461, -0.6000135518996823, -0.6000425705932818, -0.6000579386615754, -0.6000154947352551, -0.6000433961872744, -0.6000688623428841, -0.6001345785061363, -0.6000310593465152, -0.6000578026432711, -0.6000376247175548, -0.6000501044377463, -0.6000403148648985, -0.6001168319371791, -0.6000304844272182, -0.6000771086391831, -0.6001027068025492, -0.6001891277224021, -0.600057916814518, -0.600069351634964, -0.6000416353961349, -0.6000548709607932, -0.6000345175928168, -0.6000685123914944, -0.6001149099224495, -0.6000576395294331]
# Generation 0
# Max fitness value -0.6000034744826868
# Generation 10
# Max fitness value -0.6000034744826868
# Generation 20
# Max fitness value -0.6000034744826868
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  119.80602955818176  seconds
# Initial fitness:
#  [-0.5996526728815887, -0.5996930504054482, -0.5995244739975465, -0.599475084397287, -0.5996133930169473, -0.5997445904084313, -0.6002424038195338, -0.5992679661179112, -0.5980702898341996, -0.5996341001691696, -0.5996523966408651, -0.5993359919916391, -0.5996536596833816, -0.5999280059075146, -0.599777819500689, -0.5996071230624235, -0.5995427071778074, -0.5997366521355569, -0.5996288758878385, -0.5996507886591849, -0.6007954250933174, -0.5997119724287949, -0.5996435183154885, -0.5997546631401679, -0.599743879417473, -0.5999875490648964, -0.5997000306016431, -0.599610050306653, -0.5967044723137919, -0.5999958008356713, -0.6005299030311484, -0.5995723730499677, -0.6000745344348684, -0.5996555133034982, -0.5996281131981391, -0.5996682594858294, -0.59983341082539, -0.5997835839793024, -0.5997991416504228, -0.5995489746138123, -0.5994223270591754, -0.5996434492663986, -0.599533877272816, -0.5995485613717307, -0.5998809980156599, -0.5998857252043479, -0.5998907222539822, -0.599514066511274, -0.5996597031078954, -0.599642081189776]
# Generation 0
# Max fitness value -0.5942628196632647
# Generation 10
# Max fitness value -0.058406103599726145
# Generation 20
# Max fitness value 0.9667316322740881
# Generation 30
# Max fitness value 0.9956175193099578
# Generation 40
# Max fitness value 0.996521403857557
# Generation 50
# Max fitness value 0.9966377509305275
# Generation 60
# Max fitness value 0.9968253825835781
# Generation 70
# Max fitness value 0.9968470563802685
# Generation 80
# Max fitness value 0.9968586981151752
# Generation 90
# Max fitness value 0.9970008844345327
# Generation 100
# Max fitness value 0.9970083267737906
# Generation 110
# Max fitness value 0.9970702602716872
# Generation 120
# Max fitness value 0.9971056826771796
# Generation 130
# Max fitness value 0.9972316207952348
# Generation 140
# Max fitness value 0.9972316207952348
# Generation 150
# Max fitness value 0.9972316207952348
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 9
# Time:  622.8437292575836  seconds
# Initial fitness:
#  [-0.600096003611325, -0.6000844548295593, -0.6000939142742455, -0.6000479475868921, -0.6002850565681197, -0.6000667900279407, -0.6001719590505147, -0.6000194506397415, -0.60027246337649, -0.6000943305294087, -0.6001845448090934, -0.6000784708799665, -0.6000882333454007, -0.6000458557032332, -0.6000316561631913, -0.6000900319573595, -0.6001418468639321, -0.600198866301953, -0.6001076422769317, -0.6000583279527145, -0.6000066192560588, -0.6001952927554097, -0.6000971746705931, -0.6001094240716511, -0.6000652720670735, -0.6000396896984728, -0.6001432451534268, -0.600113630119709, -0.6001049576861778, -0.6000749543244817, -0.6001308549079425, -0.6000863729302699, -0.6000894011731371, -0.6000625126831679, -0.6002271343524372, -0.6000680832605166, -0.6000636613901116, -0.6000431751074051, -0.6000951123040759, -0.6002698443880441, -0.6002924142324161, -0.6002343949196869, -0.6000866916102587, -0.6001036745555659, -0.6002202886114132, -0.6000789568418674, -0.6001232231688014, -0.6002450988950748, -0.6001653350072877, -0.6001442889741365]
# Generation 0
# Max fitness value -0.6000066192560588
# Generation 10
# Max fitness value -0.6000066192560588
# Generation 20
# Max fitness value -0.6000066192560588
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  120.60710954666138  seconds
# Initial fitness:
#  [-0.6001687751778122, -0.6001527439076223, -0.6002804709748344, -0.6002814110455841, -0.6002603005337817, -0.6002369730750365, -0.6002690434887632, -0.6002700675741128, -0.6000981320788408, -0.6000433887490347, -0.6002381148529137, -0.6002869046098132, -0.60034525571597, -0.6004365426616185, -0.6002371769066075, -0.6001346426024563, -0.6002680449117768, -0.6004509970638138, -0.6000974702247561, -0.6001405109276623, -0.6003274804814533, -0.6003862202446593, -0.6000544313925678, -0.6001909507579799, -0.6002470694226132, -0.6000455043300106, -0.600089620682919, -0.6000960174497001, -0.600389768815728, -0.6002144587191837, -0.6002971577001112, -0.6001658070900237, -0.6001684307543834, -0.600206491993855, -0.6003522356561992, -0.6002116827847803, -0.6003903075631397, -0.6000272841079962, -0.6000788878773599, -0.6004765442155304, -0.6000296691872178, -0.600165257910811, -0.6001329054298347, -0.6000652945026994, -0.600175523329605, -0.6001838520292526, -0.6001806161718873, -0.6005161906980996, -0.6001002587007981, -0.6001035555709929]
# Generation 0
# Max fitness value -0.6000272841079962
# Generation 10
# Max fitness value -0.6000272841079962
# Generation 20
# Max fitness value -0.6000272841079962
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 1
# predicted label: 1
# Time:  120.6390471458435  seconds
# Initial fitness:
#  [-0.5940001140797897, -0.5885136324399206, -0.5897274209181328, -0.5917503930847307, -0.5905443066907574, -0.5904381074174648, -0.5886065994070988, -0.5910933684802453, -0.593198062100197, -0.581143048771599, -0.592197481069368, -0.5935872295465485, -0.5893055644347714, -0.5923832799038734, -0.5873021525859832, -0.5914051124914996, -0.5890686621779746, -0.5905891305932931, -0.5864637099214413, -0.5890689302339793, -0.5911134709806324, -0.5960906388549574, -0.596230120508075, -0.5943828492292986, -0.5923318155054862, -0.5843766698310543, -0.5951839404193169, -0.583987616309294, -0.5942828273490011, -0.5931537216303447, -0.5914225774651395, -0.5930262160197111, -0.5951551326857496, -0.5921078638609166, -0.5913852197171037, -0.5915598218614467, -0.5803768482786196, -0.595185610001411, -0.5961231731407097, -0.5934856232331012, -0.5934410596518839, -0.5937967002467068, -0.5929570088192693, -0.5922768759597017, -0.5920667517747731, -0.5925364765514247, -0.5920287882969747, -0.5930858171218432, -0.594389352413511, -0.5918628523303376]
# Generation 0
# Max fitness value -0.5746009775005118
# Generation 10
# Max fitness value 0.28578900414416225
# Generation 20
# Max fitness value 0.8752826041075937
# Generation 30
# Max fitness value 0.9822436748145016
# Generation 40
# Max fitness value 0.9950045857873077
# Generation 50
# Max fitness value 0.9960258148936189
# Generation 60
# Max fitness value 0.9962830113790947
# Generation 70
# Max fitness value 0.996428318386485
# Generation 80
# Max fitness value 0.996707290100719
# Generation 90
# Max fitness value 0.9967471513739322
# Generation 100
# Max fitness value 0.9967478079476292
# Generation 110
# Max fitness value 0.9968557713306693
# Generation 120
# Max fitness value 0.996864294697521
# Generation 130
# Max fitness value 0.996864294697521
# Generation 140
# Max fitness value 0.9969234627441204
# Generation 150
# Max fitness value 0.9969234627441204
# Generation 160
# Max fitness value 0.9969234627441204
# Generation 170
# Max fitness value 0.9969848412555249
# Generation 180
# Max fitness value 0.9970040017653904
# Generation 190
# Max fitness value 0.997034003043702
# Generation 200
# Max fitness value 0.9970827887534535
# Generation 210
# Max fitness value 0.9970866925521547
# Generation 220
# Max fitness value 0.9971886098744652
# Generation 230
# Max fitness value 0.9971919481187752
# Generation 240
# Max fitness value 0.997260646459781
# Generation 250
# Max fitness value 0.997260646459781
# Generation 260
# Max fitness value 0.997260646459781
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 2
# predicted label: 3
# Time:  1074.387633562088  seconds
# Initial fitness:
#  [0.6164803263712163, 0.6157900213274136, 0.5411114712602352, 0.6297607954763667, 0.6111631456388769, 0.5899994561013124, 0.560776798101142, 0.5176447669704527, 0.5434338037184069, 0.5775698741134672, 0.773987245389238, 0.44185573624708296, 0.7007653788792938, 0.6130123058593334, 0.582000006466879, 0.5854349507703775, 0.5616880304725952, 0.6406812893289657, 0.5797234290427565, 0.6285277922190537, 0.5290112109396529, 0.5813749636461114, 0.5340240267902778, 0.6224003276423125, 0.6848836218826935, 0.8090092860898433, 0.6568411683553168, 0.7750223006374175, 0.7083981319354553, 0.6734437084526459, 0.4902669712305646, 0.5294781140829534, 0.5625123808013589, 0.6410320519749202, 0.6548170261258863, 0.5547703688374606, 0.6389334007021055, 0.7359435732826487, 0.7828354750692573, 0.824255828797342, 0.5828148048442311, 0.5496149244399886, 0.5390700360809144, 0.6709462732532442, 0.45223038000098015, 0.42977882432585773, 0.5593380541011523, 0.6022177423586768, 0.3696700020165079, 0.5445646579761105]
# Generation 0
# Max fitness value 0.8975732902299376
# Generation 10
# Max fitness value 0.9955990038185442
# Generation 20
# Max fitness value 0.9965080291562685
# Generation 30
# Max fitness value 0.99678996477428
# Generation 40
# Max fitness value 0.9969113422384466
# Generation 50
# Max fitness value 0.9969113422384466
# Generation 60
# Max fitness value 0.9969113422384466
# ...
# Generation 0
# Max fitness value -0.17636337041773892
# Generation 10
# Max fitness value 0.8825653262929181
# Generation 20
# Max fitness value 0.9881739467617748
# Generation 30
# Max fitness value 0.994768244914554
# Generation 40
# Max fitness value 0.99560460973955
# Generation 50
# Max fitness value 0.9958163141528718
# Generation 60
# Max fitness value 0.9958163141528718
# Generation 70
# Max fitness value 0.9962008902545642
# Generation 80
# Max fitness value 0.9963870267517065
# Generation 90
# Max fitness value 0.9965611572213217
# Generation 100
# Max fitness value 0.9965611572213217
# Generation 110
# Max fitness value 0.9965611572213217
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  498.4337685108185  seconds
# Initial fitness:
#  [-0.599902898046627, -0.5998430740515783, -0.5998554480775239, -0.5997124446581197, -0.599834223940627, -0.5999611665647334, -0.5999212766828537, -0.5997701178025728, -0.600136542490666, -0.600010399030602, -0.6000952557555472, -0.5998681898176186, -0.599775931166305, -0.5998613513203876, -0.6002239317639965, -0.5998322166511073, -0.5997563181667994, -0.5998003684245361, -0.5997102613237866, -0.5998293086941746, -0.5998165903347533, -0.5999024076992499, -0.6001902304198987, -0.5997252222138532, -0.6001169618108978, -0.5998155107247993, -0.5997576650923702, -0.5998340724343012, -0.5997004322008448, -0.5998008468053738, -0.5997493661704443, -0.5999180924422183, -0.59982695121382, -0.5997378520211408, -0.5998520110021235, -0.5997619447218456, -0.5998362458076971, -0.5997609541792259, -0.5998701328576144, -0.599869733548871, -0.5998273086393131, -0.599740249123197, -0.5997887425138024, -0.5996250301606075, -0.5998262611543055, -0.5996435157941825, -0.5998942951453371, -0.5997695555229796, -0.5999371980621484, -0.5998204136667056]
# Generation 0
# Max fitness value -0.5996073565117427
# Generation 10
# Max fitness value -0.5881577641630417
# Generation 20
# Max fitness value -0.21934121856411926
# Generation 30
# Max fitness value 0.8093468845124132
# Generation 40
# Max fitness value 0.9771089425714954
# Generation 50
# Max fitness value 0.9925427742125332
# Generation 60
# Max fitness value 0.9960427559268019
# Generation 70
# Max fitness value 0.996658720104401
# Generation 80
# Max fitness value 0.9968114529107761
# Generation 90
# Max fitness value 0.9968431790432897
# Generation 100
# Max fitness value 0.996917142527886
# Generation 110
# Max fitness value 0.9970153608580306
# Generation 120
# Max fitness value 0.9970193261972891
# Generation 130
# Max fitness value 0.9970193261972891
# Generation 140
# Max fitness value 0.9970535935880402
# Generation 150
# Max fitness value 0.9971835621525363
# Generation 160
# Max fitness value 0.9972434759016107
# Generation 170
# Max fitness value 0.9972434759016107
# Generation 180
# Max fitness value 0.9972545950872761
# Generation 190
# Max fitness value 0.9972545950872761
# Generation 200
# Max fitness value 0.9972545950872761
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  859.0276532173157  seconds
# Initial fitness:
#  [-0.5215069844511715, -0.5280692754254264, -0.5283176709579114, -0.5254161265322753, -0.5142127108742653, -0.530694884089324, -0.52276904924053, -0.5287837786288269, -0.5140301285005109, -0.5305968241069747, -0.5097352027487829, -0.5170055506503832, -0.5289749401499225, -0.5250318683676776, -0.527810279661924, -0.5324372706032123, -0.5175798687879574, -0.5153144410331176, -0.524025207268741, -0.5545612501515176, -0.5273895969218952, -0.5291233452045236, -0.5105054384775126, -0.520136379004394, -0.5114597310501392, -0.49208324419000493, -0.5215797284749043, -0.5218469210764394, -0.5291429844120532, -0.5203334657398744, -0.5205182000910225, -0.5250201538709818, -0.5231551304732622, -0.5373741635859559, -0.532072815888757, -0.5338426064199128, -0.48868350324466736, -0.5230941726563499, -0.5451897035463791, -0.5376212456655096, -0.5221271214489457, -0.521573167982643, -0.49298660550580387, -0.5264839722159262, -0.5300998845678557, -0.5187737245127972, -0.49616435211629484, -0.4545145763831988, -0.5269477502916424, -0.5156924169524177]
# Generation 0
# Max fitness value -0.44022631582271
# Generation 10
# Max fitness value 0.41626936965951733
# Generation 20
# Max fitness value 0.9173365636782622
# Generation 30
# Max fitness value 0.9844487962532631
# Generation 40
# Max fitness value 0.9947589926960053
# Generation 50
# Max fitness value 0.9963762918822134
# Generation 60
# Max fitness value 0.9968000481150465
# Generation 70
# Max fitness value 0.9971555088253525
# Generation 80
# Max fitness value 0.9972969493530996
# Generation 90
# Max fitness value 0.9974020759555762
# Generation 100
# Max fitness value 0.9974020759555762
# Generation 110
# Max fitness value 0.9974020759555762
# Generation 120
# Max fitness value 0.9974711325347388
# Generation 130
# Max fitness value 0.997506383486415
# Generation 140
# Max fitness value 0.997506383486415
# Generation 150
# Max fitness value 0.997509752167711
# Generation 160
# Max fitness value 0.9975982401144876
# Generation 170
# Max fitness value 0.9976331196743925
# Generation 180
# Max fitness value 0.9977140001776994
# Generation 190
# Max fitness value 0.9977140001776994
# Generation 200
# Max fitness value 0.9977140001776994
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 2
# Time:  884.448239326477  seconds
# Initial fitness:
#  [-0.5979453662676897, -0.596996512754602, -0.5957260219881976, -0.5973218381604933, -0.5994295034056786, -0.597642818530753, -0.5977496930348545, -0.5975640931742943, -0.597851366847685, -0.5980748130833959, -0.5990413407470778, -0.5977322293350489, -0.5975603789533211, -0.5990562371500211, -0.5972932035624201, -0.5975827612540104, -0.5970876589888952, -0.598190673017877, -0.5986021686693622, -0.5978560349961566, -0.598860173161551, -0.5983910831646603, -0.5984723131952775, -0.5975726793221532, -0.5984877397917608, -0.596880450925773, -0.5990461147478084, -0.5977170853064093, -0.5992414355214498, -0.5977343621109623, -0.5982085565340933, -0.5988108305289886, -0.5967151121466652, -0.5994581476448709, -0.5982667250178845, -0.5983488299909757, -0.5982852986737285, -0.5986926218405116, -0.5988233838484572, -0.597685298626846, -0.5981267276329374, -0.5998883849295149, -0.5980940891134079, -0.5986905167969014, -0.5976173820330287, -0.5986990931293592, -0.5992859126333789, -0.5975174814662143, -0.5975912205813412, -0.5971952412490372]
# Generation 0
# Max fitness value -0.5931375566228434
# Generation 10
# Max fitness value -0.1771712727615203
# Generation 20
# Max fitness value 0.8141679764842069
# Generation 30
# Max fitness value 0.9902019563534608
# Generation 40
# Max fitness value 0.9959356467707168
# Generation 50
# Max fitness value 0.996826658142975
# Generation 60
# Max fitness value 0.9969069877811321
# Generation 70
# Max fitness value 0.9969069877811321
# Generation 80
# Max fitness value 0.9969069877811321
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  364.52163887023926  seconds
# Initial fitness:
#  [-0.01804048052598306, 0.02620031061082473, 0.13403757328197824, 0.16693138124886694, 0.22402921847658055, 0.024873291043052526, 0.04849647612860092, -0.004052629874001457, 0.11853527668578309, -0.002811791415554654, 0.23088845471061917, 0.22144037403271594, 0.03391600490115507, 0.05864164607163555, 0.333069090480957, 0.10553422489636523, 0.0011601709499359514, 0.20642675296859744, 0.1263770151605259, 0.17285738368929862, 0.12376464808349082, 0.28521776934941345, 0.1851586588439357, 0.1437970572085545, 0.14742088583541532, 0.06696480529268012, 0.10715920247225613, -0.03661642429978609, 0.0019554434510895558, 0.08931689806931872, 0.04008306637539255, 0.10344624085003642, 0.1200501620934301, 0.14038090073742923, 0.27927523588720243, 0.14292712531811405, 0.12824821934966524, 0.043816221149916956, 0.32399171504697716, 0.055915701156092346, 0.0692497463101083, 0.21863679084050344, 0.06565526599835908, 0.11832906103872196, 0.1475398941868854, 0.3141442087734201, -0.04661274800638254, 0.09003989695610551, 0.18215397122245783, 0.15032383406133434]
# FOUND ADVERSARIAL
# Fitness of the adversarial 0.333069090480957
# Generation 0
# Max fitness value 0.5499018712170471
# Generation 10
# Max fitness value 0.9740941880342973
# Generation 20
# Max fitness value 0.9930766247662353
# Generation 30
# Max fitness value 0.9971488683418784
# Generation 40
# Max fitness value 0.9974812566403983
# Generation 50
# Max fitness value 0.9977285834859673
# Generation 60
# Max fitness value 0.9977704285972342
# Generation 70
# Max fitness value 0.9977704285972342
# Generation 80
# Max fitness value 0.9977704285972342
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 7
# Time:  382.95406579971313  seconds
# Initial fitness:
#  [-0.60064513374795, -0.6002073869984769, -0.6003547735855745, -0.6003985442151257, -0.6000043647711009, -0.601157667631958, -0.600402921201098, -0.6007473038740359, -0.6000230784491941, -0.600652504300003, -0.6004103830522778, -0.6000848401464184, -0.6006857374021586, -0.600234494710997, -0.600162839470135, -0.6002406931948174, -0.6012042883024463, -0.600188129300801, -0.6005796486097185, -0.600210237270668, -0.60075615358131, -0.6000721494277279, -0.600137356699367, -0.6000708585872726, -0.6016756113310328, -0.6004476997933739, -0.6003401228416068, -0.6003020223374431, -0.6001919999678453, -0.6030135668011759, -0.6021252575854918, -0.6001105735022125, -0.600299179085487, -0.6026231460024378, -0.5999948829111931, -0.6001692031662047, -0.6007094219489115, -0.6002319192484322, -0.6000549728632845, -0.600338067218882, -0.6004769106278747, -0.60011554191215, -0.6002389500972422, -0.6005017999371217, -0.6001040651914109, -0.6003140498226522, -0.600581301592686, -0.6000357378511448, -0.6002791575224503, -0.6008448913500771]
# Generation 0
# Max fitness value -0.5999588963168851
# Generation 10
# Max fitness value -0.38242759677955973
# Generation 20
# Max fitness value 0.9751385370836113
# Generation 30
# Max fitness value 0.9950434319771422
# Generation 40
# Max fitness value 0.9955849644042049
# Generation 50
# Max fitness value 0.995753537809484
# Generation 60
# Max fitness value 0.9958496850382269
# Generation 70
# Max fitness value 0.9960463008801512
# Generation 80
# Max fitness value 0.9960463008801512
# Generation 90
# Max fitness value 0.9960463008801512
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 6
# Time:  456.7036602497101  seconds
# Initial fitness:
#  [-0.6004085274612556, -0.6001894364241899, -0.6001191275131493, -0.6002339730144146, -0.6000164606066292, -0.6000920884922958, -0.6000242068590563, -0.6008122833819158, -0.6004391191937446, -0.6003834908831893, -0.6000973357491386, -0.6002257362259457, -0.6000924146171325, -0.6002366022468206, -0.6003007265006844, -0.600050882152884, -0.6001045852331643, -0.6000844552292309, -0.6002652328664856, -0.6000573328193586, -0.6002058371894801, -0.6000401378514234, -0.6000791532722145, -0.6000560705104905, -0.6004765859996173, -0.6001246809142416, -0.6000978220555881, -0.6000998939214295, -0.6002083332712171, -0.6000389077465157, -0.6006812002821098, -0.6002416477188425, -0.6001341378047456, -0.6000712226555436, -0.6001264917481305, -0.6001588004792301, -0.60026708199069, -0.6002830376418178, -0.6002685780405146, -0.6000978342123275, -0.600061759331956, -0.6001015387756573, -0.6001450412106667, -0.6000338339312513, -0.6001514503061165, -0.6000572193447757, -0.6001716236269705, -0.6002190098251906, -0.6005466874827243, -0.6002517410943553]
# Generation 0
# Max fitness value -0.6000164606066292
# Generation 10
# Max fitness value -0.6000164606066292
# Generation 20
# Max fitness value -0.5446746399435479
# Generation 30
# Max fitness value 0.2453074760472442
# Generation 40
# Max fitness value 0.8901628649063952
# Generation 50
# Max fitness value 0.9695854332287586
# Generation 60
# Max fitness value 0.9913053473810838
# Generation 70
# Max fitness value 0.9938540372091949
# Generation 80
# Max fitness value 0.9949523440119926
# Generation 90
# Max fitness value 0.9954221542664644
# Generation 100
# Max fitness value 0.9956022043234322
# Generation 110
# Max fitness value 0.9957758964678345
# Generation 120
# Max fitness value 0.9959569987078891
# Generation 130
# Max fitness value 0.9960228008878289
# Generation 140
# Max fitness value 0.9960352910168068
# Generation 150
# Max fitness value 0.9960676260231579
# Generation 160
# Max fitness value 0.9962145133979925
# Generation 170
# Max fitness value 0.9962402316712856
# Generation 180
# Max fitness value 0.9962402316712856
# Generation 190
# Max fitness value 0.9962402316712856
# Generation 200
# Max fitness value 0.9963347807139473
# Generation 210
# Max fitness value 0.9963347807139473
# Generation 220
# Max fitness value 0.9963347807139473
# Generation 230
# Max fitness value 0.9963394506909021
# Generation 240
# Max fitness value 0.9963394506909021
# Generation 250
# Max fitness value 0.996415761192041
# Generation 260
# Max fitness value 0.996415761192041
# Generation 270
# Max fitness value 0.9964194895725234
# Generation 280
# Max fitness value 0.9964459821618825
# Generation 290
# Max fitness value 0.9965360567233329
# Generation 300
# Max fitness value 0.9965360567233329
# Generation 310
# Max fitness value 0.9965360567233329
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 8
# Time:  899.7787699699402  seconds
# Initial fitness:
#  [0.26435242048658597, 0.4741074506714484, 0.1619411252991719, 0.4140736356158683, 0.4490801434120838, 0.42057921981892227, 0.3640131024658547, 0.2573473758614425, 0.49386690741901895, 0.3693130246983881, 0.307810753345844, 0.3448367271885794, -0.11606164835723898, 0.3881177478902025, 0.2796131033580611, 0.26433801960532394, 0.36802748514592276, 0.32147901048129945, 0.27022365571162227, 0.44892891159200304, 0.47310270869734633, 0.2361268704999718, 0.21314794435492948, 0.4286672612187271, 0.25045328927865496, 0.3704437698290426, 0.24081181356903292, -0.17696247038035462, 0.24289256435928097, 0.2825668820215706, 0.22101902800492912, 0.39851988585800224, 0.4290867508203551, 0.525258264854273, 0.2590870438556608, 0.20212790502350114, 0.3656282820912926, 0.4023156513507141, 0.4506986668961702, 0.14128179095532498, 0.22325382517510683, 0.2909318395149913, 0.042330736945052516, 0.36664353997900234, 0.38790120229631864, 0.35894015431362414, 0.3490073856966415, 0.0954612253746085, 0.5305791973111378, 0.3254812169310527]
# FOUND ADVERSARIAL
# Fitness of the adversarial 0.5305791973111378
# Generation 0
# Max fitness value 0.5847621505180516
# Generation 10
# Max fitness value 0.9460924557306486
# Generation 20
# Max fitness value 0.9944091869466599
# Generation 30
# Max fitness value 0.9976714061324817
# Generation 40
# Max fitness value 0.9980344161809538
# Generation 50
# Max fitness value 0.9980344161809538
# Generation 60
# Max fitness value 0.9980344161809538
# FITNESS DID NOT IMPROVE FOR 30 GENERATIONS
# Best adversarial image we could find:
#
# Left: adversarial 	 Right: ground truth
# True label: 9
# predicted label: 1
# Time:  125.90621876716614  seconds

# %% [markdown]
# # Save files

# %%
import pickle
file_ = open('GA_cifar_multicrossover_seed1', 'wb')
pickle.dump(evolved_examples, file_)
pickle.dump(times, file_)
pickle.dump(ssim_values, file_)
pickle.dump(fitness_of_evolved , file_)
pickle.dump(predicted_class, file_)
pickle.dump(number_of_rounds, file_)
file_.close()

print(f"Max time: {np.max(times)}")
print(f"Min time: {np.min(times)}")
print(f"Mean time: {np.mean(times)}")
print(f"Std time: {np.std(times)}\n")

print(f"Max fitness evolved: {np.max(fitness_of_evolved)}")
print(f"Min fitness evolved:: {np.min(fitness_of_evolved)}")
print(f"Mean fitness evolved: {np.mean(fitness_of_evolved)}")
print(f"Std fitness evolved:: {np.std(fitness_of_evolved)}\n")

print(f"Max ssim: {np.max(ssim_values)}")
print(f"Min ssim: {np.min(ssim_values)}")
print(f"Mean ssim: {np.mean(ssim_values)}")
print(f"Std ssim: {np.std(ssim_values)}\n")

print(f"Max rounds: {np.max(number_of_rounds)}")
print(f"Min rounds: {np.min(number_of_rounds)}")
print(f"Mean rounds: {np.mean(number_of_rounds)}")
print(f"Std rounds: {np.std(number_of_rounds)}\n")




print(f"Percentage of adversarial founds sucessfully : {numb_of_adv_found/len(adversarial_y)} %")
print(f"Percentage of adversarial founds after fitness not improving for 30 generations: {numb_of_found_after30/len(adversarial_y)} %")
# Out:
# Max time: 9506.450877428055
# Min time: 4.702284336090088
# Mean time: 578.5788470551483
# Std time: 844.829228220508
#
# Max fitness evolved: 0.9988297465238949
# Min fitness evolved:: -0.6004257896335974
# Mean fitness evolved: 0.8506571218253001
# Std fitness evolved:: 0.4433188836874684
#
# Max ssim: 0.23317069001773694
# Min ssim: 1.4829989520626086e-05
# Mean ssim: 0.02293181834233811
# Std ssim: 0.028459130830796077
#
# Max rounds: 321
# Min rounds: 0
# Mean rounds: 114.30075187969925
# Std rounds: 70.30566827728673
#
# Percentage of adversarial founds sucessfully : 0.03759398496240601 %
# Percentage of adversarial founds after fitness not improving for 30 generations: 0.9624060150375939 %

# %% [markdown]
# Open adversarial

# %%
with open('GA_cifar_multicrossover_seed1', 'rb') as f:
    evolved_examples = pickle.load(f)
    times= pickle.load(f)
    ssim_values = pickle.load(f)
    fitness_of_evolved = pickle.load(f)
    predicted_class = pickle.load(f)
    number_of_rounds = pickle.load(f)

# %%
#Correction of ssim values
new_ssim=[]
for s in ssim_values:
    new_ssim.append(1-s)
    
print(f"Max ssim: {np.max(new_ssim)}")
print(f"Min ssim: {np.min(new_ssim)}")
print(f"Mean ssim: {np.mean(new_ssim)}")
print(f"Std ssim: {np.std(new_ssim)}\n")
# Out:
# Max ssim: 0.9999828863616035
# Min ssim: 0.734840005168537
# Mean ssim: 0.9728460684887026
# Std ssim: 0.032421658245761396

# %%
#Correctionf of rounds  (replacing 0 with 1)
number_of_rounds = np.where(np.array(number_of_rounds)==0, 1, number_of_rounds)

# %%
number_of_rounds
# Out:
# array([118,  87,  77, 151,  71,  57, 163, 138,  83,  54,  61,  53,  78,
#        104,  62,  31,  94,  61,  76,  30, 108,  30,  80,  30,  30, 134,
#         58,  62,   2, 208,  55,  75,  85, 125, 254,  64,  31,  30, 147,
#         42,  66, 142, 147,  61,  92, 115,  70,  88, 112, 196,  63,  68,
#         30,  64,  78, 116,  54,  82,  67,   1, 106,  86, 109, 103, 111,
#         48,  59, 166,  66, 158,  66,  72, 155, 162, 137, 113,  91, 164,
#        119,  56,  30, 115,  52, 275,  82, 164, 167,  68, 162, 118, 185,
#         78, 154, 142,  73, 280,  77,  89, 162,  88,  95,  59, 119, 157,
#        132,  71, 111,  92,  70,  98, 137, 167,  60,  87,  59,  73,  30,
#        137,  55, 237, 164, 140,  69,  74,  30, 152, 194, 195, 221,  89,
#         72, 167,   1])

# %%
print(f"Max rounds: {np.max(number_of_rounds)}")
print(f"Min rounds: {np.min(number_of_rounds)}")
print(f"Mean rounds: {np.mean(number_of_rounds)}")
print(f"Std rounds: {np.std(number_of_rounds)}\n")
# Out:
# Max rounds: 280
# Min rounds: 1
# Mean rounds: 100.24812030075188
# Std rounds: 54.6330762705389

# %% [markdown]
# # Examples of what functions do

# %%
population = init_pop_from_sample(50,adversarial[15],adversarial_y[15][0])
fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),adversarial_y[15][0])
print(fitness)
# Out:
# [-0.7985892726591407, -0.7986649463807212, -0.7985705252188005, -0.7986603324640114, -0.7986640443846431, -0.7983015319368282, -0.798545200422354, -0.7983238295714443, -0.7986448602525132, -0.7986523954988857, -0.7985887420905552, -0.7985393478998531, -0.7989564462911779, -0.7988277150040406, -0.7989882228910968, -0.7986940212720168, -0.7988727765084926, -0.7987316295436042, -0.7984438426216252, -0.7990896847279569, -0.7988467516858758, -0.7984860210372816, -0.7986454906217331, -0.7986385435250732, -0.7987805617963863, -0.7986695314192882, -0.7987035827823399, -0.7987494380575793, -0.7989881134607149, -0.798920478946215, -0.7986249369840608, -0.7985955019172958, -0.7982727963182844, -0.7987309617863311, -0.7986727631087088, -0.7987490886114068, -0.7987777222228992, -0.7989488590725383, -0.7987275123124932, -0.7984690902712791, -0.7985118906684375, -0.7987075963889337, -0.7986641486373497, -0.7986463555893116, -0.7985731207770441, -0.7987383184102791, -0.7986167203393824, -0.7988712274292329, -0.7987522211469823, -0.7989383692241568]

# %%
plt.imshow(population[0].reshape(CIFAR_IMG,CIFAR_IMG))
plt.show()
print(f"Class for this {adversarial_y[15][0]}")
print(model.predict(population[0].reshape(1,CIFAR_IMG,CIFAR_IMG,1) /255.0))
# Out:
# Class for this 1
# [[2.3925936e-10 1.0000000e+00 5.6845797e-14 4.3043689e-12 4.4440273e-13
#   1.9210852e-13 1.0372402e-12 5.7237066e-13 2.6933677e-13 5.6719582e-08]]

# %%
parent1 = tournament(population, model, adversarial[15], adversarial_y[15]) 
parent2 = tournament(population, model, adversarial[15], adversarial_y[15])

# %%
fd, idx =  plt.subplots(1,2)
idx[0].imshow(parent1.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")
idx[1].imshow(parent2.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")

# %%
child1, child2 = multi_crossover(parent1, parent2,adversarial[15]) # crossover 
#child1, child2 = add_noise(child1), add_noise(child2) # apply mutation to pixels

# %%
fd, idx =  plt.subplots(1,2)
idx[0].imshow(child1.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")
idx[1].imshow(child2.reshape(CIFAR_IMG,CIFAR_IMG),cmap="gray")

# %%
print(f"diff between children {np.unique(child1-child2)}")
print(f"diff between parents {np.unique(parent1-parent2)}")
print(f"diff between p1 and c1 {np.unique(parent1-child1)}")
print(f"diff between p1 and c2 {np.unique(parent1-child2)}")
print(f"diff between p2 and c1 {np.unique(parent2-child1)}")
print(f"diff between p2 and c2 {np.unique(parent2-child2)}")
# Out:
# diff between children [-5.633789  -4.149948  -3.062912   0.         5.7095413  9.564171 ]
# diff between parents [-16.72924    -9.685455   -9.564171   -8.706863   -5.7095413  -4.29274
#   -3.8920288  -2.7790756  -1.6091766   0.          1.1050491   2.2260437
#    3.0292664   3.062912    4.149948    4.1768646   5.633789    6.016098
#    6.0724335  10.647095   17.198486   21.725456 ]
# diff between p1 and c1 [-16.72924    -9.685455   -9.564171   -5.7095413  -4.29274    -3.8920288
#   -2.7790756  -1.6091766   0.          1.1050491   2.2260437   3.0292664
#    3.062912    4.149948    4.1768646   5.633789    6.016098    6.0724335
#   10.647095   17.198486   21.725456 ]
# diff between p1 and c2 [-16.72924    -9.685455   -4.29274    -3.8920288  -2.7790756  -1.6091766
#    0.          1.1050491   2.2260437   3.0292664   4.1768646   6.016098
#    6.0724335  10.647095   17.198486   21.725456 ]
# diff between p2 and c1 [0.       8.706863]
# diff between p2 and c2 [-5.633789  -4.149948  -3.062912   0.         5.7095413  8.706863
#   9.564171 ]

# %%
bb = choose_better_child(child1, child2,adversarial[15],adversarial_y[15][0],model)

# %%
fitness = pop_fitness(model,np.expand_dims(population.reshape(population.shape[0],CIFAR_IMG,CIFAR_IMG),axis=3),img.reshape(CIFAR_IMG,CIFAR_IMG),label) 
print(fitness)
# Out:
# [0.8014106319734277, 0.8013349582518472, 0.8014293794137679, 0.8013389999639673, 0.801335669513062, 0.8016970375516973, 0.8014547042102144, 0.8016758843262608, 0.8013547582777604, 0.801347223031388, 0.8014111625420132, 0.8014605567327152, 0.8010434583413905, 0.8011719988936645, 0.8010114910066083, 0.8013058833605515, 0.8011271281240757, 0.8012682750889641, 0.8015560620109432, 0.8009099338023167, 0.8011529622118293, 0.8015138835952867, 0.8013537464388139, 0.8013613611074951, 0.8012191521013188, 0.8013303732132802, 0.8012963218502285, 0.8012501804726944, 0.8010117911718535, 0.8010794256863534, 0.8013749676485076, 0.8014044027152726, 0.801727108314284, 0.801269038213669, 0.8013271415238595, 0.8012508160211615, 0.8012221824096691, 0.80105104556003, 0.801272201585212, 0.8015308143612893, 0.8014880139641308, 0.8012923082436346, 0.8013355652603554, 0.8013535490432567, 0.8014264977532295, 0.8012615862222893, 0.801383184293186, 0.8011283911010407, 0.8012473973832913, 0.8010615354084115]
